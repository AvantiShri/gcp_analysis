# %% [markdown]
# <a href="https://colab.research.google.com/github/AvantiShri/gcp_analysis/blob/main/alldata/DownloadAllGCPData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/GCP_data/
# !mkdir all_data
# Out:
# /content/drive/MyDrive/GCP_data
# mkdir: cannot create directory ‘all_data’: File exists

# %%
# %cd /content/drive/MyDrive/GCP_data/all_data

for year in range(1998,2024):
  str_year = str(year)
  # !wget -N -r -nH --cut-dirs=1 --limit-rate=125k https://global-mind.org/data/eggsummary/wget/wget{str_year}.html
# Out:
# Streaming output truncated to the last 5000 lines.
# 2023-12-17 17:17:49 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-07-20.csv.gz’ saved [1882571/1882571]
#
# --2023-12-17 17:17:49--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-07-21.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1883004 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-07-21.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.79M   128KB/s    in 15s
#
# 2023-12-17 17:18:04 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-07-21.csv.gz’ saved [1883004/1883004]
#
# --2023-12-17 17:18:04--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-07-22.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1882994 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-07-22.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.79M   128KB/s    in 15s
#
# 2023-12-17 17:18:19 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-07-22.csv.gz’ saved [1882994/1882994]
#
# --2023-12-17 17:18:19--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-07-23.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1883120 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-07-23.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.79M   128KB/s    in 15s
#
# 2023-12-17 17:18:34 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-07-23.csv.gz’ saved [1883120/1883120]
#
# --2023-12-17 17:18:34--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-07-24.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1883036 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-07-24.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.79M   128KB/s    in 15s
#
# 2023-12-17 17:18:49 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-07-24.csv.gz’ saved [1883036/1883036]
#
# --2023-12-17 17:18:49--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-07-25.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1863218 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-07-25.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.78M   125KB/s    in 15s
#
# 2023-12-17 17:19:03 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-07-25.csv.gz’ saved [1863218/1863218]
#
# --2023-12-17 17:19:04--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-07-26.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1801131 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-07-26.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:19:18 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-07-26.csv.gz’ saved [1801131/1801131]
#
# --2023-12-17 17:19:18--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-07-27.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1800846 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-07-27.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:19:32 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-07-27.csv.gz’ saved [1800846/1800846]
#
# --2023-12-17 17:19:32--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-07-28.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1878880 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-07-28.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.79M   127KB/s    in 15s
#
# 2023-12-17 17:19:47 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-07-28.csv.gz’ saved [1878880/1878880]
#
# --2023-12-17 17:19:47--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-07-29.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1828873 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-07-29.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.74M   125KB/s    in 14s
#
# 2023-12-17 17:20:01 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-07-29.csv.gz’ saved [1828873/1828873]
#
# --2023-12-17 17:20:01--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-07-30.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1800418 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-07-30.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:20:16 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-07-30.csv.gz’ saved [1800418/1800418]
#
# --2023-12-17 17:20:16--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-07-31.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1800669 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-07-31.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:20:30 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-07-31.csv.gz’ saved [1800669/1800669]
#
# --2023-12-17 17:20:30--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-01.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1834775 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-01.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.75M   125KB/s    in 14s
#
# 2023-12-17 17:20:45 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-01.csv.gz’ saved [1834775/1834775]
#
# --2023-12-17 17:20:45--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-02.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1818277 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-02.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.73M   128KB/s    in 14s
#
# 2023-12-17 17:20:59 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-08-02.csv.gz’ saved [1818277/1818277]
#
# --2023-12-17 17:20:59--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-03.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1870386 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-03.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.78M   125KB/s    in 15s
#
# 2023-12-17 17:21:14 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-03.csv.gz’ saved [1870386/1870386]
#
# --2023-12-17 17:21:14--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-04.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1850847 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-04.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.76M   128KB/s    in 14s
#
# 2023-12-17 17:21:28 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-08-04.csv.gz’ saved [1850847/1850847]
#
# --2023-12-17 17:21:28--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-05.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1800902 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-05.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:21:43 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-05.csv.gz’ saved [1800902/1800902]
#
# --2023-12-17 17:21:43--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-06.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1800570 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-06.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:21:57 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-06.csv.gz’ saved [1800570/1800570]
#
# --2023-12-17 17:21:57--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-07.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1785467 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-07.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.70M   128KB/s    in 14s
#
# 2023-12-17 17:22:11 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-08-07.csv.gz’ saved [1785467/1785467]
#
# --2023-12-17 17:22:11--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-08.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1882972 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-08.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.79M   128KB/s    in 15s
#
# 2023-12-17 17:22:26 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-08-08.csv.gz’ saved [1882972/1882972]
#
# --2023-12-17 17:22:26--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-09.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1883278 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-09.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.80M   128KB/s    in 15s
#
# 2023-12-17 17:22:41 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-08-09.csv.gz’ saved [1883278/1883278]
#
# --2023-12-17 17:22:41--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-10.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1882669 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-10.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.79M   128KB/s    in 15s
#
# 2023-12-17 17:22:55 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-08-10.csv.gz’ saved [1882669/1882669]
#
# --2023-12-17 17:22:55--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-11.csv.gz
# Reusing existing connection to global-mind.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1868086 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-11.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.78M   125KB/s    in 15s
#
# 2023-12-17 17:23:10 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-11.csv.gz’ saved [1868086/1868086]
#
# --2023-12-17 17:23:10--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-12.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1801759 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-12.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:23:24 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-12.csv.gz’ saved [1801759/1801759]
#
# --2023-12-17 17:23:24--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-13.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1800984 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-13.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:23:39 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-13.csv.gz’ saved [1800984/1800984]
#
# --2023-12-17 17:23:39--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-14.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1801179 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-14.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:23:53 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-14.csv.gz’ saved [1801179/1801179]
#
# --2023-12-17 17:23:53--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-15.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1801440 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-15.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:24:07 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-15.csv.gz’ saved [1801440/1801440]
#
# --2023-12-17 17:24:07--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-17.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 606103 (592K) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-17.csv.gz’
#
# eggsummary/2022/bas 100%[===================>] 591.90K   128KB/s    in 4.6s
#
# 2023-12-17 17:24:12 (128 KB/s) - ‘eggsummary/2022/basketdata-2022-08-17.csv.gz’ saved [606103/606103]
#
# --2023-12-17 17:24:12--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-18.csv.gz
# Reusing existing connection to global-mind.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1718618 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-18.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.64M   128KB/s    in 13s
#
# 2023-12-17 17:24:25 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-08-18.csv.gz’ saved [1718618/1718618]
#
# --2023-12-17 17:24:25--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-19.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1719694 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-19.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.64M   128KB/s    in 13s
#
# 2023-12-17 17:24:39 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-08-19.csv.gz’ saved [1719694/1719694]
#
# --2023-12-17 17:24:39--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-20.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1800393 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-20.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:24:53 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-20.csv.gz’ saved [1800393/1800393]
#
# --2023-12-17 17:24:53--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-21.csv.gz
# Reusing existing connection to global-mind.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1801535 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-21.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:25:07 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-21.csv.gz’ saved [1801535/1801535]
#
# --2023-12-17 17:25:07--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-22.csv.gz
# Reusing existing connection to global-mind.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1767971 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-22.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.69M   125KB/s    in 14s
#
# 2023-12-17 17:25:21 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-22.csv.gz’ saved [1767971/1767971]
#
# --2023-12-17 17:25:21--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-23.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1719758 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-23.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.64M   128KB/s    in 13s
#
# 2023-12-17 17:25:35 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-08-23.csv.gz’ saved [1719758/1719758]
#
# --2023-12-17 17:25:35--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-24.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1718913 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-24.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.64M   126KB/s    in 13s
#
# 2023-12-17 17:25:48 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-24.csv.gz’ saved [1718913/1718913]
#
# --2023-12-17 17:25:48--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-25.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1718968 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-25.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.64M   128KB/s    in 13s
#
# 2023-12-17 17:26:02 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-08-25.csv.gz’ saved [1718968/1718968]
#
# --2023-12-17 17:26:02--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-26.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1628939 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-26.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.55M   129KB/s    in 13s
#
# 2023-12-17 17:26:15 (127 KB/s) - ‘eggsummary/2022/basketdata-2022-08-26.csv.gz’ saved [1628939/1628939]
#
# --2023-12-17 17:26:15--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-27.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1557500 (1.5M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-27.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.48M   128KB/s    in 12s
#
# 2023-12-17 17:26:27 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-08-27.csv.gz’ saved [1557500/1557500]
#
# --2023-12-17 17:26:27--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-28.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1557683 (1.5M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-28.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.49M   128KB/s    in 12s
#
# 2023-12-17 17:26:39 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-08-28.csv.gz’ saved [1557683/1557683]
#
# --2023-12-17 17:26:39--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-29.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1638063 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-29.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.56M   125KB/s    in 13s
#
# 2023-12-17 17:26:52 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-29.csv.gz’ saved [1638063/1638063]
#
# --2023-12-17 17:26:52--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-30.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1632715 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-30.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.56M   125KB/s    in 13s
#
# 2023-12-17 17:27:05 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-30.csv.gz’ saved [1632715/1632715]
#
# --2023-12-17 17:27:05--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-08-31.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1637804 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-08-31.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.56M   125KB/s    in 13s
#
# 2023-12-17 17:27:18 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-08-31.csv.gz’ saved [1637804/1637804]
#
# --2023-12-17 17:27:18--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-01.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1638109 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-01.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.56M   125KB/s    in 13s
#
# 2023-12-17 17:27:31 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-09-01.csv.gz’ saved [1638109/1638109]
#
# --2023-12-17 17:27:31--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-02.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1719089 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-02.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.64M   128KB/s    in 13s
#
# 2023-12-17 17:27:45 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-09-02.csv.gz’ saved [1719089/1719089]
#
# --2023-12-17 17:27:45--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-03.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1675801 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-03.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.60M   126KB/s    in 13s
#
# 2023-12-17 17:27:58 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-09-03.csv.gz’ saved [1675801/1675801]
#
# --2023-12-17 17:27:58--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-04.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1637776 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-04.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.56M   125KB/s    in 13s
#
# 2023-12-17 17:28:11 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-09-04.csv.gz’ saved [1637776/1637776]
#
# --2023-12-17 17:28:11--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-05.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1693198 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-05.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.61M   129KB/s    in 13s
#
# 2023-12-17 17:28:24 (127 KB/s) - ‘eggsummary/2022/basketdata-2022-09-05.csv.gz’ saved [1693198/1693198]
#
# --2023-12-17 17:28:24--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-06.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1615616 (1.5M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-06.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.54M   127KB/s    in 13s
#
# 2023-12-17 17:28:37 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-09-06.csv.gz’ saved [1615616/1615616]
#
# --2023-12-17 17:28:37--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-07.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1637493 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-07.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.56M   125KB/s    in 13s
#
# 2023-12-17 17:28:50 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-09-07.csv.gz’ saved [1637493/1637493]
#
# --2023-12-17 17:28:50--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-08.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1672276 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-08.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.59M   125KB/s    in 13s
#
# 2023-12-17 17:29:03 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-09-08.csv.gz’ saved [1672276/1672276]
#
# --2023-12-17 17:29:03--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-09.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1719304 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-09.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.64M   128KB/s    in 13s
#
# 2023-12-17 17:29:17 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-09-09.csv.gz’ saved [1719304/1719304]
#
# --2023-12-17 17:29:17--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-10.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1719480 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-10.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.64M   128KB/s    in 13s
#
# 2023-12-17 17:29:30 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-09-10.csv.gz’ saved [1719480/1719480]
#
# --2023-12-17 17:29:31--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-11.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1759949 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-11.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.68M   129KB/s    in 14s
#
# 2023-12-17 17:29:44 (127 KB/s) - ‘eggsummary/2022/basketdata-2022-09-11.csv.gz’ saved [1759949/1759949]
#
# --2023-12-17 17:29:44--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-12.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1835993 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-12.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.75M   125KB/s    in 14s
#
# 2023-12-17 17:29:59 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-09-12.csv.gz’ saved [1835993/1835993]
#
# --2023-12-17 17:29:59--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-13.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1882676 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-13.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.79M   128KB/s    in 15s
#
# 2023-12-17 17:30:14 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-09-13.csv.gz’ saved [1882676/1882676]
#
# --2023-12-17 17:30:14--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-14.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1880081 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-14.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.79M   127KB/s    in 15s
#
# 2023-12-17 17:30:28 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-09-14.csv.gz’ saved [1880081/1880081]
#
# --2023-12-17 17:30:29--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-15.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1800979 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-15.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:30:43 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-09-15.csv.gz’ saved [1800979/1800979]
#
# --2023-12-17 17:30:43--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-16.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1770561 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-16.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.69M   125KB/s    in 14s
#
# 2023-12-17 17:30:57 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-09-16.csv.gz’ saved [1770561/1770561]
#
# --2023-12-17 17:30:57--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-17.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1719456 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-17.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.64M   128KB/s    in 13s
#
# 2023-12-17 17:31:10 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-09-17.csv.gz’ saved [1719456/1719456]
#
# --2023-12-17 17:31:10--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-18.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1872574 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-18.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.79M   126KB/s    in 15s
#
# 2023-12-17 17:31:25 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-09-18.csv.gz’ saved [1872574/1872574]
#
# --2023-12-17 17:31:25--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-19.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1881430 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-19.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.79M   128KB/s    in 15s
#
# 2023-12-17 17:31:40 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-09-19.csv.gz’ saved [1881430/1881430]
#
# --2023-12-17 17:31:40--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-20.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1832945 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-20.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.75M   125KB/s    in 14s
#
# 2023-12-17 17:31:55 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-09-20.csv.gz’ saved [1832945/1832945]
#
# --2023-12-17 17:31:55--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-21.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1862207 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-21.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.78M   125KB/s    in 15s
#
# 2023-12-17 17:32:09 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-09-21.csv.gz’ saved [1862207/1862207]
#
# --2023-12-17 17:32:09--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-22.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1883456 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-22.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.80M   128KB/s    in 15s
#
# 2023-12-17 17:32:24 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-09-22.csv.gz’ saved [1883456/1883456]
#
# --2023-12-17 17:32:24--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-23.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1882697 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-23.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.79M   128KB/s    in 15s
#
# 2023-12-17 17:32:39 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-09-23.csv.gz’ saved [1882697/1882697]
#
# --2023-12-17 17:32:39--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-24.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1882334 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-24.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.79M   128KB/s    in 15s
#
# 2023-12-17 17:32:54 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-09-24.csv.gz’ saved [1882334/1882334]
#
# --2023-12-17 17:32:54--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-25.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1883353 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-25.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.80M   128KB/s    in 15s
#
# 2023-12-17 17:33:09 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-09-25.csv.gz’ saved [1883353/1883353]
#
# --2023-12-17 17:33:09--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-26.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1883059 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-26.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.79M   128KB/s    in 15s
#
# 2023-12-17 17:33:23 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-09-26.csv.gz’ saved [1883059/1883059]
#
# --2023-12-17 17:33:23--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-27.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1883397 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-27.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.80M   128KB/s    in 15s
#
# 2023-12-17 17:33:38 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-09-27.csv.gz’ saved [1883397/1883397]
#
# --2023-12-17 17:33:38--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-28.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1903909 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-28.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.82M   126KB/s    in 15s
#
# 2023-12-17 17:33:53 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-09-28.csv.gz’ saved [1903909/1903909]
#
# --2023-12-17 17:33:53--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-29.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1937283 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-29.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.85M   126KB/s    in 15s
#
# 2023-12-17 17:34:09 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-09-29.csv.gz’ saved [1937283/1937283]
#
# --2023-12-17 17:34:09--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-09-30.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1963973 (1.9M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-09-30.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.87M   125KB/s    in 15s
#
# 2023-12-17 17:34:24 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-09-30.csv.gz’ saved [1963973/1963973]
#
# --2023-12-17 17:34:24--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-01.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1963490 (1.9M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-01.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.87M   125KB/s    in 15s
#
# 2023-12-17 17:34:40 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-10-01.csv.gz’ saved [1963490/1963490]
#
# --2023-12-17 17:34:40--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-02.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1964580 (1.9M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-02.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.87M   125KB/s    in 15s
#
# 2023-12-17 17:34:55 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-10-02.csv.gz’ saved [1964580/1964580]
#
# --2023-12-17 17:34:55--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-03.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1960341 (1.9M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-03.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.87M   125KB/s    in 15s
#
# 2023-12-17 17:35:11 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-10-03.csv.gz’ saved [1960341/1960341]
#
# --2023-12-17 17:35:11--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-04.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1964503 (1.9M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-04.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.87M   125KB/s    in 15s
#
# 2023-12-17 17:35:26 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-10-04.csv.gz’ saved [1964503/1964503]
#
# --2023-12-17 17:35:27--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-05.csv.gz
# Reusing existing connection to global-mind.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1963903 (1.9M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-05.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.87M   125KB/s    in 15s
#
# 2023-12-17 17:35:42 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-10-05.csv.gz’ saved [1963903/1963903]
#
# --2023-12-17 17:35:42--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-06.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1964103 (1.9M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-06.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.87M   125KB/s    in 15s
#
# 2023-12-17 17:35:57 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-10-06.csv.gz’ saved [1964103/1964103]
#
# --2023-12-17 17:35:57--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-07.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1963832 (1.9M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-07.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.87M   125KB/s    in 15s
#
# 2023-12-17 17:36:13 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-10-07.csv.gz’ saved [1963832/1963832]
#
# --2023-12-17 17:36:13--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-08.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1964241 (1.9M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-08.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.87M   125KB/s    in 15s
#
# 2023-12-17 17:36:29 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-10-08.csv.gz’ saved [1964241/1964241]
#
# --2023-12-17 17:36:29--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-09.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1963643 (1.9M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-09.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.87M   125KB/s    in 15s
#
# 2023-12-17 17:36:44 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-10-09.csv.gz’ saved [1963643/1963643]
#
# --2023-12-17 17:36:44--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-10.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1964149 (1.9M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-10.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.87M   129KB/s    in 15s
#
# 2023-12-17 17:37:00 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-10-10.csv.gz’ saved [1964149/1964149]
#
# --2023-12-17 17:37:00--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-11.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1964576 (1.9M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-11.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.87M   125KB/s    in 15s
#
# 2023-12-17 17:37:15 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-10-11.csv.gz’ saved [1964576/1964576]
#
# --2023-12-17 17:37:15--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-12.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1948498 (1.9M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-12.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.86M   128KB/s    in 15s
#
# 2023-12-17 17:37:30 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-10-12.csv.gz’ saved [1948498/1948498]
#
# --2023-12-17 17:37:30--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-13.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1878108 (1.8M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-13.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.79M   127KB/s    in 15s
#
# 2023-12-17 17:37:45 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-10-13.csv.gz’ saved [1878108/1878108]
#
# --2023-12-17 17:37:45--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-14.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1796262 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-14.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.71M   125KB/s    in 14s
#
# 2023-12-17 17:38:00 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-10-14.csv.gz’ saved [1796262/1796262]
#
# --2023-12-17 17:38:00--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-15.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1800332 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-15.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:38:14 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-10-15.csv.gz’ saved [1800332/1800332]
#
# --2023-12-17 17:38:14--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-16.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1800695 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-16.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:38:28 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-10-16.csv.gz’ saved [1800695/1800695]
#
# --2023-12-17 17:38:28--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-17.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1800527 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-17.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.72M   125KB/s    in 14s
#
# 2023-12-17 17:38:42 (125 KB/s) - ‘eggsummary/2022/basketdata-2022-10-17.csv.gz’ saved [1800527/1800527]
#
# --2023-12-17 17:38:42--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-18.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1791496 (1.7M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-18.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.71M   129KB/s    in 14s
#
# 2023-12-17 17:38:56 (127 KB/s) - ‘eggsummary/2022/basketdata-2022-10-18.csv.gz’ saved [1791496/1791496]
#
# --2023-12-17 17:38:56--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-19.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1719258 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-19.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.64M   128KB/s    in 13s
#
# 2023-12-17 17:39:10 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-10-19.csv.gz’ saved [1719258/1719258]
#
# --2023-12-17 17:39:10--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-20.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1719957 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-20.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.64M   128KB/s    in 13s
#
# 2023-12-17 17:39:24 (126 KB/s) - ‘eggsummary/2022/basketdata-2022-10-20.csv.gz’ saved [1719957/1719957]
#
# --2023-12-17 17:39:24--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-21.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1695798 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-21.csv.gz’
#
# eggsummary/2022/bas 100%[===================>]   1.62M   130KB/s    in 13s
#
# 2023-12-17 17:39:37 (127 KB/s) - ‘eggsummary/2022/basketdata-2022-10-21.csv.gz’ saved [1695798/1695798]
#
# --2023-12-17 17:39:37--  https://global-mind.org/data/eggsummary/2022/basketdata-2022-10-22.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1637808 (1.6M) [application/x-gzip]
# Saving to: ‘eggsummary/2022/basketdata-2022-10-22.csv.gz’
#
# ...
#
# eggsummary/2023/bas 100%[===================>]   1.26M   128KB/s    in 10s
#
# 2023-12-17 19:02:32 (127 KB/s) - ‘eggsummary/2023/basketdata-2023-10-31.csv.gz’ saved [1326873/1326873]
#
# --2023-12-17 19:02:32--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-01.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1266487 (1.2M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-01.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.21M   129KB/s    in 9.7s
#
# 2023-12-17 19:02:42 (127 KB/s) - ‘eggsummary/2023/basketdata-2023-11-01.csv.gz’ saved [1266487/1266487]
#
# --2023-12-17 19:02:42--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-02.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1348605 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-02.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.29M   126KB/s    in 10s
#
# 2023-12-17 19:02:53 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-02.csv.gz’ saved [1348605/1348605]
#
# --2023-12-17 19:02:53--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-03.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1348293 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-03.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.29M   126KB/s    in 10s
#
# 2023-12-17 19:03:03 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-03.csv.gz’ saved [1348293/1348293]
#
# --2023-12-17 19:03:03--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-04.csv.gz
# Reusing existing connection to global-mind.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1348626 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-04.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.29M   126KB/s    in 10s
#
# 2023-12-17 19:03:14 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-04.csv.gz’ saved [1348626/1348626]
#
# --2023-12-17 19:03:14--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-05.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1348100 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-05.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.29M   126KB/s    in 10s
#
# 2023-12-17 19:03:25 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-05.csv.gz’ saved [1348100/1348100]
#
# --2023-12-17 19:03:25--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-06.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1348110 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-06.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.29M   126KB/s    in 10s
#
# 2023-12-17 19:03:35 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-06.csv.gz’ saved [1348110/1348110]
#
# --2023-12-17 19:03:35--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-07.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1348588 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-07.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.29M   126KB/s    in 10s
#
# 2023-12-17 19:03:46 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-07.csv.gz’ saved [1348588/1348588]
#
# --2023-12-17 19:03:46--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-08.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1348198 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-08.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.29M   126KB/s    in 10s
#
# 2023-12-17 19:03:57 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-08.csv.gz’ saved [1348198/1348198]
#
# --2023-12-17 19:03:57--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-09.csv.gz
# Reusing existing connection to global-mind.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1347938 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-09.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.29M   126KB/s    in 10s
#
# 2023-12-17 19:04:07 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-09.csv.gz’ saved [1347938/1347938]
#
# --2023-12-17 19:04:07--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-10.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1347762 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-10.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.29M   126KB/s    in 10s
#
# 2023-12-17 19:04:18 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-10.csv.gz’ saved [1347762/1347762]
#
# --2023-12-17 19:04:18--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-11.csv.gz
# Reusing existing connection to global-mind.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1348540 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-11.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.29M   126KB/s    in 10s
#
# 2023-12-17 19:04:29 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-11.csv.gz’ saved [1348540/1348540]
#
# --2023-12-17 19:04:29--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-12.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1348361 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-12.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.29M   126KB/s    in 10s
#
# 2023-12-17 19:04:39 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-12.csv.gz’ saved [1348361/1348361]
#
# --2023-12-17 19:04:39--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-13.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1348345 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-13.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.29M   126KB/s    in 10s
#
# 2023-12-17 19:04:50 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-13.csv.gz’ saved [1348345/1348345]
#
# --2023-12-17 19:04:50--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-14.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1348704 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-14.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.29M   126KB/s    in 10s
#
# 2023-12-17 19:05:01 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-14.csv.gz’ saved [1348704/1348704]
#
# --2023-12-17 19:05:01--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-15.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1348690 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-15.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.29M   126KB/s    in 10s
#
# 2023-12-17 19:05:11 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-15.csv.gz’ saved [1348690/1348690]
#
# --2023-12-17 19:05:11--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-16.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1348201 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-16.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.29M   126KB/s    in 10s
#
# 2023-12-17 19:05:22 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-16.csv.gz’ saved [1348201/1348201]
#
# --2023-12-17 19:05:22--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-17.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1343830 (1.3M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-17.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.28M   125KB/s    in 10s
#
# 2023-12-17 19:05:33 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-17.csv.gz’ saved [1343830/1343830]
#
# --2023-12-17 19:05:33--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-18.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1266685 (1.2M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-18.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.21M   129KB/s    in 9.7s
#
# 2023-12-17 19:05:43 (127 KB/s) - ‘eggsummary/2023/basketdata-2023-11-18.csv.gz’ saved [1266685/1266685]
#
# --2023-12-17 19:05:43--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-19.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1266739 (1.2M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-19.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.21M   129KB/s    in 9.7s
#
# 2023-12-17 19:05:53 (127 KB/s) - ‘eggsummary/2023/basketdata-2023-11-19.csv.gz’ saved [1266739/1266739]
#
# --2023-12-17 19:05:53--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-20.csv.gz
# Reusing existing connection to global-mind.org:443.
# HTTP request sent, awaiting response... No data received.
# Retrying.
#
# --2023-12-17 19:05:54--  (try: 2)  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-20.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1266533 (1.2M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-20.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.21M   129KB/s    in 9.7s
#
# 2023-12-17 19:06:04 (127 KB/s) - ‘eggsummary/2023/basketdata-2023-11-20.csv.gz’ saved [1266533/1266533]
#
# --2023-12-17 19:06:04--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-21.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1266474 (1.2M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-21.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.21M   129KB/s    in 9.7s
#
# 2023-12-17 19:06:14 (127 KB/s) - ‘eggsummary/2023/basketdata-2023-11-21.csv.gz’ saved [1266474/1266474]
#
# --2023-12-17 19:06:14--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-22.csv.gz
# Reusing existing connection to global-mind.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1225749 (1.2M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-22.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.17M   128KB/s    in 9.5s
#
# 2023-12-17 19:06:23 (126 KB/s) - ‘eggsummary/2023/basketdata-2023-11-22.csv.gz’ saved [1225749/1225749]
#
# --2023-12-17 19:06:23--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-23.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1265560 (1.2M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-23.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.21M   129KB/s    in 9.7s
#
# 2023-12-17 19:06:33 (127 KB/s) - ‘eggsummary/2023/basketdata-2023-11-23.csv.gz’ saved [1265560/1265560]
#
# --2023-12-17 19:06:33--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-24.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1229190 (1.2M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-24.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.17M   128KB/s    in 9.5s
#
# 2023-12-17 19:06:43 (127 KB/s) - ‘eggsummary/2023/basketdata-2023-11-24.csv.gz’ saved [1229190/1229190]
#
# --2023-12-17 19:06:43--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-25.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1184594 (1.1M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-25.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.13M   126KB/s    in 9.2s
#
# 2023-12-17 19:06:52 (126 KB/s) - ‘eggsummary/2023/basketdata-2023-11-25.csv.gz’ saved [1184594/1184594]
#
# --2023-12-17 19:06:52--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-26.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1185251 (1.1M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-26.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.13M   126KB/s    in 9.2s
#
# 2023-12-17 19:07:02 (126 KB/s) - ‘eggsummary/2023/basketdata-2023-11-26.csv.gz’ saved [1185251/1185251]
#
# --2023-12-17 19:07:02--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-27.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1266570 (1.2M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-27.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.21M   129KB/s    in 9.7s
#
# 2023-12-17 19:07:12 (127 KB/s) - ‘eggsummary/2023/basketdata-2023-11-27.csv.gz’ saved [1266570/1266570]
#
# --2023-12-17 19:07:12--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-28.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1243609 (1.2M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-28.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.19M   125KB/s    in 9.7s
#
# 2023-12-17 19:07:22 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-28.csv.gz’ saved [1243609/1243609]
#
# --2023-12-17 19:07:22--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-29.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1242264 (1.2M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-29.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.18M   125KB/s    in 9.7s
#
# 2023-12-17 19:07:32 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-29.csv.gz’ saved [1242264/1242264]
#
# --2023-12-17 19:07:32--  https://global-mind.org/data/eggsummary/2023/basketdata-2023-11-30.csv.gz
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1146534 (1.1M) [application/x-gzip]
# Saving to: ‘eggsummary/2023/basketdata-2023-11-30.csv.gz’
#
# eggsummary/2023/bas 100%[===================>]   1.09M   125KB/s    in 9.0s
#
# 2023-12-17 19:07:41 (125 KB/s) - ‘eggsummary/2023/basketdata-2023-11-30.csv.gz’ saved [1146534/1146534]
#
# FINISHED --2023-12-17 19:07:41--
# Total wall clock time: 1h 11m 51s
# Downloaded: 336 files, 521M in 1h 10m 37s (126 KB/s)

# %% [markdown]
# Code used for restarting download in case it terminates prematurely

# %%
# %cd /content/drive/MyDrive/GCP_data/all_data
#inspect all files for a given year to see when the download stopped
# !ls eggsummary/2022
# Out:
# /content/drive/MyDrive/GCP_data/all_data
# basketdata-2022-01-01.csv.gz  basketdata-2022-02-08.csv.gz  basketdata-2022-03-18.csv.gz
# basketdata-2022-01-02.csv.gz  basketdata-2022-02-09.csv.gz  basketdata-2022-03-19.csv.gz
# basketdata-2022-01-03.csv.gz  basketdata-2022-02-10.csv.gz  basketdata-2022-03-20.csv.gz
# basketdata-2022-01-04.csv.gz  basketdata-2022-02-11.csv.gz  basketdata-2022-03-21.csv.gz
# basketdata-2022-01-05.csv.gz  basketdata-2022-02-12.csv.gz  basketdata-2022-03-22.csv.gz
# basketdata-2022-01-06.csv.gz  basketdata-2022-02-13.csv.gz  basketdata-2022-03-23.csv.gz
# basketdata-2022-01-07.csv.gz  basketdata-2022-02-14.csv.gz  basketdata-2022-03-24.csv.gz
# basketdata-2022-01-08.csv.gz  basketdata-2022-02-15.csv.gz  basketdata-2022-03-25.csv.gz
# basketdata-2022-01-09.csv.gz  basketdata-2022-02-16.csv.gz  basketdata-2022-03-26.csv.gz
# basketdata-2022-01-10.csv.gz  basketdata-2022-02-17.csv.gz  basketdata-2022-03-27.csv.gz
# basketdata-2022-01-11.csv.gz  basketdata-2022-02-18.csv.gz  basketdata-2022-03-28.csv.gz
# basketdata-2022-01-12.csv.gz  basketdata-2022-02-19.csv.gz  basketdata-2022-03-29.csv.gz
# basketdata-2022-01-13.csv.gz  basketdata-2022-02-20.csv.gz  basketdata-2022-03-30.csv.gz
# basketdata-2022-01-14.csv.gz  basketdata-2022-02-21.csv.gz  basketdata-2022-03-31.csv.gz
# basketdata-2022-01-15.csv.gz  basketdata-2022-02-22.csv.gz  basketdata-2022-04-01.csv.gz
# basketdata-2022-01-16.csv.gz  basketdata-2022-02-23.csv.gz  basketdata-2022-04-02.csv.gz
# basketdata-2022-01-17.csv.gz  basketdata-2022-02-24.csv.gz  basketdata-2022-04-03.csv.gz
# basketdata-2022-01-18.csv.gz  basketdata-2022-02-25.csv.gz  basketdata-2022-04-04.csv.gz
# basketdata-2022-01-19.csv.gz  basketdata-2022-02-26.csv.gz  basketdata-2022-04-05.csv.gz
# basketdata-2022-01-20.csv.gz  basketdata-2022-02-27.csv.gz  basketdata-2022-04-06.csv.gz
# basketdata-2022-01-21.csv.gz  basketdata-2022-02-28.csv.gz  basketdata-2022-04-07.csv.gz
# basketdata-2022-01-22.csv.gz  basketdata-2022-03-01.csv.gz  basketdata-2022-04-08.csv.gz
# basketdata-2022-01-23.csv.gz  basketdata-2022-03-02.csv.gz  basketdata-2022-04-09.csv.gz
# basketdata-2022-01-24.csv.gz  basketdata-2022-03-03.csv.gz  basketdata-2022-04-10.csv.gz
# basketdata-2022-01-25.csv.gz  basketdata-2022-03-04.csv.gz  basketdata-2022-04-11.csv.gz
# basketdata-2022-01-26.csv.gz  basketdata-2022-03-05.csv.gz  basketdata-2022-04-12.csv.gz
# basketdata-2022-01-27.csv.gz  basketdata-2022-03-06.csv.gz  basketdata-2022-04-13.csv.gz
# basketdata-2022-01-28.csv.gz  basketdata-2022-03-07.csv.gz  basketdata-2022-04-14.csv.gz
# basketdata-2022-01-29.csv.gz  basketdata-2022-03-08.csv.gz  basketdata-2022-04-15.csv.gz
# basketdata-2022-01-30.csv.gz  basketdata-2022-03-09.csv.gz  basketdata-2022-04-16.csv.gz
# basketdata-2022-01-31.csv.gz  basketdata-2022-03-10.csv.gz  basketdata-2022-04-17.csv.gz
# basketdata-2022-02-01.csv.gz  basketdata-2022-03-11.csv.gz  basketdata-2022-04-18.csv.gz
# basketdata-2022-02-02.csv.gz  basketdata-2022-03-12.csv.gz  basketdata-2022-04-19.csv.gz
# basketdata-2022-02-03.csv.gz  basketdata-2022-03-13.csv.gz  basketdata-2022-04-20.csv.gz
# basketdata-2022-02-04.csv.gz  basketdata-2022-03-14.csv.gz  basketdata-2022-04-21.csv.gz
# basketdata-2022-02-05.csv.gz  basketdata-2022-03-15.csv.gz  basketdata-2022-04-22.csv.gz
# basketdata-2022-02-06.csv.gz  basketdata-2022-03-16.csv.gz  basketdata-2022-04-23.csv.gz
# basketdata-2022-02-07.csv.gz  basketdata-2022-03-17.csv.gz  basketdata-2022-04-24.csv.gz

# %%
#If the transport endpoint disconnects, need to remove the last partially donwloaded file
# %cd /content/drive/MyDrive/GCP_data/all_data
# !rm eggsummary/2022/basketdata-2022-04-24.csv.gz
# !rm eggsummary/wget/wget2022.html
# Out:
# /content/drive/MyDrive/GCP_data/all_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/GCP_data/all_data
# Out:
# /content/drive/MyDrive/GCP_data/all_data

# %%
# !du -h GCP1*
# Out:
# 70M	GCP1data_1998.hdf5
# 510M	GCP1data_1999.hdf5
# 822M	GCP1data_2000.hdf5
# 1.1G	GCP1data_2001.hdf5
# 3.6M	GCP1data_2002.hdf5
