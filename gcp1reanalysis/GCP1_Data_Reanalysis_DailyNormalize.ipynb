# %% [markdown]
# <a href="https://colab.research.google.com/github/AvantiShri/gcp_analysis/blob/main/gcp1reanalysis/GCP1_Data_Reanalysis_DailyNormalize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Preparation

# %%
#mount Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/GCP_data/all_data
#data at https://drive.google.com/drive/u/0/folders/1MUS-xbwoBiodWLz4gese19ti_ftlKsVu
# Out:
# /content/drive/MyDrive/GCP_data/all_data

# %%
#install utilities code for reading/parsing data at https://github.com/AvantiShri/gcpdatautils
# !pip uninstall -y gcpdatautils #uninstall the pre-existing version if want to fetch latest
# !pip install git+https://github.com/AvantiShri/gcpdatautils.git@main #install latest from github

#Note: the code that was used to consolidate the downloaded csv.gz files into hdf5 files
# is at https://github.com/AvantiShri/gcp_analysis/blob/main/alldata/Consolidate_GCP_as_HDF5.ipynb
# Out:
# WARNING: Skipping gcpdatautils as it is not installed.
# Collecting git+https://github.com/AvantiShri/gcpdatautils.git@main
#   Cloning https://github.com/AvantiShri/gcpdatautils.git (to revision main) to /tmp/pip-req-build-e4q_j6_b
#   Running command git clone --filter=blob:none --quiet https://github.com/AvantiShri/gcpdatautils.git /tmp/pip-req-build-e4q_j6_b
#   Resolved https://github.com/AvantiShri/gcpdatautils.git to commit 55a9bc16c7c36ea920eafb44079d401f76da48f1
#   Preparing metadata (setup.py) ... done
# Collecting bs4 (from gcpdatautils==0.1.1.3)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from gcpdatautils==0.1.1.3) (3.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gcpdatautils==0.1.1.3) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gcpdatautils==0.1.1.3) (1.11.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->gcpdatautils==0.1.1.3) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->gcpdatautils==0.1.1.3) (2.5)
# Building wheels for collected packages: gcpdatautils
#   Building wheel for gcpdatautils (setup.py) ... done
#   Created wheel for gcpdatautils: filename=gcpdatautils-0.1.1.3-py3-none-any.whl size=6405 sha256=96241a41c6a71b106fa2305de60a34544a85fe9b1671520044fe9165d113c915
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g8zxaeob/wheels/8c/35/d9/946037b24577e21d0dce0d66645d002768f5bac3497186d55f
# Successfully built gcpdatautils
# Installing collected packages: bs4, gcpdatautils
# Successfully installed bs4-0.0.2 gcpdatautils-0.1.1.3

# %% [markdown]
# Load in the GCP event timeperiod definitions

# %%
from gcpdatautils import parse_events_html

#download the formal event registry if not already present
# !wget https://global-mind.org/pred_formal.html -O pred_formal.html

# we will parse the events file, dropping events longer than 30 days for memory efficiency
# we will also drop 'New Year Var...' events as they tend to be redundant in duration
# with the 'mean' events, and we are going to do a standard analysis on all the events
included_events = parse_events_html("/content/drive/MyDrive/GCP_data/pred_formal.html",
                                    exclude_events_longer_than_days=30)
# Out:
# --2024-02-13 20:06:49--  https://global-mind.org/pred_formal.html
# Resolving global-mind.org (global-mind.org)... 162.245.217.130
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘pred_formal.html’
#
# pred_formal.html        [ <=>                ] 184.64K  --.-KB/s    in 0.1s
#
# 2024-02-13 20:06:49 (1.81 MB/s) - ‘pred_formal.html’ saved [189067]
#
# Skipping because redundant with a corresponding 'mean' event:  43 New Year Var 99-00 1999-12-31 09:30:00 2000-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  65 New Year Var 00-01 2000-12-31 09:30:00 2001-01-01 11:29:59
# Skipping because end < start: 82 Silent Prayer, Sept 14 2001-09-14 10:00:00 2001-09-14 10:00:00
# Skipping because redundant with a corresponding 'mean' event:  98 New Year Var 01-02 2001-12-31 09:30:00 2002-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  126 New Year Variance 2002-12-31 09:30:00 2003-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  163 New Year Variance 2003-12-31 09:30:00 2004-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  191 New Year Variance 2004-12-31 09:30:00 2005-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  210 New Year Dev-Net Var 2005-12-31 23:53:00 2006-01-01 00:00:59
# Skipping because event is more than 30 days long! 223 TM Flyer Aggregation 2006-07-29 12:30:00 2006-09-09 23:29:59
# Skipping because redundant with a corresponding 'mean' event:  232 New Year Variance 2006-12-31 09:30:00 2007-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  257 New Year Var, 2008 2007-12-31 09:30:00 2008-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  284 New Year Variance 2009 2008-12-31 09:30:00 2009-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  318 New Year Variance 2010 2009-12-31 09:30:00 2010-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  357 New Year Variance 2011 2010-12-31 09:30:00 2011-01-01 11:29:59
# Skipping because end < start: 392 Troy Davis Execution 2011-09-22 00:00:00 2011-09-21 05:59:59
# Skipping because redundant with a corresponding 'mean' event:  405 New Year Variance 2012 2011-12-31 09:30:00 2012-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  439 New Year Variance 2013 2012-12-31 09:30:00 2013-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  474 New Year Variance 2014 2013-12-31 09:30:00 2014-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  495 New Year Variance 2015 2014-12-31 09:30:00 2015-01-01 11:29:59

# %%
len(included_events)
# Out:
# 480

# %% [markdown]
# Load the code for reading from the hdf5 files

# %%
import numpy as np
from collections import defaultdict
import h5py
from datetime import datetime, timedelta
from gcpdatautils import GCPHdf5DataReader, GCPMissingDataError

#Refer to the github repo https://github.com/AvantiShri/gcpdatautils for the
# code for reading from the hdf5 files
#Instantiate the hdf5 data reader
#it will auto-load a rotteneggs.txt file specifying bad data time periods (downloaded from https://global-mind.org/rotteneggs and saved in the package)
# this rotten egg file can be overridden by altering the arguments to the GCPHdf5DataReader
gcp_data_reader = GCPHdf5DataReader()
# Out:
# Parsing the bad data file: /usr/local/lib/python3.10/dist-packages/gcpdatautils/resources/rotteneggs.txt
# manually correcting 47,2000-01-01 00:00:00,2001-06-31 23:59:59,2222
# manually correcting 47,2008-04-25 00:00:00,2008-04-55 23:59:59,1092

# %% [markdown]
# Pull data for a specific event to compare to the GCP plots, as a sanity check

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import scipy
#data for a top-ranked GCP event - Valentine's day 2009
# Compare to: https://global-mind.org/valentines.09.html
idx=263
print(included_events[idx])

start_datetime, end_datetime = included_events[idx][2], included_events[idx][3]
event_data = gcp_data_reader.fetch_data(start_datetime, end_datetime, normalize=False)[0] #returns both the event data and the device ids; we just want the data

#make the chi-squared-minus-1 plot
csm1 = np.square(np.nansum((event_data - 100)/np.sqrt(50), axis=1)/np.sqrt(
        np.sum(np.isnan(event_data)==False, axis=1))) - 1
plt.figure(figsize=(20,5))
plt.plot(np.arange(len(csm1)), np.cumsum(csm1))
#also plot the p=0.05 envelop
plt.plot(np.arange(len(csm1)), np.array([scipy.stats.chi2.ppf(0.95, x+1)
                                         for x in np.arange(len(csm1))])
                                        - (np.arange(len(csm1))+1) )
plt.show()
# Out:
# ('289', 'Meditations Valentines Day', datetime.datetime(2009, 2, 14, 0, 0), datetime.datetime(2009, 2, 14, 23, 59, 59), 86400.0)

# %% [markdown]
# Load the empirical variances, computed from https://github.com/AvantiShri/gcp_analysis/blob/main/alldata/ComputeLifetimeDeviceStats.ipynb

# %%
import json
from matplotlib import pyplot as plt

device_to_empirical_variances = json.loads(open("empirical_device_variances.json").read())
plt.hist(device_to_empirical_variances.values(), bins=50)
plt.show()

# %% [markdown]
# Do aggregate analysis

# %%
from datetime import datetime,timedelta
import numpy as np
import h5py
import traceback
import scipy


def normalize_by_lifetime_device_variance(data, devices, device_to_empirical_variances):
  data = np.array(data) #make a copy, just in case
  for i,device in enumerate(devices):
    scalefactor = (np.sqrt(device_to_empirical_variances[str(int(device))])/np.sqrt(50))
    data[:,i] = ((data[:,i]-100)/scalefactor)+100
  return data


def compute_pvaltoz(egg_values):

  num_nonnan_eggs = np.sum(np.isnan(egg_values)==False, axis=1) #get the number of non NaN eggs per row
  egg_zscores = (egg_values - 100)/np.sqrt(50)
  composite_z_scores = np.nansum(egg_zscores, axis=1)/np.sqrt(num_nonnan_eggs)

  print(np.nansum(np.square(composite_z_scores)))
  pvaltoz_sumthensquare = scipy.stats.norm.ppf(
      scipy.stats.chi2.cdf(x=np.nansum(np.square(composite_z_scores)),
                           df=np.sum(np.isnan(composite_z_scores)==False)))
  pvaltoz_squarethensum = scipy.stats.norm.ppf(
      scipy.stats.chi2.cdf(np.nansum(np.square(egg_zscores)),
                           df=np.sum(np.isnan(egg_zscores)==False)))

  return pvaltoz_sumthensquare, pvaltoz_squarethensum


def get_normalized_data(start_datetime, end_datetime, device_to_empirical_variances):
  data, devices = gcp_data_reader.fetch_data(start_datetime, end_datetime, normalize=DAY_NORMALIZE)
  if LIFETIME_NORMALIZE:
    data = normalize_by_lifetime_device_variance(data, devices, device_to_empirical_variances)
  return data


DAY_NORMALIZE = True
LIFETIME_NORMALIZE = False
assert (DAY_NORMALIZE and LIFETIME_NORMALIZE)==False #at most one should be true

control_timeshifts = [-2, 2] #how much to shift the events by (as a multiple of their duration) to define 'control' time periods

surviving_events = [] #in case we encounter missing data errors, maintain a list of surviving events

eventcount = 0

allevents_pvaltozs_sumthensquare = []
allevents_pvaltozs_squarethensum = []
controls_pvaltozs_sumthensquare = defaultdict(list)
controls_pvaltozs_squarethensum = defaultdict(list)

missing_data_errors = []

for (event_num, event_name, start_datetime, end_datetime, duration) in included_events[:]:
  eventcount += 1
  print("EVENT COUNT", eventcount)
  print(event_num, event_name, start_datetime, end_datetime, duration)
  try:
    event_data = get_normalized_data(start_datetime, end_datetime, device_to_empirical_variances)
    event_pvaltoz_sumthensquare, event_pvaltoz_squarethensum = compute_pvaltoz(event_data)
    print("Event data: Sum then square:", event_pvaltoz_sumthensquare)
    print("Event data: Square then sum:", event_pvaltoz_squarethensum)

    print("For controls...")
    thisevent_control_pvaltozs_sumthensquare = {}
    thisevent_control_pvaltozs_squarethensum = {}
    for control_timeshift in control_timeshifts:
      timeshift = timedelta(seconds=control_timeshift*duration)
      control_starttime = start_datetime + timeshift
      control_endtime = end_datetime + timeshift
      print("Control start and end:", control_starttime, control_endtime)
      control_data = get_normalized_data(control_starttime, control_endtime, device_to_empirical_variances)
      pvaltozs_sumthensquare, pvaltozs_squarethensum = compute_pvaltoz(control_data)
      print("Control data: Sum then square:", pvaltozs_sumthensquare)
      print("Control data: Square then sum:", pvaltozs_squarethensum)
      thisevent_control_pvaltozs_sumthensquare[control_timeshift] = pvaltozs_sumthensquare
      thisevent_control_pvaltozs_squarethensum[control_timeshift] = pvaltozs_squarethensum

    allevents_pvaltozs_sumthensquare.append(event_pvaltoz_sumthensquare)
    allevents_pvaltozs_squarethensum.append(event_pvaltoz_squarethensum)
    for control_timeshift in control_timeshifts:
      controls_pvaltozs_sumthensquare[control_timeshift].append(
          thisevent_control_pvaltozs_sumthensquare[control_timeshift])
      controls_pvaltozs_squarethensum[control_timeshift].append(
          thisevent_control_pvaltozs_squarethensum[control_timeshift])
    surviving_events.append((event_num, event_name, start_datetime, end_datetime, duration))
  except GCPMissingDataError as e:
    print("MISSING DATA ERROR!",e)
    missing_data_errors.append(e)
# Out:
# EVENT COUNT 1
# 1 Embassy 1998-08-07 07:15:00 1998-08-07 10:14:59 10800.0
# 11021.309634950274
# Event data: Sum then square: 1.5001853950537507
# Event data: Square then sum: 1.0480112038145037
# For controls...
# Control start and end: 1998-08-07 01:15:00 1998-08-07 04:14:59
# 10806.66867004427
# Control data: Sum then square: 0.049901095628338235
# Control data: Square then sum: 0.3346089891139333
# Control start and end: 1998-08-07 13:15:00 1998-08-07 16:14:59
# 10726.058666734538
# Control data: Sum then square: -0.4997211106026594
# Control data: Square then sum: -2.0770349700513995
# EVENT COUNT 2
# 3 Bomb Afghanistan 1998-08-20 17:15:00 1998-08-20 17:44:59 1800.0
# 1774.7327520892386
# Event data: Sum then square: -0.4119831063396925
# Event data: Square then sum: 0.0242888203427187
# For controls...
# Control start and end: 1998-08-20 16:15:00 1998-08-20 16:44:59
# 1857.9334630974467
# Control data: Sum then square: 0.9664709526977595
# Control data: Square then sum: 0.9921617374830158
# Control start and end: 1998-08-20 18:15:00 1998-08-20 18:44:59
# 1838.5038496599277
# Control data: Sum then square: 0.6483030628737187
# Control data: Square then sum: -0.6227111908509502
# EVENT COUNT 3
# 4 Swissair 111 Crash 1998-09-03 01:00:00 1998-09-03 03:59:59 10800.0
# 11013.650892733065
# Event data: Sum then square: 1.4487619944117602
# Event data: Square then sum: 0.4830858942201652
# For controls...
# Control start and end: 1998-09-02 19:00:00 1998-09-02 21:59:59
# 10619.672600389
# Control data: Sum then square: -1.229326294351592
# Control data: Square then sum: -1.331161791179076
# Control start and end: 1998-09-03 07:00:00 1998-09-03 09:59:59
# 10686.749365889276
# Control data: Sum then square: -0.7687429234584539
# Control data: Square then sum: -0.9868891634393977
# EVENT COUNT 4
# 5 McGwire Record 1998-09-09 01:00:00 1998-09-09 01:29:59 1800.0
# 1757.136154265698
# Event data: Sum then square: -0.7090146170218615
# Event data: Square then sum: -0.4981143918635452
# For controls...
# Control start and end: 1998-09-09 00:00:00 1998-09-09 00:29:59
# 1773.5158548348859
# Control data: Sum then square: -0.4324609448453193
# Control data: Square then sum: -0.17279460386357245
# Control start and end: 1998-09-09 02:00:00 1998-09-09 02:29:59
# 1858.208396922284
# Control data: Sum then square: 0.9709571923401417
# Control data: Square then sum: -0.07842242657040556
# EVENT COUNT 5
# 6 Clinton Grand Jury 1998-09-11 19:00:00 1998-09-11 22:59:59 14400.0
# 14487.996972772253
# Event data: Sum then square: 0.5214010487767936
# Event data: Square then sum: -0.8434368308642639
# For controls...
# Control start and end: 1998-09-11 11:00:00 1998-09-11 14:59:59
# 14410.08719905945
# Control data: Sum then square: 0.06335367193204308
# Control data: Square then sum: 1.1544382078971434
# Control start and end: 1998-09-12 03:00:00 1998-09-12 06:59:59
# 14152.397070972947
# Control data: Sum then square: -1.4635275128124814
# Control data: Square then sum: -2.112258043487678
# EVENT COUNT 6
# 7 Casitas Collapse 1998-10-30 15:30:00 1998-10-30 15:59:59 1800.0
# 1926.9066400720558
# Event data: Sum then square: 2.078399698696627
# Event data: Square then sum: -0.15686926281843058
# For controls...
# Control start and end: 1998-10-30 14:30:00 1998-10-30 14:59:59
# 1757.9533950147754
# Control data: Sum then square: -0.6951756716637287
# Control data: Square then sum: 0.7521927988420594
# Control start and end: 1998-10-30 16:30:00 1998-10-30 16:59:59
# 1639.0019289037823
# Control data: Sum then square: -2.7565583889236227
# Control data: Square then sum: -1.7281084049863655
# EVENT COUNT 7
# 8 Casitas Flood 1998-10-30 19:00:00 1998-10-30 21:59:59 10800.0
# 10624.131611481149
# Event data: Sum then square: -1.1986482908542722
# Event data: Square then sum: -0.29554462915571644
# For controls...
# Control start and end: 1998-10-30 13:00:00 1998-10-30 15:59:59
# 10917.865696004981
# Control data: Sum then square: 0.8036074689816141
# Control data: Square then sum: 0.414385461787429
# Control start and end: 1998-10-31 01:00:00 1998-10-31 03:59:59
# 10590.657826192364
# Control data: Sum then square: -1.4291583350605404
# Control data: Square then sum: -0.8172396523509203
# EVENT COUNT 8
# 9 Global Vigil JT 1998-11-13 16:00:00 1998-11-13 16:14:59 900.0
# 833.4626393629746
# Event data: Sum then square: -1.5928931208430714
# Event data: Square then sum: -1.135529314465848
# For controls...
# Control start and end: 1998-11-13 15:30:00 1998-11-13 15:44:59
# 842.8504969295897
# Control data: Sum then square: -1.3608444899240801
# Control data: Square then sum: -0.20847344358854142
# Control start and end: 1998-11-13 16:30:00 1998-11-13 16:44:59
# 889.2716788194522
# Control data: Sum then square: -0.23815077575469001
# Control data: Square then sum: 0.9858622363920456
# EVENT COUNT 9
# 11 World Peace UN 1998-12-10 23:30:00 1998-12-11 00:29:59 3600.0
# Before masking, fraction of nans in raw data is 0.15488095238095237 for 1998-12-10 00:00:00 to 1998-12-10 23:59:59
# Found 'rotten egg' entries for device id: 1005 in time range 1998-12-10 00:00:00 to 1998-12-10 23:59:59 (range: 1998-12-10 00:00:00 to 1998-12-17 23:59:59 )
# After masking, fraction of nans in raw data is 0.15585482804232803
# Before masking, fraction of nans in raw data is 4.96031746031746e-06 for 1998-12-11 00:00:00 to 1998-12-11 23:59:59
# Found 'rotten egg' entries for device id: 1005 in time range 1998-12-11 00:00:00 to 1998-12-11 23:59:59 (range: 1998-12-10 00:00:00 to 1998-12-17 23:59:59 )
# After masking, fraction of nans in raw data is 0.14286210317460318
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.10/dist-packages/gcpdatautils/load_data.py:138: RuntimeWarning: Mean of empty slice
#   device_day_means = np.nan_to_num(np.nanmean(full_day_data, axis=0), 100)
# Streaming output truncated to the last 5000 lines.
# 28740.259045380728
# Control data: Sum then square: -0.24631470515556045
# Control data: Square then sum: -0.6766871228200622
# Control start and end: 2003-12-26 17:30:00 2003-12-27 01:29:59
# 28916.687747587726
# Control data: Sum then square: 0.4883207043192577
# Control data: Square then sum: -1.416896869843995
# EVENT COUNT 143
# 161 60 Seconds for Peace 2003-12-27 21:00:00 2003-12-27 21:00:59 60.0
# 76.49626733141957
# Event data: Sum then square: 1.446137481418577
# Event data: Square then sum: 0.3142922413207431
# For controls...
# Control start and end: 2003-12-27 20:58:00 2003-12-27 20:58:59
# 56.27109360076517
# Control data: Sum then square: -0.2864937246552365
# Control data: Square then sum: 0.16103948419132375
# Control start and end: 2003-12-27 21:02:00 2003-12-27 21:02:59
# 58.87690025518253
# Control data: Sum then square: -0.04217003159839621
# Control data: Square then sum: -0.043961514640322746
# EVENT COUNT 144
# 162 New Year Mean 2003-2004 2003-12-31 09:30:00 2004-01-01 12:29:59 97200.0
# 97315.03951337209
# Event data: Sum then square: 0.2623239343223583
# Event data: Square then sum: -0.03700063867199158
# For controls...
# Control start and end: 2003-12-29 03:30:00 2003-12-30 06:29:59
# 97514.20919997312
# Control data: Sum then square: 0.7133861112018093
# Control data: Square then sum: 0.7623204107750342
# Control start and end: 2004-01-02 15:30:00 2004-01-03 18:29:59
# 96849.59754656996
# Control data: Sum then square: -0.794173419920201
# Control data: Square then sum: -0.16092827499202683
# EVENT COUNT 145
# 164 Hadj Ritual Tragedy 2004-02-01 05:30:00 2004-02-01 07:29:59 7200.0
# 7299.751214557347
# Event data: Sum then square: 0.8330012041907803
# Event data: Square then sum: 1.7097438866677819
# For controls...
# Control start and end: 2004-02-01 01:30:00 2004-02-01 03:29:59
# 7235.081182325819
# Control data: Sum then square: 0.2974230684480194
# Control data: Square then sum: -0.2447933163907598
# Control start and end: 2004-02-01 09:30:00 2004-02-01 11:29:59
# 7055.2050730778465
# Control data: Sum then square: -1.20924423329785
# Control data: Square then sum: -0.8543474308613647
# EVENT COUNT 146
# 165 Iran Train Explosion 2004-02-18 00:30:00 2004-02-18 10:29:59 36000.0
# 36277.76660619723
# Event data: Sum then square: 1.0350074908081457
# Event data: Square then sum: -0.7840416494037002
# For controls...
# Control start and end: 2004-02-17 04:30:00 2004-02-17 14:29:59
# 35242.03381079506
# Control data: Sum then square: -2.842356241602695
# Control data: Square then sum: -1.207934937905004
# Control start and end: 2004-02-18 20:30:00 2004-02-19 06:29:59
# 36116.585501653
# Control data: Sum then square: 0.4365042206639369
# Control data: Square then sum: 1.2500497594876578
# EVENT COUNT 147
# 166 Oscar Ceremony 2004 2004-03-01 01:00:00 2004-03-01 05:08:59 14940.0
# 14990.393192862375
# Event data: Sum then square: 0.2950573931733623
# Event data: Square then sum: -1.0073421949400088
# For controls...
# Control start and end: 2004-02-29 16:42:00 2004-02-29 20:50:59
# 15213.582804266875
# Control data: Sum then square: 1.5769915608591591
# Control data: Square then sum: 0.48353019608853554
# Control start and end: 2004-03-01 09:18:00 2004-03-01 13:26:59
# 14894.292262699231
# Control data: Sum then square: -0.2608355436500188
# Control data: Square then sum: -1.6918423661131756
# EVENT COUNT 148
# 167 Attacks on Shiites, Iraq 2004-03-02 06:30:00 2004-03-02 10:29:59 14400.0
# 14528.86463248876
# Event data: Sum then square: 0.7610142424816396
# Event data: Square then sum: -1.1179773749202226
# For controls...
# Control start and end: 2004-03-01 22:30:00 2004-03-02 02:29:59
# 14574.929278150248
# Control data: Sum then square: 1.0305604804954103
# Control data: Square then sum: 0.8296724559333215
# Control start and end: 2004-03-02 14:30:00 2004-03-02 18:29:59
# 14236.896334451314
# Control data: Sum then square: -0.9608182966925732
# Control data: Square then sum: 0.9353381737490104
# EVENT COUNT 149
# 168 Terror Attacks in Madrid 2004-03-11 06:00:00 2004-03-11 10:59:59 18000.0
# 17693.42306978506
# Event data: Sum then square: -1.621549342333091
# Event data: Square then sum: -0.8192709686021754
# For controls...
# Control start and end: 2004-03-10 20:00:00 2004-03-11 00:59:59
# 17832.3478472312
# Control data: Sum then square: -0.8828463443858349
# Control data: Square then sum: 1.0540447296209507
# Control start and end: 2004-03-11 16:00:00 2004-03-11 20:59:59
# 17918.676806692598
# Control data: Sum then square: -0.4257430745206188
# Control data: Square then sum: 1.1772264166026947
# EVENT COUNT 150
# 169 Demonstrations in Spain 2004-03-12 11:00:00 2004-03-12 22:59:59 43200.0
# 43510.500786685356
# Event data: Sum then square: 1.0560915461407947
# Event data: Square then sum: 1.413641129463765
# For controls...
# Control start and end: 2004-03-11 11:00:00 2004-03-11 22:59:59
# 42812.41030149328
# Control data: Sum then square: -1.3203014579821661
# Control data: Square then sum: -0.006536640395236612
# Control start and end: 2004-03-13 11:00:00 2004-03-13 22:59:59
# 43246.427136934115
# Control data: Sum then square: 0.16015962587434573
# Control data: Square then sum: 0.38452247489272307
# EVENT COUNT 151
# 170 Global Day of Peace 2004-03-20 00:00:00 2004-03-20 23:59:59 86400.0
# 85814.19125249104
# Event data: Sum then square: -1.410829788449906
# Event data: Square then sum: -0.017730856485012932
# For controls...
# Control start and end: 2004-03-18 00:00:00 2004-03-18 23:59:59
# 86882.86375343759
# Control data: Sum then square: 1.1610357660492476
# Control data: Square then sum: -0.018897982716391978
# Control start and end: 2004-03-22 00:00:00 2004-03-22 23:59:59
# 86538.31806197808
# Control data: Sum then square: 0.3341676840488445
# Control data: Square then sum: -0.01792539042108178
# EVENT COUNT 152
# 171 Cricket, India vs Pakistan 2004-03-24 09:00:00 2004-03-24 16:59:59 28800.0
# 29085.22505357903
# Event data: Sum then square: 1.1873124411503329
# Event data: Square then sum: -0.5868230476738776
# For controls...
# Control start and end: 2004-03-23 17:00:00 2004-03-24 00:59:59
# 28783.22905020075
# Control data: Sum then square: -0.06711460894373242
# Control data: Square then sum: -0.41534663398733157
# Control start and end: 2004-03-25 01:00:00 2004-03-25 08:59:59
# 28986.623788305336
# Control data: Sum then square: 0.77870211166339
# Control data: Square then sum: -1.3504445688828561
# EVENT COUNT 153
# 172 Rantisi Assassination 2004-04-17 17:00:00 2004-04-17 20:59:59 14400.0
# 14276.614725240976
# Event data: Sum then square: -0.7252105193247049
# Event data: Square then sum: -0.3183841749992917
# For controls...
# Control start and end: 2004-04-17 09:00:00 2004-04-17 12:59:59
# 14649.994226295774
# Control data: Sum then square: 1.4685884221353698
# Control data: Square then sum: 0.35330902187975066
# Control start and end: 2004-04-18 01:00:00 2004-04-18 04:59:59
# 14557.57533799781
# Control data: Sum then square: 0.929080999618867
# Control data: Square then sum: 0.09404988976854041
# EVENT COUNT 154
# 173 Korean Train Explosion 2004-04-22 03:00:00 2004-04-22 06:59:59 14400.0
# 14547.844709942641
# Event data: Sum then square: 0.8721445938339153
# Event data: Square then sum: -0.7596824911499295
# For controls...
# Control start and end: 2004-04-21 19:00:00 2004-04-21 22:59:59
# 14344.532504656614
# Control data: Sum then square: -0.3233363092053202
# Control data: Square then sum: -1.2664691780310042
# Control start and end: 2004-04-22 11:00:00 2004-04-22 14:59:59
# 14677.7019105037
# Control data: Sum then square: 1.6298940001777478
# Control data: Square then sum: 1.866790623030207
# EVENT COUNT 155
# 174 Floods in Haiti 2004-05-24 00:00:00 2004-05-24 23:59:59 86400.0
# 86620.64004998692
# Event data: Sum then square: 0.5319297339754531
# Event data: Square then sum: -0.018821689234062678
# For controls...
# Control start and end: 2004-05-22 00:00:00 2004-05-22 23:59:59
# 86189.44776134792
# Control data: Sum then square: -0.505317919591825
# Control data: Square then sum: -0.01787455026903679
# Control start and end: 2004-05-26 00:00:00 2004-05-26 23:59:59
# 85894.50061321008
# Control data: Sum then square: -1.216817682860852
# Control data: Square then sum: -0.018617263048601
# EVENT COUNT 156
# 175 Iraq Insurgency Bombs 2004-06-24 04:30:00 2004-06-24 08:29:59 14400.0
# 14545.44480284688
# Event data: Sum then square: 0.8580982211271158
# Event data: Square then sum: -0.6127301043039365
# For controls...
# Control start and end: 2004-06-23 20:30:00 2004-06-24 00:29:59
# 14517.508963918952
# Control data: Sum then square: 0.6944793607593597
# Control data: Square then sum: -0.14295828265043764
# Control start and end: 2004-06-24 12:30:00 2004-06-24 16:29:59
# 13719.219257432404
# Control data: Sum then square: -4.072614836228236
# Control data: Square then sum: 0.6744266980128126
# EVENT COUNT 157
# 176 Turkish Train Wreck 2004-07-22 04:15:00 2004-07-22 08:14:59 14400.0
# 14284.72963060854
# Event data: Sum then square: -0.6771270703694391
# Event data: Square then sum: 0.3428403634417992
# For controls...
# Control start and end: 2004-07-21 20:15:00 2004-07-22 00:14:59
# 14286.329440808906
# Control data: Sum then square: -0.667649826035717
# Control data: Square then sum: 0.07187271354814459
# Control start and end: 2004-07-22 12:15:00 2004-07-22 16:14:59
# 14086.255419793011
# Control data: Sum then square: -1.8584221789042026
# Control data: Square then sum: -0.461283396553673
# EVENT COUNT 158
# 177 Democratic Convention, Kerry 2004-07-30 02:00:00 2004-07-30 02:44:59 2700.0
# 2840.571704385341
# Event data: Sum then square: 1.8897471911598802
# Event data: Square then sum: -0.4232036589563899
# For controls...
# Control start and end: 2004-07-30 00:30:00 2004-07-30 01:14:59
# 2639.1722618268627
# Control data: Sum then square: -0.8249703159583432
# Control data: Square then sum: -0.9050723599347317
# Control start and end: 2004-07-30 03:30:00 2004-07-30 04:14:59
# 2585.6357714773108
# Control data: Sum then square: -1.5697281414551287
# Control data: Square then sum: 0.4572977879492623
# EVENT COUNT 159
# 178 Fire in Paraguay 2004-08-01 14:00:00 2004-08-01 17:59:59 14400.0
# 14458.603593146749
# Event data: Sum then square: 0.3487846911748455
# Event data: Square then sum: -0.1018750868976007
# For controls...
# Control start and end: 2004-08-01 06:00:00 2004-08-01 09:59:59
# 14203.191789914774
# Control data: Sum then square: -1.1610964622289077
# Control data: Square then sum: 0.09625752761700178
# Control start and end: 2004-08-01 22:00:00 2004-08-02 01:59:59
# 14466.280351223631
# Control data: Sum then square: 0.3938899738038927
# Control data: Square then sum: 1.00139330082289
# EVENT COUNT 160
# 179 Bob Morris Dies 2004-08-12 04:00:00 2004-08-12 19:59:59 57600.0
# 57841.57039324246
# Event data: Sum then square: 0.7127045382742965
# Event data: Square then sum: 0.5582984699222281
# For controls...
# Control start and end: 2004-08-10 20:00:00 2004-08-11 11:59:59
# 58273.87550756718
# Control data: Sum then square: 1.9796968023414818
# Control data: Square then sum: 0.9047951891514379
# Control start and end: 2004-08-13 12:00:00 2004-08-14 03:59:59
# 57806.00660385791
# Control data: Sum then square: 0.608194296000891
# Control data: Square then sum: -0.026577912273455892
# EVENT COUNT 161
# 180 Olympic Opening Athens 2004-08-13 18:00:00 2004-08-13 20:59:59 10800.0
# 10623.31925381865
# Event data: Sum then square: -1.204236672446306
# Event data: Square then sum: -0.08813092284530992
# For controls...
# Control start and end: 2004-08-13 12:00:00 2004-08-13 14:59:59
# 10976.136846143225
# Control data: Sum then square: 1.196535494134495
# Control data: Square then sum: -0.4722968788489601
# Control start and end: 2004-08-14 00:00:00 2004-08-14 02:59:59
# 10852.670401100168
# Control data: Sum then square: 0.36233002245492213
# Control data: Square then sum: 0.2810535318351455
# EVENT COUNT 162
# 181 Day of Murderous Violence 2004-08-31 00:00:00 2004-08-31 23:59:59 86400.0
# 87054.22244835233
# Event data: Sum then square: 1.5714624890065747
# Event data: Square then sum: -0.019615526967128937
# For controls...
# Control start and end: 2004-08-29 00:00:00 2004-08-29 23:59:59
# 86219.0687456511
# Control data: Sum then square: -0.43395311443967166
# Control data: Square then sum: -0.01919964419010595
# Control start and end: 2004-09-02 00:00:00 2004-09-02 23:59:59
# 86814.72689341722
# Control data: Sum then square: 0.9976891030251172
# Control data: Square then sum: -0.01906523111777426
# EVENT COUNT 163
# 182 Republican Convention, Bush 2004-09-03 02:09:59 2004-09-03 03:11:59 3721.0
# 3700.3884654853423
# Event data: Sum then square: -0.23163811829818967
# Event data: Square then sum: -1.5622336745902923
# For controls...
# Control start and end: 2004-09-03 00:05:57 2004-09-03 01:07:57
# 3781.7518853768483
# Control data: Sum then square: 0.7081517297845039
# Control data: Square then sum: -0.6654768884546645
# Control start and end: 2004-09-03 04:14:01 2004-09-03 05:16:01
# 3745.263719326813
# Control data: Sum then square: 0.28837777715880514
# Control data: Square then sum: -0.5124517784322765
# EVENT COUNT 164
# 183 Russian School Hostage Crisis 2004-09-03 05:00:00 2004-09-03 08:59:59 14400.0
# 14716.286286041488
# Event data: Sum then square: 1.85418303421014
# Event data: Square then sum: 1.568949743571296
# For controls...
# Control start and end: 2004-09-02 21:00:00 2004-09-03 00:59:59
# 14574.936179074439
# Control data: Sum then square: 1.0306008185593636
# Control data: Square then sum: 1.0724378967395929
# Control start and end: 2004-09-03 13:00:00 2004-09-03 16:59:59
# 14346.807457321902
# Control data: Sum then square: -0.30989724415341025
# Control data: Square then sum: -0.06153737816549516
# EVENT COUNT 165
# 184 Earthdance 2004 2004-09-18 22:50:00 2004-09-18 23:14:59 1500.0
# 1414.7767306983326
# Event data: Sum then square: -1.5742106741648703
# Event data: Square then sum: -0.6555517507093493
# For controls...
# Control start and end: 2004-09-18 22:00:00 2004-09-18 22:24:59
# 1519.5830031184807
# Control data: Sum then square: 0.36814973050146127
# Control data: Square then sum: -1.6797174183123005
# Control start and end: 2004-09-18 23:40:00 2004-09-19 00:04:59
# 1455.2685300897035
# Control data: Sum then square: -0.8127409317990012
# Control data: Square then sum: -1.0211011329495772
# EVENT COUNT 166
# 185 Intnl Day Peace + Hurricane Haiti 2004-09-21 00:00:00 2004-09-21 23:59:59 86400.0
# 85775.1564890614
# Event data: Sum then square: -1.505174077056176
# Event data: Square then sum: -0.01931114264459842
# For controls...
# Control start and end: 2004-09-19 00:00:00 2004-09-19 23:59:59
# 85923.05583530899
# Control data: Sum then square: -1.1478628692940185
# Control data: Square then sum: -0.018623752651517615
# Control start and end: 2004-09-23 00:00:00 2004-09-23 23:59:59
# 86974.17808421969
# Control data: Sum then square: 1.3798127171395655
# Control data: Square then sum: -0.018859444026576664
# EVENT COUNT 167
# 186 Bombing in Taba, Egypt 2004-10-07 19:00:00 2004-10-07 22:59:59 14400.0
# 14624.218847677183
# Event data: Sum then square: 1.3183496864485362
# Event data: Square then sum: 0.5980615645155808
# For controls...
# Control start and end: 2004-10-07 11:00:00 2004-10-07 14:59:59
# 14240.555820710062
# Control data: Sum then square: -0.9390920533814002
# Control data: Square then sum: -1.7794615886371166
# Control start and end: 2004-10-08 03:00:00 2004-10-08 06:59:59
# 14474.79764935396
# Control data: Sum then square: 0.4439152406623238
# Control data: Square then sum: -0.45305728387439326
# EVENT COUNT 168
# 187 US Election 2004 2004-11-02 11:00:00 2004-11-03 05:59:59 68400.0
# 67954.81746392458
# Event data: Sum then square: -1.2044535402383154
# Event data: Square then sum: -0.14222866083073307
# For controls...
# Control start and end: 2004-10-31 21:00:00 2004-11-01 15:59:59
# 69289.79053059695
# Control data: Sum then square: 2.3971653375636848
# Control data: Square then sum: 0.021290351456006086
# Control start and end: 2004-11-04 01:00:00 2004-11-04 19:59:59
# 68302.97524381445
# Control data: Sum then square: -0.2606463604271389
# Control data: Square then sum: -0.5223699802408306
# EVENT COUNT 169
# 188 Arafat Dies 2004-11-11 02:30:00 2004-11-11 14:29:59 43200.0
# 43633.01256102374
# Event data: Sum then square: 1.4705114162490702
# Event data: Square then sum: 0.8058875533683882
# For controls...
# Control start and end: 2004-11-10 02:30:00 2004-11-10 14:29:59
# 43343.2816076064
# Control data: Sum then square: 0.48918347718364036
# Control data: Square then sum: -0.12310793590352435
# Control start and end: 2004-11-12 02:30:00 2004-11-12 14:29:59
# 42897.160760172526
# Control data: Sum then square: -1.030428011361226
# Control data: Square then sum: 0.030252657956187895
# EVENT COUNT 170
# 189 Tsunami Indian Ocean 2004-12-26 00:29:00 2004-12-26 08:28:59 28800.0
# 28858.058904915357
# Event data: Sum then square: 0.24452705114873502
# Event data: Square then sum: 0.8059658818408578
# For controls...
# Control start and end: 2004-12-25 08:29:00 2004-12-25 16:28:59
# 28695.79175673752
# Control data: Sum then square: -0.43194719669740167
# Control data: Square then sum: -0.5001077335610864
# Control start and end: 2004-12-26 16:29:00 2004-12-27 00:28:59
# 29106.683336061742
# Control data: Sum then square: 1.2761147122161507
# Control data: Square then sum: -0.9658074483012358
# EVENT COUNT 171
# 190 New Year Mean 2004-2005 2004-12-31 09:30:00 2005-01-01 12:29:59 97200.0
# 97910.88617607372
# Event data: Sum then square: 1.609919734913607
# Event data: Square then sum: 0.08538458387535587
# For controls...
# Control start and end: 2004-12-29 03:30:00 2004-12-30 06:29:59
# 96961.30509929982
# Control data: Sum then square: -0.5403024732863381
# Control data: Square then sum: 0.2164217989625057
# Control start and end: 2005-01-02 15:30:00 2005-01-03 18:29:59
# 96110.07809139999
# Control data: Sum then square: -2.4797801924966105
# Control data: Square then sum: 0.04240322119767995
# EVENT COUNT 172
# 192 Elections in Iraq 2005-01-30 04:00:00 2005-01-30 15:59:59 43200.0
# 43714.890415314374
# Event data: Sum then square: 1.7470472226508105
# Event data: Square then sum: -0.12774911768599703
# For controls...
# Control start and end: 2005-01-29 04:00:00 2005-01-29 15:59:59
# 43233.76360444481
# Control data: Sum then square: 0.11710410438516057
# Control data: Square then sum: 0.2299210166735868
# Control start and end: 2005-01-31 04:00:00 2005-01-31 15:59:59
# 43718.18003831443
# Control data: Sum then square: 1.7581504460577637
# Control data: Square then sum: -0.293810577613963
# EVENT COUNT 173
# 193 Hariri Assassination Beirut 2005-02-14 09:00:00 2005-02-14 12:59:59 14400.0
# 14407.362640277763
# Event data: Sum then square: 0.04730559876204495
# Event data: Square then sum: -0.16583732679783084
# For controls...
# Control start and end: 2005-02-14 01:00:00 2005-02-14 04:59:59
# 14407.564058445818
# Control data: Sum then square: 0.04849205221485016
# Control data: Square then sum: 2.078446787606934
# Control start and end: 2005-02-14 17:00:00 2005-02-14 20:59:59
# 14440.487023482043
# Control data: Sum then square: 0.24227631466462285
# Control data: Square then sum: -0.2143262196634841
# EVENT COUNT 174
# 194 Siyum Daf Yomi 2005-03-01 22:45:00 2005-03-02 01:59:59 11700.0
# 11673.98073576116
# Event data: Sum then square: -0.16586054109170922
# Event data: Square then sum: -0.21121227370104564
# For controls...
# Control start and end: 2005-03-01 16:15:00 2005-03-01 19:29:59
# 11863.707970804942
# Control data: Sum then square: 1.069594501512616
# Control data: Square then sum: 0.7274712238278154
# Control start and end: 2005-03-02 05:15:00 2005-03-02 08:29:59
# 11479.25791933362
# Control data: Sum then square: -1.4478474642459493
# Control data: Square then sum: 0.7314747362731235
# EVENT COUNT 175
# 195 Quake, Indian Ocean 2005-03-28 16:00:00 2005-03-28 23:59:59 28800.0
# 28875.349200777484
# Event data: Sum then square: 0.31645879835166174
# Event data: Square then sum: -0.3920160719394494
# For controls...
# Control start and end: 2005-03-28 00:00:00 2005-03-28 07:59:59
# 28792.683565008047
# Control data: Sum then square: -0.027709886461896146
# Control data: Square then sum: -0.47371314285164257
# Control start and end: 2005-03-29 08:00:00 2005-03-29 15:59:59
# 28828.305318464234
# Control data: Sum then square: 0.12067776637223325
# Control data: Square then sum: -0.08247497194981662
# EVENT COUNT 176
# 196 Pope John Paul Dies 2005-04-02 04:00:00 2005-04-02 23:59:59 72000.0
# 72101.55371243622
# Event data: Sum then square: 0.26924842722718795
# Event data: Square then sum: 0.1850088942354902
# For controls...
# Control start and end: 2005-03-31 12:00:00 2005-04-01 07:59:59
# 71878.32948420939
# Control data: Sum then square: -0.31905367773978743
# Control data: Square then sum: 0.8849440193909421
# Control start and end: 2005-04-03 20:00:00 2005-04-04 15:59:59
# 71731.38878340395
# Control data: Sum then square: -0.7069775243798314
# Control data: Square then sum: 0.025098036966555003
# EVENT COUNT 177
# 197 Pope Paul's Funeral 2005-04-08 08:00:00 2005-04-08 12:29:59 16200.0
# 16548.52850497423
# Event data: Sum then square: 1.926252588437351
# Event data: Square then sum: 0.7250695122760666
# For controls...
# Control start and end: 2005-04-07 23:00:00 2005-04-08 03:29:59
# 16320.975476799358
# Control data: Sum then square: 0.6741216861008923
# Control data: Square then sum: 0.8447816629201507
# Control start and end: 2005-04-08 17:00:00 2005-04-08 21:29:59
# 15887.342859679336
# Control data: Sum then square: -1.7445764192668665
# Control data: Square then sum: 0.6999441157784689
# EVENT COUNT 178
# 198 Prince Charles' Wedding 2005-04-09 11:00:00 2005-04-09 14:59:59 14400.0
# 14717.877674404881
# Event data: Sum then square: 1.8634252867867103
# Event data: Square then sum: -1.6367446291649246
# For controls...
# Control start and end: 2005-04-09 03:00:00 2005-04-09 06:59:59
# 14189.81460564681
# Control data: Sum then square: -1.240673907523406
# Control data: Square then sum: 0.79010139715221
# Control start and end: 2005-04-09 19:00:00 2005-04-09 22:59:59
# 14460.749794239173
# Control data: Sum then square: 0.3613964397745576
# Control data: Square then sum: 0.6288353735058057
# EVENT COUNT 179
# 199 Oraworld Resonance 2005-04-23 00:50:00 2005-04-23 14:44:59 50100.0
# 50756.779088793526
# Event data: Sum then square: 2.0679499032534387
# Event data: Square then sum: 0.27066597231517947
# For controls...
# Control start and end: 2005-04-21 21:00:00 2005-04-22 10:54:59
# 50318.05133217581
# Control data: Sum then square: 0.6899588329324704
# Control data: Square then sum: 0.6957511357142406
# Control start and end: 2005-04-24 04:40:00 2005-04-24 18:34:59
# 50718.944961765446
# Control data: Sum then square: 1.949430799422932
# Control data: Square then sum: 0.1748237286910045
# EVENT COUNT 180
# 200 Live 8 Concert 2005-07-02 00:00:00 2005-07-02 23:59:59 86400.0
# Before masking, fraction of nans in raw data is 0.09175617283950617 for 2005-07-02 00:00:00 to 2005-07-02 23:59:59
# Found 'rotten egg' entries for device id: 1026 in time range 2005-07-02 00:00:00 to 2005-07-02 23:59:59 (range: 2005-07-02 00:00:00 to 2005-07-04 23:59:59 )
# After masking, fraction of nans in raw data is 0.0963804012345679
# 85746.61897253961
# Event data: Sum then square: -1.5741653796774115
# Event data: Square then sum: -0.018404622392967255
# For controls...
# Control start and end: 2005-06-30 00:00:00 2005-06-30 23:59:59
# 86149.1923095591
# Control data: Sum then square: -0.60233019671532
# Control data: Square then sum: -0.01871908544060875
# Control start and end: 2005-07-04 00:00:00 2005-07-04 23:59:59
# Before masking, fraction of nans in raw data is 0.07662615740740741 for 2005-07-04 00:00:00 to 2005-07-04 23:59:59
# Found 'rotten egg' entries for device id: 1026 in time range 2005-07-04 00:00:00 to 2005-07-04 23:59:59 (range: 2005-07-02 00:00:00 to 2005-07-04 23:59:59 )
# After masking, fraction of nans in raw data is 0.07821813512731482
# 85585.6536521504
# Control data: Sum then square: -1.9635966587501303
# Control data: Square then sum: -0.0188965765017356
# EVENT COUNT 181
# 201 London Subway Bombs 2005-07-07 00:00:00 2005-07-07 23:59:59 86400.0
# 86400.12842335309
# Event data: Sum then square: 0.0019126898625656094
# Event data: Square then sum: -0.019376224522773017
# For controls...
# Control start and end: 2005-07-05 00:00:00 2005-07-05 23:59:59
# 86460.14447376231
# Control data: Sum then square: 0.14625521683843423
# Control data: Square then sum: -0.019273616049951547
# Control start and end: 2005-07-09 00:00:00 2005-07-09 23:59:59
# 87110.55307755414
# Control data: Sum then square: 1.7062642249538982
# Control data: Square then sum: -0.018879614064345584
# EVENT COUNT 182
# 202 Hurricane Katrina 2005-08-29 10:00:00 2005-08-29 23:59:59 50400.0
# 50058.76786016084
# Event data: Sum then square: -1.0751144413999576
# Event data: Square then sum: -0.6182794018741327
# For controls...
# Control start and end: 2005-08-28 06:00:00 2005-08-28 19:59:59
# 49968.3297534964
# Control data: Sum then square: -1.3614333813683237
# Control data: Square then sum: 0.4005455123794476
# Control start and end: 2005-08-30 14:00:00 2005-08-31 03:59:59
# 50186.292162121346
# Control data: Sum then square: -0.6719696225342782
# Control data: Square then sum: 0.015586928358037705
# EVENT COUNT 183
# 203 Baghdad Bridge Stampede 2005-08-31 08:00:00 2005-08-31 12:59:59 18000.0
# 18454.246401771583
# Event data: Sum then square: 2.3777474249015937
# Event data: Square then sum: -3.5572251279057405
# For controls...
# Control start and end: 2005-08-30 22:00:00 2005-08-31 02:59:59
# 17966.65685186918
# Control data: Sum then square: -0.17232825382963154
# Control data: Square then sum: 0.6271917197937982
# Control start and end: 2005-08-31 18:00:00 2005-08-31 22:59:59
# 18003.94032198458
# Control data: Sum then square: 0.02427939228519257
# Control data: Square then sum: 2.4973352033306178
# EVENT COUNT 184
# 204 End the War Rally 2005-09-24 13:00:00 2005-09-24 19:59:59 25200.0
# 25605.448402899714
# Event data: Sum then square: 1.7993804721826399
# Event data: Square then sum: 0.9737447307784687
# For controls...
# Control start and end: 2005-09-23 23:00:00 2005-09-24 05:59:59
# 25172.690235366208
# Control data: Sum then square: -0.11872148863437912
# Control data: Square then sum: -0.23418668757037145
# Control start and end: 2005-09-25 03:00:00 2005-09-25 09:59:59
# 25660.1309199792
# Control data: Sum then square: 2.04020773052686
# Control data: Square then sum: 0.6475495389309689
# EVENT COUNT 185
# 205 Bali Bombing 2 2005-10-01 11:30:00 2005-10-01 17:29:59 21600.0
# 21995.082448370067
# Event data: Sum then square: 1.8925767296528544
# Event data: Square then sum: 0.16372925124885387
# For controls...
# Control start and end: 2005-09-30 23:30:00 2005-10-01 05:29:59
# 21922.4594104286
# Control data: Sum then square: 1.5469833566578264
# Control data: Square then sum: 0.5213444839298773
# Control start and end: 2005-10-01 23:30:00 2005-10-02 05:29:59
# 21763.15316687512
# Control data: Sum then square: 0.7862088005959939
# Control data: Square then sum: 2.2875502791797766
# EVENT COUNT 186
# 206 Earthquake Pakistan 2005-10-08 03:20:00 2005-10-08 11:19:59 28800.0
# 29099.812925276176
# Event data: Sum then square: 1.2476871708888901
# Event data: Square then sum: 0.18841733719940884
# For controls...
# Control start and end: 2005-10-07 11:20:00 2005-10-07 19:19:59
# 28989.106713122063
# Control data: Sum then square: 0.7890028772061298
# Control data: Square then sum: -0.28937237411922984
# Control start and end: 2005-10-08 19:20:00 2005-10-09 03:19:59
# 28523.140111319834
# Control data: Sum then square: -1.154520261074202
# Control data: Square then sum: 0.0028643170964064123
# EVENT COUNT 187
# 207 India Train Crash 2005-10-28 21:30:00 2005-10-29 02:29:59 18000.0
# 18076.976054744133
# Event data: Sum then square: 0.40863495219303947
# Event data: Square then sum: -0.04601021589386452
# For controls...
# Control start and end: 2005-10-28 11:30:00 2005-10-28 16:29:59
# 17841.92924420578
# Control data: Sum then square: -0.8320410709454448
# Control data: Square then sum: -1.5620375944657028
# Control start and end: 2005-10-29 07:30:00 2005-10-29 12:29:59
# 18250.495119381452
# Control data: Sum then square: 1.3176597754890973
# Control data: Square then sum: 1.1398572677466028
# EVENT COUNT 188
# 208 India Bombs 2005-10-29 11:08:00 2005-10-29 16:07:59 18000.0
# 18064.694146962138
# Event data: Sum then square: 0.3440730538320511
# Event data: Square then sum: 0.9184865576414212
# For controls...
# Control start and end: 2005-10-29 01:08:00 2005-10-29 06:07:59
# 17755.62832667535
# Control data: Sum then square: -1.2903092598948618
# Control data: Square then sum: -0.444959749447539
# Control start and end: 2005-10-29 21:08:00 2005-10-30 02:07:59
# 17946.281976544626
# Control data: Sum then square: -0.27988644844023586
# Control data: Square then sum: -0.11511036087780364
# EVENT COUNT 189
# 209 Jordan Bombs 2005-11-09 18:00:00 2005-11-09 22:59:59 18000.0
# 18313.918964588076
# Event data: Sum then square: 1.6484853462213152
# Event data: Square then sum: -0.004435842456161146
# For controls...
# Control start and end: 2005-11-09 08:00:00 2005-11-09 12:59:59
# 18257.09817550072
# Control data: Sum then square: 1.352137687878114
# Control data: Square then sum: 0.7317907051989698
# Control start and end: 2005-11-10 04:00:00 2005-11-10 08:59:59
# 17959.936545703265
# Control data: Sum then square: -0.2077955022151388
# Control data: Square then sum: -2.3094176927204724
# EVENT COUNT 190
# 211 New Year Covar Min 2005-12-31 23:55:00 2006-01-01 00:04:59 600.0
# 542.9557018368253
# Event data: Sum then square: -1.6826107888170116
# Event data: Square then sum: 0.8561763318130585
# For controls...
# Control start and end: 2005-12-31 23:35:00 2005-12-31 23:44:59
# 595.4292516510563
# Control data: Sum then square: -0.11302389509453589
# Control data: Square then sum: -1.3508692034372771
# Control start and end: 2006-01-01 00:15:00 2006-01-01 00:24:59
# 587.9773673686027
# Control data: Sum then square: -0.3301302324082499
# Control data: Square then sum: -0.3092924425244224
# EVENT COUNT 191
# 212 Hadj Stoning 2006 2006-01-12 08:00:00 2006-01-12 11:59:59 14400.0
# 14591.617048754486
# Event data: Sum then square: 1.128068576975612
# Event data: Square then sum: 0.650122034637748
# For controls...
# Control start and end: 2006-01-12 00:00:00 2006-01-12 03:59:59
# 14513.029856107776
# Control data: Sum then square: 0.6682259363825008
# Control data: Square then sum: -0.9235116764075759
# Control start and end: 2006-01-12 16:00:00 2006-01-12 19:59:59
# 14516.671890567455
# Control data: Sum then square: 0.6895734272175428
# Control data: Square then sum: 1.185110324752264
# EVENT COUNT 192
# 213 Mudslide, Philippines 2006-02-17 00:00:00 2006-02-17 23:59:59 86400.0
# 86956.53942597477
# Event data: Sum then square: 1.337564776493618
# Event data: Square then sum: -0.01816085637143153
# For controls...
# Control start and end: 2006-02-15 00:00:00 2006-02-15 23:59:59
# 86721.02166443077
# Control data: Sum then square: 0.7729069758707366
# Control data: Square then sum: -0.01826438595607987
# Control start and end: 2006-02-19 00:00:00 2006-02-19 23:59:59
# 86235.62079638115
# Control data: Sum then square: -0.394081955226947
# Control data: Square then sum: -0.01783587315798915
# EVENT COUNT 193
# 214 Golden Dome Bomb 2006-02-22 03:00:00 2006-02-22 06:59:59 14400.0
# 14279.092727270036
# Event data: Sum then square: -0.7105256194091839
# Event data: Square then sum: 1.035367291483224
# For controls...
# Control start and end: 2006-02-21 19:00:00 2006-02-21 22:59:59
# 14411.148189426269
# Control data: Sum then square: 0.06960252229336386
# Control data: Square then sum: 0.4991854502792451
# Control start and end: 2006-02-22 11:00:00 2006-02-22 14:59:59
# 14275.209893236504
# Control data: Sum then square: -0.7335364564110286
# Control data: Square then sum: -0.31538946126113065
# EVENT COUNT 194
# 215 Planetary Play 2006-04-01 17:45:00 2006-04-01 18:14:59 1800.0
# 1798.207752672586
# Event data: Sum then square: -0.018768378320718086
# Event data: Square then sum: 0.3740979199495634
# For controls...
# Control start and end: 2006-04-01 16:45:00 2006-04-01 17:14:59
# 1847.651824343695
# Control data: Sum then square: 0.7983821234787993
# Control data: Square then sum: 1.1118115763851613
# Control start and end: 2006-04-01 18:45:00 2006-04-01 19:14:59
# 1814.0792204012314
# Control data: Sum then square: 0.24514883010996477
# Control data: Square then sum: 0.9824126819171843
# EVENT COUNT 195
# 216 Earth Day, 2006 2006-04-22 00:00:00 2006-04-22 23:59:59 86400.0
# 86818.01515293602
# Event data: Sum then square: 1.0055741138278251
# Event data: Square then sum: -0.018506907258872708
# For controls...
# Control start and end: 2006-04-20 00:00:00 2006-04-20 23:59:59
# 86448.38688701863
# Control data: Sum then square: 0.11798271382227796
# Control data: Square then sum: -0.019380046920476474
# Control start and end: 2006-04-24 00:00:00 2006-04-24 23:59:59
# 86496.22665068037
# Control data: Sum then square: 0.233003065379997
# Control data: Square then sum: -0.018885695624590734
# EVENT COUNT 196
# 217 Indonesian Earthquake 2006-05-26 21:54:00 2006-05-27 05:53:59 28800.0
# Before masking, fraction of nans in raw data is 0.07204469373219373 for 2006-05-27 00:00:00 to 2006-05-27 23:59:59
# Found 'rotten egg' entries for device id: 161 in time range 2006-05-27 00:00:00 to 2006-05-27 23:59:59 (range: 2006-05-01 00:00:00 to 2006-05-31 23:59:59 )
# After masking, fraction of nans in raw data is 0.08107247150997152
# 29451.696803341154
# Event data: Sum then square: 2.697960393496802
# Event data: Square then sum: 0.8404529646606079
# For controls...
# Control start and end: 2006-05-26 05:54:00 2006-05-26 13:53:59
# 29088.067981914504
# Control data: Sum then square: 1.199080032327445
# Control data: Square then sum: 0.6444885060570299
# Control start and end: 2006-05-27 13:54:00 2006-05-27 21:53:59
# Before masking, fraction of nans in raw data is 0.07204469373219373 for 2006-05-27 00:00:00 to 2006-05-27 23:59:59
# Found 'rotten egg' entries for device id: 161 in time range 2006-05-27 00:00:00 to 2006-05-27 23:59:59 (range: 2006-05-01 00:00:00 to 2006-05-31 23:59:59 )
# After masking, fraction of nans in raw data is 0.08107247150997152
# 28834.459308392772
# Control data: Sum then square: 0.1463007322799235
# Control data: Square then sum: -0.5116649639208544
# EVENT COUNT 197
# 218 Zarkawi News Release 2006-06-08 07:00:00 2006-06-08 14:59:59 28800.0
# 28535.387268066683
# Event data: Sum then square: -1.1031680800202577
# Event data: Square then sum: -0.7044448519437339
# For controls...
# Control start and end: 2006-06-07 15:00:00 2006-06-07 22:59:59
# 29147.489588962075
# Control data: Sum then square: 1.4448657730555978
# Control data: Square then sum: 0.10417676184428896
# Control start and end: 2006-06-08 23:00:00 2006-06-09 06:59:59
# 28712.228809965927
# Control data: Sum then square: -0.363306982388251
# Control data: Square then sum: 0.29328351651433454
# EVENT COUNT 198
# 219 Bombay Train Bombings 2006-07-11 11:24:00 2006-07-11 16:23:59 18000.0
# 18158.958424239132
# Event data: Sum then square: 0.8388419910762236
# Event data: Square then sum: -0.5672614887308814
# For controls...
# Control start and end: 2006-07-11 01:24:00 2006-07-11 06:23:59
# 17981.159494548796
# Control data: Sum then square: -0.09581889080696274
# Control data: Square then sum: 0.1937700936484479
# Control start and end: 2006-07-11 21:24:00 2006-07-12 02:23:59
# 17794.757954534518
# Control data: Sum then square: -1.0823425024203222
# Control data: Square then sum: -0.19752490320965915
# EVENT COUNT 199
# 220 Avebury Meditations 2006-07-22 22:00:00 2006-07-22 22:59:59 3600.0
# 3693.969648740818
# Event data: Sum then square: 1.1057911914108354
# Event data: Square then sum: -0.4072690998304182
# For controls...
# Control start and end: 2006-07-22 20:00:00 2006-07-22 20:59:59
# 3484.139540878785
# Control data: Sum then square: -1.3724798525610673
# Control data: Square then sum: 1.0778101432086034
# Control start and end: 2006-07-23 00:00:00 2006-07-23 00:59:59
# 3540.3594946967723
# Control data: Sum then square: -0.6989217314686794
# Control data: Square then sum: 1.4224770603145034
# EVENT COUNT 200
# 221 Qana Lebanon 2006-07-30 01:00:00 2006-07-30 05:59:59 18000.0
# 18284.46483616449
# Event data: Sum then square: 1.4949444827828287
# Event data: Square then sum: 0.42349132414501117
# For controls...
# Control start and end: 2006-07-29 15:00:00 2006-07-29 19:59:59
# 17923.64898094923
# Control data: Sum then square: -0.39946068407823154
# Control data: Square then sum: 0.7832857897113262
# Control start and end: 2006-07-30 11:00:00 2006-07-30 15:59:59
# 18105.961740937157
# Control data: Sum then square: 0.5608872336838291
# Control data: Square then sum: 0.4808029018183855
# EVENT COUNT 201
# 222 British Terror Plot 2006-08-10 00:00:00 2006-08-10 23:59:59 86400.0
# 87012.42233757263
# Event data: Sum then square: 1.4713953724134097
# Event data: Square then sum: -0.01844646042119632
# For controls...
# Control start and end: 2006-08-08 00:00:00 2006-08-08 23:59:59
# 86257.05624926822
# Control data: Sum then square: -0.3424550682235375
# Control data: Square then sum: -0.018265295366539463
# Control start and end: 2006-08-12 00:00:00 2006-08-12 23:59:59
# 86129.59220052682
# Control data: Sum then square: -0.6495757649006776
# Control data: Square then sum: -0.018302108701581086
# EVENT COUNT 202
# 224 Oraworld Reconciliation 2006-10-02 12:00:00 2006-10-02 23:59:59 43200.0
# 43183.067685435286
# Event data: Sum then square: -0.055344309115469566
# Event data: Square then sum: 1.2052518542070283
# For controls...
# Control start and end: 2006-10-01 12:00:00 2006-10-01 23:59:59
# 43254.98447279144
# Control data: Sum then square: 0.18924947911868412
# Control data: Square then sum: 0.7544505393350848
# Control start and end: 2006-10-03 12:00:00 2006-10-03 23:59:59
# 43251.57608884767
# Control data: Sum then square: 0.17766346026143065
# Control data: Square then sum: 0.14975734006347974
# EVENT COUNT 203
# 225 Native American Earth Ceremony 2006-10-07 03:00:00 2006-10-07 03:14:59 900.0
# 925.093948638852
# Event data: Sum then square: 0.6017387330713562
# Event data: Square then sum: 0.8381440192545885
# For controls...
# Control start and end: 2006-10-07 02:30:00 2006-10-07 02:44:59
# 887.9613277071353
# Control data: Sum then square: -0.269297477680758
# Control data: Square then sum: 2.5166246194715116
# Control start and end: 2006-10-07 03:30:00 2006-10-07 03:44:59
# 878.2099519924182
# Control data: Sum then square: -0.5020545614450946
# Control data: Square then sum: -0.8238923216322345
# EVENT COUNT 204
# 226 Election 2006 Results 2006-11-08 13:00:00 2006-11-08 20:59:59 28800.0
# 29123.345708751425
# Event data: Sum then square: 1.345039671200219
# Event data: Square then sum: -0.3629942931654439
# For controls...
# Control start and end: 2006-11-07 21:00:00 2006-11-08 04:59:59
# 28619.88115893467
# Control data: Sum then square: -0.7492862348921905
# Control data: Square then sum: -0.07891190731925293
# Control start and end: 2006-11-09 05:00:00 2006-11-09 12:59:59
# 28783.663196727954
# Control data: Sum then square: -0.06530497505017886
# Control data: Square then sum: 0.43075217848134933
# EVENT COUNT 205
# 227 Gemayel Assassination 2006-11-21 10:00:00 2006-11-21 13:59:59 14400.0
# 14228.285974204133
# Event data: Sum then square: -1.0119524112714904
# Event data: Square then sum: -0.18159701877014023
# For controls...
# Control start and end: 2006-11-21 02:00:00 2006-11-21 05:59:59
# 14622.798559521925
# Control data: Sum then square: 1.3100660313421897
# Control data: Square then sum: 0.4295586238059319
# Control start and end: 2006-11-21 18:00:00 2006-11-21 21:59:59
# 14212.632568599005
# Control data: Sum then square: -1.1049657909472685
# Control data: Square then sum: 0.5028511187352095
# EVENT COUNT 206
# 228 Global Deeksha 2006-11-23 16:30:00 2006-11-23 17:29:59 3600.0
# 3586.675360624795
# Event data: Sum then square: -0.14936726804221062
# Event data: Square then sum: -0.4198353659444598
# For controls...
# Control start and end: 2006-11-23 14:30:00 2006-11-23 15:29:59
# 3598.370139290975
# Control data: Sum then square: -0.011353848669307937
# Control data: Square then sum: 0.13974698141565473
# Control start and end: 2006-11-23 18:30:00 2006-11-23 19:29:59
# 3567.037309323328
# Control data: Sum then square: -0.3817981963942364
# Control data: Square then sum: -0.5372986093201476
# EVENT COUNT 207
# 229 Global Orgasm 2006-12-22 00:00:00 2006-12-22 23:59:59 86400.0
# 86646.34181448873
# Event data: Sum then square: 0.5936474008168093
# Event data: Square then sum: -0.01918283201275745
# For controls...
# Control start and end: 2006-12-20 00:00:00 2006-12-20 23:59:59
# 86587.81468806631
# Control data: Sum then square: 0.4530884153904353
# Control data: Square then sum: -0.019144200801041605
# Control start and end: 2006-12-24 00:00:00 2006-12-24 23:59:59
# 86129.86004989334
# Control data: Sum then square: -0.6489300724463472
# Control data: Square then sum: -0.019383170970612082
# EVENT COUNT 208
# 230 Saddam's Execution 2006-12-30 03:00:00 2006-12-30 16:59:59 50400.0
# 50427.952804222485
# Event data: Sum then square: 0.09012649371997389
# Event data: Square then sum: -0.5663593343509821
# For controls...
# Control start and end: 2006-12-28 23:00:00 2006-12-29 12:59:59
# 50477.1381068418
# Control data: Sum then square: 0.24493789400026766
# Control data: Square then sum: -0.9021012223692889
# Control start and end: 2006-12-31 07:00:00 2006-12-31 20:59:59
# 50119.33114004057
# Control data: Sum then square: -0.8835693769966501
# Control data: Square then sum: -0.4323123281623024
# EVENT COUNT 209
# 231 New Year Mean 2006-2007 2006-12-31 09:30:00 2007-01-01 12:29:59 97200.0
# 97133.4514591926
# Event data: Sum then square: -0.1494574978838885
# Event data: Square then sum: -0.5378288571926548
# For controls...
# Control start and end: 2006-12-29 03:30:00 2006-12-30 06:29:59
# 96991.05085472208
# Control data: Sum then square: -0.47273399195792837
# Control data: Square then sum: -0.41426802833663934
# Control start and end: 2007-01-02 15:30:00 2007-01-03 18:29:59
# 96409.05550834119
# Control data: Sum then square: -1.7972745290843004
# Control data: Square then sum: 0.34264600533872236
# EVENT COUNT 210
# 233 European Storms 2007-01-18 00:00:00 2007-01-18 23:59:59 86400.0
# 86991.3635330612
# Event data: Sum then square: 1.420969644713302
# Event data: Square then sum: -0.01842348081777463
# For controls...
# Control start and end: 2007-01-16 00:00:00 2007-01-16 23:59:59
# 86376.1351624502
# Control data: Sum then square: -0.055811374682965736
# Control data: Square then sum: -0.018907901553569407
# Control start and end: 2007-01-20 00:00:00 2007-01-20 23:59:59
# 86698.36727897292
# Control data: Sum then square: 0.7185388514812423
# Control data: Square then sum: -0.018262796856008897
# EVENT COUNT 211
# 234 Iraq Worst Bombing 2007-02-03 16:00:00 2007-02-03 20:59:59 18000.0
# 18139.51156693187
# Event data: Sum then square: 0.7369107911119519
# Event data: Square then sum: -0.7221443926526591
# For controls...
# Control start and end: 2007-02-03 06:00:00 2007-02-03 10:59:59
# 18130.2493946383
# Control data: Sum then square: 0.6883372819187749
# Control data: Square then sum: -0.7048735599542352
# Control start and end: 2007-02-04 02:00:00 2007-02-04 06:59:59
# 18081.101390498887
# Control data: Sum then square: 0.4303139094584535
# Control data: Square then sum: 0.36567226451677093
# EVENT COUNT 212
# 235 World Sound Healing 2007-02-14 00:00:00 2007-02-14 23:59:59 86400.0
# 86403.19384986123
# ...
# Found 'rotten egg' entries for device id: 1251 in time range 2014-09-19 00:00:00 to 2014-09-19 23:59:59 (range: 2014-03-14 00:00:00 to 2024-02-13 20:06:50 )
# After masking, fraction of nans in raw data is 0.06983311800172265
# 85917.48423229529
# Control data: Sum then square: -1.161315910217605
# Control data: Square then sum: -0.014961526887114626
# Control start and end: 2014-09-23 00:00:00 2014-09-23 23:59:59
# Before masking, fraction of nans in raw data is 0.029715057319223987 for 2014-09-23 00:00:00 to 2014-09-23 23:59:59
# Found 'rotten egg' entries for device id: 1251 in time range 2014-09-23 00:00:00 to 2014-09-23 23:59:59 (range: 2014-03-14 00:00:00 to 2024-02-13 20:06:50 )
# After masking, fraction of nans in raw data is 0.0535245811287478
# 86677.84998349505
# Control data: Sum then square: 0.6692913453749035
# Control data: Square then sum: -0.015007601074621716
# EVENT COUNT 457
# 488 Ottowa Terror Shooting 2014-09-22 14:00:00 2014-09-22 19:59:59 21600.0
# Before masking, fraction of nans in raw data is 0.033093584656084654 for 2014-09-22 00:00:00 to 2014-09-22 23:59:59
# Found 'rotten egg' entries for device id: 1251 in time range 2014-09-22 00:00:00 to 2014-09-22 23:59:59 (range: 2014-03-14 00:00:00 to 2024-02-13 20:06:50 )
# After masking, fraction of nans in raw data is 0.05690310846560846
# 21548.00097564776
# Event data: Sum then square: -0.24717331066957998
# Event data: Square then sum: -0.7142235514321048
# For controls...
# Control start and end: 2014-09-22 02:00:00 2014-09-22 07:59:59
# Before masking, fraction of nans in raw data is 0.033093584656084654 for 2014-09-22 00:00:00 to 2014-09-22 23:59:59
# Found 'rotten egg' entries for device id: 1251 in time range 2014-09-22 00:00:00 to 2014-09-22 23:59:59 (range: 2014-03-14 00:00:00 to 2024-02-13 20:06:50 )
# After masking, fraction of nans in raw data is 0.05690310846560846
# 21845.587432449094
# Control data: Sum then square: 1.1803389167876812
# Control data: Square then sum: 0.26880667537402125
# Control start and end: 2014-09-23 02:00:00 2014-09-23 07:59:59
# Before masking, fraction of nans in raw data is 0.029715057319223987 for 2014-09-23 00:00:00 to 2014-09-23 23:59:59
# Found 'rotten egg' entries for device id: 1251 in time range 2014-09-23 00:00:00 to 2014-09-23 23:59:59 (range: 2014-03-14 00:00:00 to 2024-02-13 20:06:50 )
# After masking, fraction of nans in raw data is 0.0535245811287478
# 21640.330148954512
# Control data: Sum then square: 0.19712489539096587
# Control data: Square then sum: -1.373554622071928
# EVENT COUNT 458
# 489 Nigeria School Bombing 2014-11-10 07:00:00 2014-11-10 12:59:59 21600.0
# 21309.846245806904
# Event data: Sum then square: -1.3990920862254443
# Event data: Square then sum: 0.4257427701083166
# For controls...
# Control start and end: 2014-11-09 19:00:00 2014-11-10 00:59:59
# 21287.58280027294
# Control data: Sum then square: -1.5072152381945592
# Control data: Square then sum: 0.9993549112750285
# Control start and end: 2014-11-10 19:00:00 2014-11-11 00:59:59
# 21306.553083760828
# Control data: Sum then square: -1.4150806826489766
# Control data: Square then sum: -0.22689059225522554
# EVENT COUNT 459
# 490 Sydney Hostage Crisis 2014-12-14 22:00:00 2014-12-15 15:59:59 64800.0
# 64499.886037958975
# Event data: Sum then square: -0.8330877992480685
# Event data: Square then sum: -1.5457529519304822
# For controls...
# Control start and end: 2014-12-13 10:00:00 2014-12-14 03:59:59
# 64509.02978070176
# Control data: Sum then square: -0.8076109981975897
# Control data: Square then sum: 0.9366108938967578
# Control start and end: 2014-12-16 10:00:00 2014-12-17 03:59:59
# 65146.383255585504
# Control data: Sum then square: 0.9623176543834995
# Control data: Square then sum: -0.2645623702232791
# EVENT COUNT 460
# 491 Pakistani School Slaughter 2014-12-16 05:00:00 2014-12-16 14:59:59 36000.0
# 36052.746909204965
# Event data: Sum then square: 0.19896441911213805
# Event data: Square then sum: -0.8192650885967961
# For controls...
# Control start and end: 2014-12-15 09:00:00 2014-12-15 18:59:59
# 36041.39911275609
# Control data: Sum then square: 0.15671056735287064
# Control data: Square then sum: -0.8156850937931885
# Control start and end: 2014-12-17 01:00:00 2014-12-17 10:59:59
# 36133.46179743728
# Control data: Sum then square: 0.49925319045848654
# Control data: Square then sum: -0.232302686374999
# EVENT COUNT 461
# 492 Winter Solstice 2014-12-21 00:00:00 2014-12-21 23:59:59 86400.0
# 86028.49235395833
# Event data: Sum then square: -0.8933883327693022
# Event data: Square then sum: -0.014804913676854608
# For controls...
# Control start and end: 2014-12-19 00:00:00 2014-12-19 23:59:59
# 86884.19480231978
# Control data: Sum then square: 1.164225881677325
# Control data: Square then sum: -0.014663096208111348
# Control start and end: 2014-12-23 00:00:00 2014-12-23 23:59:59
# 86473.80523227878
# Control data: Sum then square: 0.17910090198052714
# Control data: Square then sum: -0.014381288174558166
# EVENT COUNT 462
# 493 Air Asia Loss 2014-12-28 00:00:00 2014-12-28 05:59:59 21600.0
# 21747.36529844485
# Event data: Sum then square: 0.7106112954463149
# Event data: Square then sum: 0.8871001329004304
# For controls...
# Control start and end: 2014-12-27 12:00:00 2014-12-27 17:59:59
# 21666.611165397633
# Control data: Sum then square: 0.32336095481837457
# Control data: Square then sum: -0.27074756957201024
# Control start and end: 2014-12-28 12:00:00 2014-12-28 17:59:59
# 21659.913529760306
# Control data: Sum then square: 0.29119978083614617
# Control data: Square then sum: -1.351326160520945
# EVENT COUNT 463
# 494 New Year Mean 2015 2014-12-31 09:30:00 2015-01-01 12:29:59 97200.0
# 97511.97661418686
# Event data: Sum then square: 0.708333349801628
# Event data: Square then sum: -0.42609238015694006
# For controls...
# Control start and end: 2014-12-29 03:30:00 2014-12-30 06:29:59
# 97008.02460002247
# Control data: Sum then square: -0.43418375177317525
# Control data: Square then sum: 0.0853306858273716
# Control start and end: 2015-01-02 15:30:00 2015-01-03 18:29:59
# 96626.43347967707
# Control data: Sum then square: -1.3019301272622252
# Control data: Square then sum: -0.23447833157678202
# EVENT COUNT 464
# 496 Charlie Hebdo & Yemen 2015-01-07 05:00:00 2015-01-07 16:59:59 43200.0
# 43493.228152876545
# Event data: Sum then square: 0.9976010047465539
# Event data: Square then sum: 0.7729208521103347
# For controls...
# Control start and end: 2015-01-06 05:00:00 2015-01-06 16:59:59
# 43023.88733772641
# Control data: Sum then square: -0.5976947436542994
# Control data: Square then sum: -0.06392592073012232
# Control start and end: 2015-01-08 05:00:00 2015-01-08 16:59:59
# 43429.83681269697
# Control data: Sum then square: 0.7828053646256421
# Control data: Square then sum: 0.3365854478187806
# EVENT COUNT 465
# 497 Millions Rally for Unity 2015-01-11 12:00:00 2015-01-11 23:59:59 43200.0
# 43288.56622585125
# Event data: Sum then square: 0.30337041782633983
# Event data: Square then sum: 0.7361704539814031
# For controls...
# Control start and end: 2015-01-10 12:00:00 2015-01-10 23:59:59
# 42892.116869140904
# Control data: Sum then square: -1.0476690209890593
# Control data: Square then sum: 0.14257695795670597
# Control start and end: 2015-01-12 12:00:00 2015-01-12 23:59:59
# 43683.40672621895
# Control data: Sum then square: 1.6407544745783151
# Control data: Square then sum: -0.186382687109092
# EVENT COUNT 466
# 498 Terror attacks in Denmark 2015-02-14 14:30:00 2015-02-15 00:29:59 36000.0
# 35788.316638003045
# Event data: Sum then square: -0.7879631577634066
# Event data: Square then sum: 1.0003193850998533
# For controls...
# Control start and end: 2015-02-13 18:30:00 2015-02-14 04:29:59
# 35774.52722902348
# Control data: Sum then square: -0.8395622968095994
# Control data: Square then sum: 0.46573978257319726
# Control start and end: 2015-02-15 10:30:00 2015-02-15 20:29:59
# 36040.60919475955
# Control data: Sum then square: 0.15376895447777275
# Control data: Square then sum: 0.3477105911006981
# EVENT COUNT 467
# 499 ISIS beheads Copts in Libya 2015-02-15 18:00:00 2015-02-15 23:59:59 21600.0
# 21804.560226123464
# Event data: Sum then square: 0.9843059956308031
# Event data: Square then sum: 0.883408481678836
# For controls...
# Control start and end: 2015-02-15 06:00:00 2015-02-15 11:59:59
# 21621.920980078557
# Control data: Sum then square: 0.10863894494350018
# Control data: Square then sum: -0.011205374046861217
# Control start and end: 2015-02-16 06:00:00 2015-02-16 11:59:59
# 21427.682281131754
# Control data: Sum then square: -0.8280693491013004
# Control data: Square then sum: 0.6374570939806692
# EVENT COUNT 468
# 500 Yemen Mosque Bombings 2015-03-20 08:00:00 2015-03-20 13:59:59 21600.0
# 21454.129635839297
# Event data: Sum then square: -0.7001959074185374
# Event data: Square then sum: -1.0282253958534253
# For controls...
# Control start and end: 2015-03-19 20:00:00 2015-03-20 01:59:59
# 21321.48522422878
# Control data: Sum then square: -1.3425970143967834
# Control data: Square then sum: 0.21122342645888517
# Control start and end: 2015-03-20 20:00:00 2015-03-21 01:59:59
# 21199.767447451683
# Control data: Sum then square: -1.9344309616068935
# Control data: Square then sum: -0.8166332894311901
# EVENT COUNT 469
# 501 Germanwings Crash 2015-03-24 09:30:00 2015-03-24 15:29:59 21600.0
# 21374.188276384615
# Event data: Sum then square: -1.087036067447675
# Event data: Square then sum: 0.20009533054752487
# For controls...
# Control start and end: 2015-03-23 21:30:00 2015-03-24 03:29:59
# 21900.78132620296
# Control data: Sum then square: 1.4436755263065688
# Control data: Square then sum: -0.7449443988763944
# Control start and end: 2015-03-24 21:30:00 2015-03-25 03:29:59
# 21635.98795220272
# Control data: Sum then square: 0.1762581120081453
# Control data: Square then sum: -0.4693831809082768
# EVENT COUNT 470
# 502 Global Meditation Day 2015-04-22 03:00:00 2015-04-22 17:59:59 54000.0
# 53818.6449246754
# Event data: Sum then square: -0.5504357394495188
# Event data: Square then sum: -0.593071850019864
# For controls...
# Control start and end: 2015-04-20 21:00:00 2015-04-21 11:59:59
# 54163.350834627956
# Control data: Sum then square: 0.498588530677915
# Control data: Square then sum: -0.553800849545872
# Control start and end: 2015-04-23 09:00:00 2015-04-23 23:59:59
# 54488.19323609458
# Control data: Sum then square: 1.4830985654005615
# Control data: Square then sum: -0.5172224152300475
# EVENT COUNT 471
# 503 Nepal Earthquake 2015-04-25 05:15:00 2015-04-26 05:14:59 86400.0
# 86412.39163530554
# Event data: Sum then square: 0.031411949057957515
# Event data: Square then sum: -0.5308393579455973
# For controls...
# Control start and end: 2015-04-23 05:15:00 2015-04-24 05:14:59
# 86551.42344891041
# Control data: Sum then square: 0.36565913515150084
# Control data: Square then sum: -0.8306762514249824
# Control start and end: 2015-04-27 05:15:00 2015-04-28 05:14:59
# 86158.5705280517
# Control data: Sum then square: -0.579726772992959
# Control data: Square then sum: 0.3060726655601648
# EVENT COUNT 472
# 504 Fuji Peace Declaration 2015-05-17 01:00:00 2015-05-17 04:59:59 14400.0
# 14369.94372219946
# Event data: Sum then square: -0.17330262041210245
# Event data: Square then sum: 0.6753994486769713
# For controls...
# Control start and end: 2015-05-16 17:00:00 2015-05-16 20:59:59
# 14395.56154907999
# Control data: Sum then square: -0.022228025388780374
# Control data: Square then sum: 0.9435639218225447
# Control start and end: 2015-05-17 09:00:00 2015-05-17 12:59:59
# 14375.587412305493
# Control data: Sum then square: -0.14000498558688737
# Control data: Square then sum: -0.4802269566501616
# EVENT COUNT 473
# 505 Charleston Hate Crime 2015-05-18 00:00:00 2015-05-18 07:59:59 28800.0
# 28621.683048128558
# Event data: Sum then square: -0.741747060335906
# Event data: Square then sum: 0.14282023895951215
# For controls...
# Control start and end: 2015-05-17 08:00:00 2015-05-17 15:59:59
# 28995.949379654026
# Control data: Sum then square: 0.8173876071876013
# Control data: Square then sum: -1.1165039576400213
# Control start and end: 2015-05-18 16:00:00 2015-05-18 23:59:59
# 29089.905625606978
# Control data: Sum then square: 1.206686091379999
# Control data: Square then sum: 0.6149439119576026
# EVENT COUNT 474
# 506 Iran Nuclear Deal 2015-07-14 10:25:00 2015-07-14 16:24:59 21600.0
# 21852.3321213608
# Event data: Sum then square: 1.2125423748115978
# Event data: Square then sum: -0.40123142081437885
# For controls...
# Control start and end: 2015-07-13 22:25:00 2015-07-14 04:24:59
# 21732.864888909862
# Control data: Sum then square: 0.6411463446230402
# Control data: Square then sum: 0.004554621019935029
# Control start and end: 2015-07-14 22:25:00 2015-07-15 04:24:59
# 21693.83475164136
# Control data: Sum then square: 0.4540169118217654
# Control data: Square then sum: -0.05944596101789404
# EVENT COUNT 475
# 507 Mecca Crane Falls 2015-09-11 13:00:00 2015-09-11 18:59:59 21600.0
# 21684.37679530413
# Event data: Sum then square: 0.4086371102857796
# Event data: Square then sum: 1.4657076905533808
# For controls...
# Control start and end: 2015-09-11 01:00:00 2015-09-11 06:59:59
# 21596.468617689934
# Control data: Sum then square: -0.013783744721269763
# Control data: Square then sum: 0.22229541834906555
# Control start and end: 2015-09-12 01:00:00 2015-09-12 06:59:59
# 21581.13087944013
# Control data: Sum then square: -0.08760280533040442
# Control data: Square then sum: 0.34458563973971174
# EVENT COUNT 476
# 509 Hadj Stampede 2015 2015-09-24 05:00:00 2015-09-24 08:59:59 14400.0
# 14544.386175686539
# Event data: Sum then square: 0.8519017107492067
# Event data: Square then sum: 1.405946096913802
# For controls...
# Control start and end: 2015-09-23 21:00:00 2015-09-24 00:59:59
# 14552.66876170997
# Control data: Sum then square: 0.9003745301567339
# Control data: Square then sum: -0.35046537682206536
# Control start and end: 2015-09-24 13:00:00 2015-09-24 16:59:59
# 14359.92147486066
# Control data: Sum then square: -0.23245513513255908
# Control data: Square then sum: -0.18710414083991794
# EVENT COUNT 477
# 510 Turkey Peace Bombing 2015-10-10 09:00:00 2015-10-10 14:59:59 21600.0
# 21671.251561650413
# Event data: Sum then square: 0.34563964761905924
# Event data: Square then sum: -0.25060901723118584
# For controls...
# Control start and end: 2015-10-09 21:00:00 2015-10-10 02:59:59
# 21793.070165960016
# Control data: Sum then square: 0.9293610723538869
# Control data: Square then sum: -1.500379657158546
# Control start and end: 2015-10-10 21:00:00 2015-10-11 02:59:59
# 21754.917920876647
# Control data: Sum then square: 0.7467802955323508
# Control data: Square then sum: -0.7478088683421726
# EVENT COUNT 478
# 511 Paris Terror 2015-11-13 20:00:00 2015-11-14 01:59:59 21600.0
# 21413.25070119428
# Event data: Sum then square: -0.8978907069520277
# Event data: Square then sum: 0.08851207105939672
# For controls...
# Control start and end: 2015-11-13 08:00:00 2015-11-13 13:59:59
# 21872.44698255371
# Control data: Sum then square: 1.3085442921846608
# Control data: Square then sum: 1.098882793516847
# Control start and end: 2015-11-14 08:00:00 2015-11-14 13:59:59
# 21677.430392710732
# Control data: Sum then square: 0.3752994810545778
# Control data: Square then sum: -0.739262313442399
# EVENT COUNT 479
# 512 Arbaeen, Hussein 2015-12-03 00:00:00 2015-12-03 23:59:59 86400.0
# 86137.98369569889
# Event data: Sum then square: -0.6293473999848033
# Event data: Square then sum: -0.01476666283632367
# For controls...
# Control start and end: 2015-12-01 00:00:00 2015-12-01 23:59:59
# 86420.28490268649
# Control data: Sum then square: 0.05039779366052291
# Control data: Square then sum: -0.014767236971848013
# Control start and end: 2015-12-05 00:00:00 2015-12-05 23:59:59
# 85956.22928319545
# Control data: Sum then square: -1.0677752080838314
# Control data: Square then sum: -0.015021469691500406
# EVENT COUNT 480
# 513 Climate Agreement, Day 1 World Peace 2015-12-12 00:00:00 2015-12-12 23:59:59 86400.0
# 86800.45235761574
# Event data: Sum then square: 0.9634574810960362
# Event data: Square then sum: -0.014369442417916576
# For controls...
# Control start and end: 2015-12-10 00:00:00 2015-12-10 23:59:59
# 86989.82539718562
# Control data: Sum then square: 1.4172862289499013
# Control data: Square then sum: -0.014526541153422027
# Control start and end: 2015-12-14 00:00:00 2015-12-14 23:59:59
# 86496.87251232479
# Control data: Sum then square: 0.2345556096762869
# Control data: Square then sum: -0.014404628623898246

# %%
from matplotlib import pyplot as plt

print("num events after dropping events with missing data:", len(surviving_events))

for (touse_pvaltozs_sumthensquare, touse_pvaltozs_squarethensum, testtype) in (
    [ (allevents_pvaltozs_sumthensquare, allevents_pvaltozs_squarethensum, "actual")]
    +[ (controls_pvaltozs_sumthensquare[control_timeshift],
        controls_pvaltozs_squarethensum[control_timeshift],
        "controltimeshift_"+str(control_timeshift))
        for control_timeshift in control_timeshifts ]):

  print("************TIME PERIODS:", testtype)

  pvaltoz_sumthensquare = np.array(touse_pvaltozs_sumthensquare)
  pvaltoz_squarethensum = np.array(touse_pvaltozs_squarethensum)

  metaz_sumthensquare = np.sum(pvaltoz_sumthensquare)/np.sqrt(len(pvaltoz_sumthensquare))
  metaz_squarethensum = np.sum(pvaltoz_squarethensum)/np.sqrt(len(pvaltoz_squarethensum))
  print("Meta-analysis Z-score if squaring *after* summing:", metaz_sumthensquare, "pval:", 1-scipy.stats.norm.cdf(metaz_sumthensquare))
  print("Meta-analysis Z-score if squaring *before* summing", metaz_squarethensum, "pval: ", 1-scipy.stats.norm.cdf(metaz_squarethensum))
  print("Argmax event for square after summing:", surviving_events[np.argmax(pvaltoz_sumthensquare)], np.max(pvaltoz_sumthensquare))
  print("Argmax event for square before summing:", surviving_events[np.argmax(pvaltoz_squarethensum)], np.max(pvaltoz_squarethensum))
  print("Correlation between the two scores:", scipy.stats.pearsonr(pvaltoz_squarethensum, pvaltoz_sumthensquare))

  fig, ax = plt.subplots(ncols=3, figsize=(20,4))
  plt.sca(ax[0])
  scipy.stats.probplot(pvaltoz_sumthensquare, dist=scipy.stats.norm, plot=plt, fit=False)
  plt.plot(plt.xlim(), plt.xlim(), color="black")
  plt.title("Q-Q plot; square after sum across eggs")
  plt.xlabel("Theoretical Z-scores for the quantile")
  plt.ylabel("Actual Z-scores (invcdf(1-p)) for the quantile")
  plt.sca(ax[1])
  scipy.stats.probplot(pvaltoz_squarethensum, dist=scipy.stats.norm, plot=plt, fit=False)
  plt.plot(plt.xlim(), plt.xlim(), color="black")
  plt.title("Q-Q plot; square before sum across eggs")
  plt.xlabel("Theoretical Z-scores for the quantile")
  plt.ylabel("Actual Z-scores (invcdf(1-p)) for the quantile")
  plt.sca(ax[2])
  plt.scatter(pvaltoz_squarethensum, pvaltoz_sumthensquare, s=1)
  plt.plot(plt.xlim(), plt.xlim(), color="black", linestyle="--")
  plt.plot(plt.xlim(), [0,0], color="black")
  plt.plot([0,0], plt.ylim(), color="black")
  plt.xlabel("pvalues to zscores\n(square before sum across eggs)")
  plt.ylabel("pvalues to zscores\n(square after sum across eggs)")
  plt.show()
# Out:
# num events after dropping events with missing data: 475
# ************TIME PERIODS: actual
# Meta-analysis Z-score if squaring *after* summing: 5.699417289773736 pval: 6.010881570261972e-09
# Meta-analysis Z-score if squaring *before* summing 1.0928336260177285 pval:  0.13723342739765898
# Argmax event for square after summing: ('487', 'September 21', datetime.datetime(2014, 9, 21, 0, 0), datetime.datetime(2014, 9, 21, 23, 59, 59), 86400.0) 3.3323948949835147
# Argmax event for square before summing: ('271', 'Obama Acceptance 080828', datetime.datetime(2008, 8, 29, 2, 0), datetime.datetime(2008, 8, 29, 3, 59, 59), 7200.0) 3.274159999443293
# Correlation between the two scores: PearsonRResult(statistic=0.09902823969764994, pvalue=0.030936351522470127)
# ************TIME PERIODS: controltimeshift_-2
# Meta-analysis Z-score if squaring *after* summing: 0.03870698535787964 pval: 0.4845620020372071
# Meta-analysis Z-score if squaring *before* summing 1.5797068784706358 pval:  0.05708700483288531
# Argmax event for square after summing: ('434', '12.12.12 Meditation', datetime.datetime(2012, 12, 12, 12, 30), datetime.datetime(2012, 12, 12, 15, 29, 59), 10800.0) 3.6782721397569507
# Argmax event for square before summing: ('106', 'Tiger Woods Triumph', datetime.datetime(2002, 4, 14, 18, 22), datetime.datetime(2002, 4, 14, 22, 59, 59), 16680.0) 3.0899698954945283
# Correlation between the two scores: PearsonRResult(statistic=0.1256673260604315, pvalue=0.0060969831924469545)
# ************TIME PERIODS: controltimeshift_2
# Meta-analysis Z-score if squaring *after* summing: -0.6329618059835873 pval: 0.7366207074827908
# Meta-analysis Z-score if squaring *before* summing -0.2544317316078673 pval:  0.600418980461717
# Argmax event for square after summing: ('376', 'William &amp Catherine', datetime.datetime(2011, 4, 29, 10, 0), datetime.datetime(2011, 4, 29, 15, 59, 59), 21600.0) 3.617324336526462
# Argmax event for square before summing: ('45', 'Just A Minute', datetime.datetime(2000, 1, 1, 12, 0), datetime.datetime(2000, 1, 1, 12, 0, 59), 60.0) 2.895171371485081
# Correlation between the two scores: PearsonRResult(statistic=0.1337387245728552, pvalue=0.003497876658363101)
