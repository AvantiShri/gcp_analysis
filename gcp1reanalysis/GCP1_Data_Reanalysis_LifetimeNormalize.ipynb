# %% [markdown]
# <a href="https://colab.research.google.com/github/AvantiShri/gcp_analysis/blob/main/gcp1reanalysis/GCP1_Data_Reanalysis_LifetimeNormalize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Preparation

# %%
#mount Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/GCP_data/all_data
#data at https://drive.google.com/drive/u/0/folders/1MUS-xbwoBiodWLz4gese19ti_ftlKsVu
# Out:
# /content/drive/MyDrive/GCP_data/all_data

# %%
#install utilities code for reading/parsing data at https://github.com/AvantiShri/gcpdatautils
# !pip uninstall -y gcpdatautils #uninstall the pre-existing version if want to fetch latest
# !pip install git+https://github.com/AvantiShri/gcpdatautils.git@main #install latest from github

#Note: the code that was used to consolidate the downloaded csv.gz files into hdf5 files
# is at https://github.com/AvantiShri/gcp_analysis/blob/main/alldata/Consolidate_GCP_as_HDF5.ipynb
# Out:
# WARNING: Skipping gcpdatautils as it is not installed.
# Collecting git+https://github.com/AvantiShri/gcpdatautils.git@main
#   Cloning https://github.com/AvantiShri/gcpdatautils.git (to revision main) to /tmp/pip-req-build-zjf0u0o_
#   Running command git clone --filter=blob:none --quiet https://github.com/AvantiShri/gcpdatautils.git /tmp/pip-req-build-zjf0u0o_
#   Resolved https://github.com/AvantiShri/gcpdatautils.git to commit 55a9bc16c7c36ea920eafb44079d401f76da48f1
#   Preparing metadata (setup.py) ... done
# Collecting bs4 (from gcpdatautils==0.1.1.3)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from gcpdatautils==0.1.1.3) (3.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gcpdatautils==0.1.1.3) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gcpdatautils==0.1.1.3) (1.11.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->gcpdatautils==0.1.1.3) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->gcpdatautils==0.1.1.3) (2.5)
# Building wheels for collected packages: gcpdatautils
#   Building wheel for gcpdatautils (setup.py) ... done
#   Created wheel for gcpdatautils: filename=gcpdatautils-0.1.1.3-py3-none-any.whl size=6405 sha256=ab9499a417b0e4a101fbe73e39ea1da2effc9b496a24209c012af73dbb8adc1a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c400eegh/wheels/8c/35/d9/946037b24577e21d0dce0d66645d002768f5bac3497186d55f
# Successfully built gcpdatautils
# Installing collected packages: bs4, gcpdatautils
# Successfully installed bs4-0.0.2 gcpdatautils-0.1.1.3

# %% [markdown]
# Load in the GCP event timeperiod definitions

# %%
from gcpdatautils import parse_events_html

#download the formal event registry if not already present
# !wget https://global-mind.org/pred_formal.html -O pred_formal.html

# we will parse the events file, dropping events longer than 30 days for memory efficiency
# we will also drop 'New Year Var...' events as they tend to be redundant in duration
# with the 'mean' events, and we are going to do a standard analysis on all the events
included_events = parse_events_html("/content/drive/MyDrive/GCP_data/pred_formal.html",
                                    exclude_events_longer_than_days=30)
# Out:
# --2024-02-13 20:05:16--  https://global-mind.org/pred_formal.html
# Resolving global-mind.org (global-mind.org)... 162.245.217.130
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘pred_formal.html’
#
# pred_formal.html        [  <=>               ] 184.64K   378KB/s    in 0.5s
#
# 2024-02-13 20:05:17 (378 KB/s) - ‘pred_formal.html’ saved [189067]
#
# Skipping because redundant with a corresponding 'mean' event:  43 New Year Var 99-00 1999-12-31 09:30:00 2000-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  65 New Year Var 00-01 2000-12-31 09:30:00 2001-01-01 11:29:59
# Skipping because end < start: 82 Silent Prayer, Sept 14 2001-09-14 10:00:00 2001-09-14 10:00:00
# Skipping because redundant with a corresponding 'mean' event:  98 New Year Var 01-02 2001-12-31 09:30:00 2002-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  126 New Year Variance 2002-12-31 09:30:00 2003-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  163 New Year Variance 2003-12-31 09:30:00 2004-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  191 New Year Variance 2004-12-31 09:30:00 2005-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  210 New Year Dev-Net Var 2005-12-31 23:53:00 2006-01-01 00:00:59
# Skipping because event is more than 30 days long! 223 TM Flyer Aggregation 2006-07-29 12:30:00 2006-09-09 23:29:59
# Skipping because redundant with a corresponding 'mean' event:  232 New Year Variance 2006-12-31 09:30:00 2007-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  257 New Year Var, 2008 2007-12-31 09:30:00 2008-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  284 New Year Variance 2009 2008-12-31 09:30:00 2009-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  318 New Year Variance 2010 2009-12-31 09:30:00 2010-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  357 New Year Variance 2011 2010-12-31 09:30:00 2011-01-01 11:29:59
# Skipping because end < start: 392 Troy Davis Execution 2011-09-22 00:00:00 2011-09-21 05:59:59
# Skipping because redundant with a corresponding 'mean' event:  405 New Year Variance 2012 2011-12-31 09:30:00 2012-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  439 New Year Variance 2013 2012-12-31 09:30:00 2013-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  474 New Year Variance 2014 2013-12-31 09:30:00 2014-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  495 New Year Variance 2015 2014-12-31 09:30:00 2015-01-01 11:29:59

# %%
len(included_events)
# Out:
# 480

# %% [markdown]
# Load the code for reading from the hdf5 files

# %%
import numpy as np
from collections import defaultdict
import h5py
from datetime import datetime, timedelta
from gcpdatautils import GCPHdf5DataReader, GCPMissingDataError

#Refer to the github repo https://github.com/AvantiShri/gcpdatautils for the
# code for reading from the hdf5 files
#Instantiate the hdf5 data reader
#it will auto-load a rotteneggs.txt file specifying bad data time periods (downloaded from https://global-mind.org/rotteneggs and saved in the package)
# this rotten egg file can be overridden by altering the arguments to the GCPHdf5DataReader
gcp_data_reader = GCPHdf5DataReader()
# Out:
# Parsing the bad data file: /usr/local/lib/python3.10/dist-packages/gcpdatautils/resources/rotteneggs.txt
# manually correcting 47,2000-01-01 00:00:00,2001-06-31 23:59:59,2222
# manually correcting 47,2008-04-25 00:00:00,2008-04-55 23:59:59,1092

# %% [markdown]
# Pull data for a specific event to compare to the GCP plots, as a sanity check

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import scipy
#data for a top-ranked GCP event - Valentine's day 2009
# Compare to: https://global-mind.org/valentines.09.html
idx=263
print(included_events[idx])

start_datetime, end_datetime = included_events[idx][2], included_events[idx][3]
event_data = gcp_data_reader.fetch_data(start_datetime, end_datetime, normalize=False)[0] #returns both the event data and the device ids; we just want the data

#make the chi-squared-minus-1 plot
csm1 = np.square(np.nansum((event_data - 100)/np.sqrt(50), axis=1)/np.sqrt(
        np.sum(np.isnan(event_data)==False, axis=1))) - 1
plt.figure(figsize=(20,5))
plt.plot(np.arange(len(csm1)), np.cumsum(csm1))
#also plot the p=0.05 envelop
plt.plot(np.arange(len(csm1)), np.array([scipy.stats.chi2.ppf(0.95, x+1)
                                         for x in np.arange(len(csm1))])
                                        - (np.arange(len(csm1))+1) )
plt.show()
# Out:
# ('289', 'Meditations Valentines Day', datetime.datetime(2009, 2, 14, 0, 0), datetime.datetime(2009, 2, 14, 23, 59, 59), 86400.0)

# %% [markdown]
# Load the empirical variances, computed from https://github.com/AvantiShri/gcp_analysis/blob/main/alldata/ComputeLifetimeDeviceStats.ipynb

# %%
import json
from matplotlib import pyplot as plt

device_to_empirical_variances = json.loads(open("empirical_device_variances.json").read())
plt.hist(device_to_empirical_variances.values(), bins=50)
plt.show()

# %% [markdown]
# Do aggregate analysis

# %%
from datetime import datetime,timedelta
import numpy as np
import h5py
import traceback
import scipy


def normalize_by_lifetime_device_variance(data, devices, device_to_empirical_variances):
  data = np.array(data) #make a copy, just in case
  for i,device in enumerate(devices):
    scalefactor = (np.sqrt(device_to_empirical_variances[str(int(device))])/np.sqrt(50))
    data[:,i] = ((data[:,i]-100)/scalefactor)+100
  return data


def compute_pvaltoz(egg_values):

  num_nonnan_eggs = np.sum(np.isnan(egg_values)==False, axis=1) #get the number of non NaN eggs per row
  egg_zscores = (egg_values - 100)/np.sqrt(50)
  composite_z_scores = np.nansum(egg_zscores, axis=1)/np.sqrt(num_nonnan_eggs)

  print(np.nansum(np.square(composite_z_scores)))
  pvaltoz_sumthensquare = scipy.stats.norm.ppf(
      scipy.stats.chi2.cdf(x=np.nansum(np.square(composite_z_scores)),
                           df=np.sum(np.isnan(composite_z_scores)==False)))
  pvaltoz_squarethensum = scipy.stats.norm.ppf(
      scipy.stats.chi2.cdf(np.nansum(np.square(egg_zscores)),
                           df=np.sum(np.isnan(egg_zscores)==False)))

  return pvaltoz_sumthensquare, pvaltoz_squarethensum


def get_normalized_data(start_datetime, end_datetime, device_to_empirical_variances):
  data, devices = gcp_data_reader.fetch_data(start_datetime, end_datetime, normalize=DAY_NORMALIZE)
  if LIFETIME_NORMALIZE:
    data = normalize_by_lifetime_device_variance(data, devices, device_to_empirical_variances)
  return data


DAY_NORMALIZE = False
LIFETIME_NORMALIZE = True
assert (DAY_NORMALIZE and LIFETIME_NORMALIZE)==False #at most one should be true

control_timeshifts = [-2, 2] #how much to shift the events by (as a multiple of their duration) to define 'control' time periods

surviving_events = [] #in case we encounter missing data errors, maintain a list of surviving events

eventcount = 0

allevents_pvaltozs_sumthensquare = []
allevents_pvaltozs_squarethensum = []
controls_pvaltozs_sumthensquare = defaultdict(list)
controls_pvaltozs_squarethensum = defaultdict(list)

missing_data_errors = []

for (event_num, event_name, start_datetime, end_datetime, duration) in included_events[:]:
  eventcount += 1
  print("EVENT COUNT", eventcount)
  print(event_num, event_name, start_datetime, end_datetime, duration)
  try:
    event_data = get_normalized_data(start_datetime, end_datetime, device_to_empirical_variances)
    event_pvaltoz_sumthensquare, event_pvaltoz_squarethensum = compute_pvaltoz(event_data)
    print("Event data: Sum then square:", event_pvaltoz_sumthensquare)
    print("Event data: Square then sum:", event_pvaltoz_squarethensum)

    print("For controls...")
    thisevent_control_pvaltozs_sumthensquare = {}
    thisevent_control_pvaltozs_squarethensum = {}
    for control_timeshift in control_timeshifts:
      timeshift = timedelta(seconds=control_timeshift*duration)
      control_starttime = start_datetime + timeshift
      control_endtime = end_datetime + timeshift
      print("Control start and end:", control_starttime, control_endtime)
      control_data = get_normalized_data(control_starttime, control_endtime, device_to_empirical_variances)
      pvaltozs_sumthensquare, pvaltozs_squarethensum = compute_pvaltoz(control_data)
      print("Control data: Sum then square:", pvaltozs_sumthensquare)
      print("Control data: Square then sum:", pvaltozs_squarethensum)
      thisevent_control_pvaltozs_sumthensquare[control_timeshift] = pvaltozs_sumthensquare
      thisevent_control_pvaltozs_squarethensum[control_timeshift] = pvaltozs_squarethensum

    allevents_pvaltozs_sumthensquare.append(event_pvaltoz_sumthensquare)
    allevents_pvaltozs_squarethensum.append(event_pvaltoz_squarethensum)
    for control_timeshift in control_timeshifts:
      controls_pvaltozs_sumthensquare[control_timeshift].append(
          thisevent_control_pvaltozs_sumthensquare[control_timeshift])
      controls_pvaltozs_squarethensum[control_timeshift].append(
          thisevent_control_pvaltozs_squarethensum[control_timeshift])
    surviving_events.append((event_num, event_name, start_datetime, end_datetime, duration))
  except GCPMissingDataError as e:
    print("MISSING DATA ERROR!",e)
    missing_data_errors.append(e)
# Out:
# Streaming output truncated to the last 5000 lines.
# 28716.167043958725
# Control data: Sum then square: -0.34686502908929984
# Control data: Square then sum: -1.3646532574640997
# Control start and end: 2003-12-26 17:30:00 2003-12-27 01:29:59
# 28922.98871633355
# Control data: Sum then square: 0.5145021248877634
# Control data: Square then sum: -1.2327431453459177
# EVENT COUNT 143
# 161 60 Seconds for Peace 2003-12-27 21:00:00 2003-12-27 21:00:59 60.0
# 76.73024303008096
# Event data: Sum then square: 1.4642978771868802
# Event data: Square then sum: 0.3459290137102313
# For controls...
# Control start and end: 2003-12-27 20:58:00 2003-12-27 20:58:59
# 56.247826434351374
# Control data: Sum then square: -0.288709066124998
# Control data: Square then sum: 0.18831326655445607
# Control start and end: 2003-12-27 21:02:00 2003-12-27 21:02:59
# 58.98861874326423
# Control data: Sum then square: -0.031858236911567216
# Control data: Square then sum: -0.020616935723644352
# EVENT COUNT 144
# 162 New Year Mean 2003-2004 2003-12-31 09:30:00 2004-01-01 12:29:59 97200.0
# 97372.2852139176
# Event data: Sum then square: 0.3920319807464257
# Event data: Square then sum: 0.9090795159406589
# For controls...
# Control start and end: 2003-12-29 03:30:00 2003-12-30 06:29:59
# 97537.27710362738
# Control data: Sum then square: 0.7655886010468793
# Control data: Square then sum: 1.0954765619686908
# Control start and end: 2004-01-02 15:30:00 2004-01-03 18:29:59
# 96836.22365876634
# Control data: Sum then square: -0.8245805254738658
# Control data: Square then sum: -0.30533493025975167
# EVENT COUNT 145
# 164 Hadj Ritual Tragedy 2004-02-01 05:30:00 2004-02-01 07:29:59 7200.0
# 7298.686264649788
# Event data: Sum then square: 0.8242072489143557
# Event data: Square then sum: 1.637984445095943
# For controls...
# Control start and end: 2004-02-01 01:30:00 2004-02-01 03:29:59
# 7234.593899980855
# Control data: Sum then square: 0.2933754568168811
# Control data: Square then sum: -0.32183122283296645
# Control start and end: 2004-02-01 09:30:00 2004-02-01 11:29:59
# 7054.418114351058
# Control data: Sum then square: -1.2158919181360077
# Control data: Square then sum: -0.9253496449889875
# EVENT COUNT 146
# 165 Iran Train Explosion 2004-02-18 00:30:00 2004-02-18 10:29:59 36000.0
# 36239.37105511779
# Event data: Sum then square: 0.8925968229006597
# Event data: Square then sum: -1.799704577831771
# For controls...
# Control start and end: 2004-02-17 04:30:00 2004-02-17 14:29:59
# 35262.86406575123
# Control data: Sum then square: -2.7636320042545957
# Control data: Square then sum: -0.6456050340124118
# Control start and end: 2004-02-18 20:30:00 2004-02-19 06:29:59
# 36064.26147603988
# Control data: Sum then square: 0.2418301845269086
# Control data: Square then sum: -0.110305609490951
# EVENT COUNT 147
# 166 Oscar Ceremony 2004 2004-03-01 01:00:00 2004-03-01 05:08:59 14940.0
# 14980.350358961703
# Event data: Sum then square: 0.2370762813515242
# Event data: Square then sum: -1.3976432393819798
# For controls...
# Control start and end: 2004-02-29 16:42:00 2004-02-29 20:50:59
# 15197.32741519415
# Control data: Sum then square: 1.4840499910878213
# Control data: Square then sum: -0.09124536177048767
# Control start and end: 2004-03-01 09:18:00 2004-03-01 13:26:59
# 14886.801767639807
# Control data: Sum then square: -0.30426443192827457
# Control data: Square then sum: -1.9790737449172693
# EVENT COUNT 148
# 167 Attacks on Shiites, Iraq 2004-03-02 06:30:00 2004-03-02 10:29:59 14400.0
# 14503.881800077179
# Event data: Sum then square: 0.6145895986175945
# Event data: Square then sum: -2.196355524068716
# For controls...
# Control start and end: 2004-03-01 22:30:00 2004-03-02 02:29:59
# 14556.484560806943
# Control data: Sum then square: 0.9226998436823154
# Control data: Square then sum: 0.0734169329258682
# Control start and end: 2004-03-02 14:30:00 2004-03-02 18:29:59
# 14215.931379523641
# Control data: Sum then square: -1.0853583950714738
# Control data: Square then sum: -0.0010275223370575328
# EVENT COUNT 149
# 168 Terror Attacks in Madrid 2004-03-11 06:00:00 2004-03-11 10:59:59 18000.0
# 17704.905230516186
# Event data: Sum then square: -1.5603489366023242
# Event data: Square then sum: -0.4042548091411392
# For controls...
# Control start and end: 2004-03-10 20:00:00 2004-03-11 00:59:59
# 17830.21423934674
# Control data: Sum then square: -0.8941622607207932
# Control data: Square then sum: 0.9715419563507867
# Control start and end: 2004-03-11 16:00:00 2004-03-11 20:59:59
# 17927.68695411481
# Control data: Sum then square: -0.3781199600104034
# Control data: Square then sum: 1.5379387506199147
# EVENT COUNT 150
# 169 Demonstrations in Spain 2004-03-12 11:00:00 2004-03-12 22:59:59 43200.0
# 43511.02100788764
# Event data: Sum then square: 1.0578529378617618
# Event data: Square then sum: 1.3970974201389015
# For controls...
# Control start and end: 2004-03-11 11:00:00 2004-03-11 22:59:59
# 42834.61888393264
# Control data: Sum then square: -1.2443040759182975
# Control data: Square then sum: 0.5505853370397644
# Control start and end: 2004-03-13 11:00:00 2004-03-13 22:59:59
# 43212.577840476355
# Control data: Sum then square: 0.04505452364681044
# Control data: Square then sum: -0.46834057368944737
# EVENT COUNT 151
# 170 Global Day of Peace 2004-03-20 00:00:00 2004-03-20 23:59:59 86400.0
# 85859.11307870259
# Event data: Sum then square: -1.3022923023625088
# Event data: Square then sum: 0.8244938307423093
# For controls...
# Control start and end: 2004-03-18 00:00:00 2004-03-18 23:59:59
# 86937.34878610758
# Control data: Sum then square: 1.291593058381328
# Control data: Square then sum: 0.9631005653777012
# Control start and end: 2004-03-22 00:00:00 2004-03-22 23:59:59
# 86534.18742165872
# Control data: Sum then square: 0.32424134664489745
# Control data: Square then sum: -0.05090434098113611
# EVENT COUNT 152
# 171 Cricket, India vs Pakistan 2004-03-24 09:00:00 2004-03-24 16:59:59 28800.0
# 29073.650837619436
# Event data: Sum then square: 1.1393959564594434
# Event data: Square then sum: -0.9125213488051029
# For controls...
# Control start and end: 2004-03-23 17:00:00 2004-03-24 00:59:59
# 28799.82551382237
# Control data: Sum then square: 0.002050756615601034
# Control data: Square then sum: 0.11005981272298562
# Control start and end: 2004-03-25 01:00:00 2004-03-25 08:59:59
# 29002.242806854345
# Control data: Sum then square: 0.8434900442760405
# Control data: Square then sum: -0.8572209543565548
# EVENT COUNT 153
# 172 Rantisi Assassination 2004-04-17 17:00:00 2004-04-17 20:59:59 14400.0
# 14273.620157497831
# Event data: Sum then square: -0.7429589111506064
# Event data: Square then sum: -0.4257742174699312
# For controls...
# Control start and end: 2004-04-17 09:00:00 2004-04-17 12:59:59
# 14647.151516785703
# Control data: Sum then square: 1.4520275623938645
# Control data: Square then sum: 0.24535094117871853
# Control start and end: 2004-04-18 01:00:00 2004-04-18 04:59:59
# 14558.097836350054
# Control data: Sum then square: 0.9321375545582519
# Control data: Square then sum: 0.07602962531106211
# EVENT COUNT 154
# 173 Korean Train Explosion 2004-04-22 03:00:00 2004-04-22 06:59:59 14400.0
# 14546.296921882918
# Event data: Sum then square: 0.8630857499166465
# Event data: Square then sum: -0.8380330863467943
# For controls...
# Control start and end: 2004-04-21 19:00:00 2004-04-21 22:59:59
# 14342.41430783307
# Control data: Sum then square: -0.33585063201457005
# Control data: Square then sum: -1.3885668721543922
# Control start and end: 2004-04-22 11:00:00 2004-04-22 14:59:59
# 14672.430725182103
# Control data: Sum then square: 1.5992224096559433
# Control data: Square then sum: 1.6184166998965144
# EVENT COUNT 155
# 174 Floods in Haiti 2004-05-24 00:00:00 2004-05-24 23:59:59 86400.0
# 86693.46984472625
# Event data: Sum then square: 0.7067842836463721
# Event data: Square then sum: 1.2722631842167198
# For controls...
# Control start and end: 2004-05-22 00:00:00 2004-05-22 23:59:59
# 86226.43500898189
# Control data: Sum then square: -0.41620837126650995
# Control data: Square then sum: 0.6990318136799721
# Control start and end: 2004-05-26 00:00:00 2004-05-26 23:59:59
# 85807.01684133578
# Control data: Sum then square: -1.4281676900840985
# Control data: Square then sum: -1.5931406988498773
# EVENT COUNT 156
# 175 Iraq Insurgency Bombs 2004-06-24 04:30:00 2004-06-24 08:29:59 14400.0
# 14554.766381588088
# Event data: Sum then square: 0.9126476769779686
# Event data: Square then sum: -0.21605860810255587
# For controls...
# Control start and end: 2004-06-23 20:30:00 2004-06-24 00:29:59
# 14531.019661895338
# Control data: Sum then square: 0.7736370315727593
# Control data: Square then sum: 0.446096711533087
# Control start and end: 2004-06-24 12:30:00 2004-06-24 16:29:59
# 13727.024276963855
# Control data: Sum then square: -4.025120284176111
# Control data: Square then sum: 1.1170517068881476
# EVENT COUNT 157
# 176 Turkish Train Wreck 2004-07-22 04:15:00 2004-07-22 08:14:59 14400.0
# 14282.631148498009
# Event data: Sum then square: -0.6895595109456096
# Event data: Square then sum: 0.2518140312982042
# For controls...
# Control start and end: 2004-07-21 20:15:00 2004-07-22 00:14:59
# 14291.945773056912
# Control data: Sum then square: -0.6343843880564624
# Control data: Square then sum: 0.3261643331377219
# Control start and end: 2004-07-22 12:15:00 2004-07-22 16:14:59
# 14083.19346693686
# Control data: Sum then square: -1.876733341661561
# Control data: Square then sum: -0.6127001983771282
# EVENT COUNT 158
# 177 Democratic Convention, Kerry 2004-07-30 02:00:00 2004-07-30 02:44:59 2700.0
# 2839.778731882977
# Event data: Sum then square: 1.8793137176218497
# Event data: Square then sum: -0.5234116433624166
# For controls...
# Control start and end: 2004-07-30 00:30:00 2004-07-30 01:14:59
# 2638.8016328520625
# Control data: Sum then square: -0.8300913486686383
# Control data: Square then sum: -0.9894017740378153
# Control start and end: 2004-07-30 03:30:00 2004-07-30 04:14:59
# 2584.6251471557307
# Control data: Sum then square: -1.583885893743556
# Control data: Square then sum: 0.3437013119324841
# EVENT COUNT 159
# 178 Fire in Paraguay 2004-08-01 14:00:00 2004-08-01 17:59:59 14400.0
# 14460.587741712714
# Event data: Sum then square: 0.36044421200567356
# Event data: Square then sum: -0.04104139954946173
# For controls...
# Control start and end: 2004-08-01 06:00:00 2004-08-01 09:59:59
# 14204.31816732387
# Control data: Sum then square: -1.154398215114583
# Control data: Square then sum: 0.16952352892885458
# Control start and end: 2004-08-01 22:00:00 2004-08-02 01:59:59
# 14471.475659693198
# Control data: Sum then square: 0.4244062910528334
# Control data: Square then sum: 1.218637166192468
# EVENT COUNT 160
# 179 Bob Morris Dies 2004-08-12 04:00:00 2004-08-12 19:59:59 57600.0
# 57808.94706229494
# Event data: Sum then square: 0.6168369578723979
# Event data: Square then sum: -0.16340568483070417
# For controls...
# Control start and end: 2004-08-10 20:00:00 2004-08-11 11:59:59
# 58255.33896304387
# Control data: Sum then square: 1.925498940985224
# Control data: Square then sum: 0.5147794433320908
# Control start and end: 2004-08-13 12:00:00 2004-08-14 03:59:59
# 57793.66798597327
# Control data: Sum then square: 0.5719251569146361
# Control data: Square then sum: -0.23407614443999558
# EVENT COUNT 161
# 180 Olympic Opening Athens 2004-08-13 18:00:00 2004-08-13 20:59:59 10800.0
# 10619.250298281162
# Event data: Sum then square: -1.2322321792825126
# Event data: Square then sum: -0.337082674438965
# For controls...
# Control start and end: 2004-08-13 12:00:00 2004-08-13 14:59:59
# 10973.137106375383
# Control data: Sum then square: 1.176341914930968
# Control data: Square then sum: -0.6311372498626078
# Control start and end: 2004-08-14 00:00:00 2004-08-14 02:59:59
# 10858.095617772371
# Control data: Sum then square: 0.39911812327349716
# Control data: Square then sum: 0.5924883229921454
# EVENT COUNT 162
# 181 Day of Murderous Violence 2004-08-31 00:00:00 2004-08-31 23:59:59 86400.0
# 87095.02720026257
# Event data: Sum then square: 1.6691158993334057
# Event data: Square then sum: 0.8027375215982281
# For controls...
# Control start and end: 2004-08-29 00:00:00 2004-08-29 23:59:59
# 86268.11866631184
# Control data: Sum then square: -0.31581479033272736
# Control data: Square then sum: 0.8876668234960985
# Control start and end: 2004-09-02 00:00:00 2004-09-02 23:59:59
# 86698.62615560109
# Control data: Sum then square: 0.7191601814315252
# Control data: Square then sum: -2.2597841205032823
# EVENT COUNT 163
# 182 Republican Convention, Bush 2004-09-03 02:09:59 2004-09-03 03:11:59 3721.0
# 3704.205885108821
# Event data: Sum then square: -0.18723864227435125
# Event data: Square then sum: -1.3158383892585304
# For controls...
# Control start and end: 2004-09-03 00:05:57 2004-09-03 01:07:57
# 3784.6467837778805
# Control data: Sum then square: 0.7413400772668455
# Control data: Square then sum: -0.4276162941227838
# Control start and end: 2004-09-03 04:14:01 2004-09-03 05:16:01
# 3747.744230156608
# Control data: Sum then square: 0.31700061537498575
# Control data: Square then sum: -0.2751943845071404
# EVENT COUNT 164
# 183 Russian School Hostage Crisis 2004-09-03 05:00:00 2004-09-03 08:59:59 14400.0
# 14727.38877630785
# Event data: Sum then square: 1.9186487334356968
# Event data: Square then sum: 2.0397838256177323
# For controls...
# Control start and end: 2004-09-02 21:00:00 2004-09-03 00:59:59
# 14558.538214569886
# Control data: Sum then square: 0.9347136594754499
# Control data: Square then sum: 0.45773341663527406
# Control start and end: 2004-09-03 13:00:00 2004-09-03 16:59:59
# 14357.138420682088
# Control data: Sum then square: -0.24888594053458202
# Control data: Square then sum: 0.3919898384771571
# EVENT COUNT 165
# 184 Earthdance 2004 2004-09-18 22:50:00 2004-09-18 23:14:59 1500.0
# 1413.699968478819
# Event data: Sum then square: -1.5946577304912872
# Event data: Square then sum: -0.8072608965166388
# For controls...
# Control start and end: 2004-09-18 22:00:00 2004-09-18 22:24:59
# 1518.3141378070138
# Control data: Sum then square: 0.3451773405015285
# Control data: Square then sum: -1.8343470537447428
# Control start and end: 2004-09-18 23:40:00 2004-09-19 00:04:59
# 1454.1454163267772
# Control data: Sum then square: -0.8336693103680288
# Control data: Square then sum: -1.1715064762778034
# EVENT COUNT 166
# 185 Intnl Day Peace + Hurricane Haiti 2004-09-21 00:00:00 2004-09-21 23:59:59 86400.0
# 85758.66112113903
# Event data: Sum then square: -1.5450508343616254
# Event data: Square then sum: -0.38794039153420745
# For controls...
# Control start and end: 2004-09-19 00:00:00 2004-09-19 23:59:59
# 85853.40516099814
# Control data: Sum then square: -1.316081337856042
# Control data: Square then sum: -1.3387459444147267
# Control start and end: 2004-09-23 00:00:00 2004-09-23 23:59:59
# 87039.45254134451
# Control data: Sum then square: 1.5361078195737554
# Control data: Square then sum: 1.114310235229739
# EVENT COUNT 167
# 186 Bombing in Taba, Egypt 2004-10-07 19:00:00 2004-10-07 22:59:59 14400.0
# 14613.108943848045
# Event data: Sum then square: 1.2535382464215248
# Event data: Square then sum: 0.08497246323811816
# For controls...
# Control start and end: 2004-10-07 11:00:00 2004-10-07 14:59:59
# 14228.038362664998
# Control data: Sum then square: -1.0134232006697508
# Control data: Square then sum: -2.347762860251843
# Control start and end: 2004-10-08 03:00:00 2004-10-08 06:59:59
# 14474.182172412951
# Control data: Sum then square: 0.44030097278802544
# Control data: Square then sum: -0.41756659157700826
# EVENT COUNT 168
# 187 US Election 2004 2004-11-02 11:00:00 2004-11-03 05:59:59 68400.0
# 67944.36968824998
# Event data: Sum then square: -1.2328257910626865
# Event data: Square then sum: -0.4056114951095101
# For controls...
# Control start and end: 2004-10-31 21:00:00 2004-11-01 15:59:59
# 69281.38145866303
# Control data: Sum then square: 2.374623872793514
# Control data: Square then sum: -0.15105002859292324
# Control start and end: 2004-11-04 01:00:00 2004-11-04 19:59:59
# 68297.18570536557
# Control data: Sum then square: -0.27631473064080986
# Control data: Square then sum: -0.7039144795149673
# EVENT COUNT 169
# 188 Arafat Dies 2004-11-11 02:30:00 2004-11-11 14:29:59 43200.0
# 43667.17473243818
# Event data: Sum then square: 1.5859333618924099
# Event data: Square then sum: 1.8218562604204003
# For controls...
# Control start and end: 2004-11-10 02:30:00 2004-11-10 14:29:59
# 43317.015276374084
# Control data: Sum then square: 0.40000272102695533
# Control data: Square then sum: -0.7838712761091426
# Control start and end: 2004-11-12 02:30:00 2004-11-12 14:29:59
# 42904.62675149291
# Control data: Sum then square: -1.0049102695582572
# Control data: Square then sum: 0.13588611641979248
# EVENT COUNT 170
# 189 Tsunami Indian Ocean 2004-12-26 00:29:00 2004-12-26 08:28:59 28800.0
# 28868.985940047147
# Event data: Sum then square: 0.2899894582436368
# Event data: Square then sum: 1.1361427384878353
# For controls...
# Control start and end: 2004-12-25 08:29:00 2004-12-25 16:28:59
# 28683.660602519376
# Control data: Sum then square: -0.4826230358222803
# Control data: Square then sum: -0.8661966532648678
# Control start and end: 2004-12-26 16:29:00 2004-12-27 00:28:59
# 29118.740845638564
# Control data: Sum then square: 1.3259939904866278
# Control data: Square then sum: -0.5821947207825244
# EVENT COUNT 171
# 190 New Year Mean 2004-2005 2004-12-31 09:30:00 2005-01-01 12:29:59 97200.0
# 97923.56046073756
# Event data: Sum then square: 1.638525079325277
# Event data: Square then sum: 0.29169928914300286
# For controls...
# Control start and end: 2004-12-29 03:30:00 2004-12-30 06:29:59
# 96936.84166618493
# Control data: Sum then square: -0.5958823410848858
# Control data: Square then sum: -0.2151700140745877
# Control start and end: 2005-01-02 15:30:00 2005-01-03 18:29:59
# 96090.88474378256
# Control data: Sum then square: -2.52364313012606
# Control data: Square then sum: -0.31061830318505124
# EVENT COUNT 172
# 192 Elections in Iraq 2005-01-30 04:00:00 2005-01-30 15:59:59 43200.0
# 43673.88331885687
# Event data: Sum then square: 1.608592246812193
# Event data: Square then sum: -1.1634700241372538
# For controls...
# Control start and end: 2005-01-29 04:00:00 2005-01-29 15:59:59
# 43284.59068585574
# Control data: Sum then square: 0.28986341250148195
# Control data: Square then sum: 1.5735854169604568
# Control start and end: 2005-01-31 04:00:00 2005-01-31 15:59:59
# 43668.30175515437
# Control data: Sum then square: 1.5897401497096912
# Control data: Square then sum: -1.5689991055661476
# EVENT COUNT 173
# 193 Hariri Assassination Beirut 2005-02-14 09:00:00 2005-02-14 12:59:59 14400.0
# 14428.406894079724
# Event data: Sum then square: 0.17120702424662193
# Event data: Square then sum: 0.675074075236805
# For controls...
# Control start and end: 2005-02-14 01:00:00 2005-02-14 04:59:59
# 14427.569911377686
# Control data: Sum then square: 0.16628145517537737
# Control data: Square then sum: 3.003892407866761
# Control start and end: 2005-02-14 17:00:00 2005-02-14 20:59:59
# 14453.847163638273
# Control data: Sum then square: 0.32082997728652485
# Control data: Square then sum: 0.44347636316103095
# EVENT COUNT 174
# 194 Siyum Daf Yomi 2005-03-01 22:45:00 2005-03-02 01:59:59 11700.0
# 11685.800129512616
# Event data: Sum then square: -0.08850644250586633
# Event data: Square then sum: 0.38684764777889774
# For controls...
# Control start and end: 2005-03-01 16:15:00 2005-03-01 19:29:59
# 11882.887145855155
# Control data: Sum then square: 1.1937498975428968
# Control data: Square then sum: 1.6835766654723254
# Control start and end: 2005-03-02 05:15:00 2005-03-02 08:29:59
# 11484.735636216275
# Control data: Sum then square: -1.411586487820713
# Control data: Square then sum: 1.0372691618728413
# EVENT COUNT 175
# 195 Quake, Indian Ocean 2005-03-28 16:00:00 2005-03-28 23:59:59 28800.0
# 28897.43308823737
# Event data: Sum then square: 0.40829128965457007
# Event data: Square then sum: 0.31154612272253535
# For controls...
# Control start and end: 2005-03-28 00:00:00 2005-03-28 07:59:59
# 28815.062279915637
# Control data: Sum then square: 0.0655262233779301
# Control data: Square then sum: 0.2462241108606225
# Control start and end: 2005-03-29 08:00:00 2005-03-29 15:59:59
# 28836.3976665566
# Control data: Sum then square: 0.15437059262206804
# Control data: Square then sum: 0.22687150261181457
# EVENT COUNT 176
# 196 Pope John Paul Dies 2005-04-02 04:00:00 2005-04-02 23:59:59 72000.0
# 72096.53898311857
# Event data: Sum then square: 0.2560455701607587
# Event data: Square then sum: 0.10759214222996036
# For controls...
# Control start and end: 2005-03-31 12:00:00 2005-04-01 07:59:59
# 71877.25409305333
# Control data: Sum then square: -0.32189079157080924
# Control data: Square then sum: 0.8796009376700498
# Control start and end: 2005-04-03 20:00:00 2005-04-04 15:59:59
# 71747.57536615523
# Control data: Sum then square: -0.6642189460828138
# Control data: Square then sum: 0.3244871709788824
# EVENT COUNT 177
# 197 Pope Paul's Funeral 2005-04-08 08:00:00 2005-04-08 12:29:59 16200.0
# 16550.50120472346
# Event data: Sum then square: 1.9370572786511713
# Event data: Square then sum: 0.8202711829356426
# For controls...
# Control start and end: 2005-04-07 23:00:00 2005-04-08 03:29:59
# 16319.429691312036
# Control data: Sum then square: 0.665576224320525
# Control data: Square then sum: 0.7860412032000542
# Control start and end: 2005-04-08 17:00:00 2005-04-08 21:29:59
# 15889.156347946428
# Control data: Sum then square: -1.7343700497428294
# Control data: Square then sum: 0.7174540373108252
# EVENT COUNT 178
# 198 Prince Charles' Wedding 2005-04-09 11:00:00 2005-04-09 14:59:59 14400.0
# 14723.276677683783
# Event data: Sum then square: 1.8947759419495829
# Event data: Square then sum: -1.390978231425819
# For controls...
# Control start and end: 2005-04-09 03:00:00 2005-04-09 06:59:59
# 14193.319960579047
# Control data: Sum then square: -1.2198166084686355
# Control data: Square then sum: 0.977277968327057
# Control start and end: 2005-04-09 19:00:00 2005-04-09 22:59:59
# 14467.804776760335
# Control data: Sum then square: 0.40284493506301194
# Control data: Square then sum: 0.9779073113465763
# EVENT COUNT 179
# 199 Oraworld Resonance 2005-04-23 00:50:00 2005-04-23 14:44:59 50100.0
# 50762.510449185815
# Event data: Sum then square: 2.085898818510127
# Event data: Square then sum: 0.2965638340368322
# For controls...
# Control start and end: 2005-04-21 21:00:00 2005-04-22 10:54:59
# 50340.49610778405
# Control data: Sum then square: 0.7606490349545915
# Control data: Square then sum: 1.2715324111342095
# Control start and end: 2005-04-24 04:40:00 2005-04-24 18:34:59
# 50724.91173206263
# Control data: Sum then square: 1.9681262007445808
# Control data: Square then sum: 0.332304184739208
# EVENT COUNT 180
# 200 Live 8 Concert 2005-07-02 00:00:00 2005-07-02 23:59:59 86400.0
# Before masking, fraction of nans in raw data is 0.09175617283950617 for 2005-07-02 00:00:00 to 2005-07-02 23:59:59
# Found 'rotten egg' entries for device id: 1026 in time range 2005-07-02 00:00:00 to 2005-07-02 23:59:59 (range: 2005-07-02 00:00:00 to 2005-07-04 23:59:59 )
# After masking, fraction of nans in raw data is 0.0963804012345679
# 85651.09723572378
# Event data: Sum then square: -1.8052068968086274
# Event data: Square then sum: -1.7486703295208723
# For controls...
# Control start and end: 2005-06-30 00:00:00 2005-06-30 23:59:59
# 86135.18335419304
# Control data: Sum then square: -0.6360976992724152
# Control data: Square then sum: -0.2815842518065016
# Control start and end: 2005-07-04 00:00:00 2005-07-04 23:59:59
# Before masking, fraction of nans in raw data is 0.07662615740740741 for 2005-07-04 00:00:00 to 2005-07-04 23:59:59
# Found 'rotten egg' entries for device id: 1026 in time range 2005-07-04 00:00:00 to 2005-07-04 23:59:59 (range: 2005-07-02 00:00:00 to 2005-07-04 23:59:59 )
# After masking, fraction of nans in raw data is 0.07821813512731482
# 85552.14907542504
# Control data: Sum then square: -2.044717349931976
# Control data: Square then sum: -0.6058151008282224
# EVENT COUNT 181
# 201 London Subway Bombs 2005-07-07 00:00:00 2005-07-07 23:59:59 86400.0
# 86378.21300376246
# Event data: Sum then square: -0.05081198798951904
# Event data: Square then sum: -0.4254287241890512
# For controls...
# Control start and end: 2005-07-05 00:00:00 2005-07-05 23:59:59
# 86513.72302339373
# Control data: Sum then square: 0.2750587135517722
# Control data: Square then sum: 0.9712459641042077
# Control start and end: 2005-07-09 00:00:00 2005-07-09 23:59:59
# 87069.5630139379
# Control data: Sum then square: 1.6081789109228837
# Control data: Square then sum: -0.7838633528081894
# EVENT COUNT 182
# 202 Hurricane Katrina 2005-08-29 10:00:00 2005-08-29 23:59:59 50400.0
# 50056.94721657519
# Event data: Sum then square: -1.0808750310033037
# Event data: Square then sum: -0.6846863267576245
# For controls...
# Control start and end: 2005-08-28 06:00:00 2005-08-28 19:59:59
# 49949.41173359294
# Control data: Sum then square: -1.4213698499771212
# Control data: Square then sum: -0.04756736178265411
# Control start and end: 2005-08-30 14:00:00 2005-08-31 03:59:59
# 50204.66762790372
# Control data: Sum then square: -0.6139352761021082
# Control data: Square then sum: 0.4964055001793627
# EVENT COUNT 183
# 203 Baghdad Bridge Stampede 2005-08-31 08:00:00 2005-08-31 12:59:59 18000.0
# 18452.594677854835
# Event data: Sum then square: 2.369185145182576
# Event data: Square then sum: -3.576658102161186
# For controls...
# Control start and end: 2005-08-30 22:00:00 2005-08-31 02:59:59
# 17972.949026973023
# Control data: Sum then square: -0.13912853749921514
# Control data: Square then sum: 0.8377867525462456
# Control start and end: 2005-08-31 18:00:00 2005-08-31 22:59:59
# 18000.14001379225
# Control data: Sum then square: 0.004251584530779666
# Control data: Square then sum: 2.374806367421152
# EVENT COUNT 184
# 204 End the War Rally 2005-09-24 13:00:00 2005-09-24 19:59:59 25200.0
# 25600.419011177786
# Event data: Sum then square: 1.7772133416964544
# Event data: Square then sum: 0.9013010252372653
# For controls...
# Control start and end: 2005-09-23 23:00:00 2005-09-24 05:59:59
# 25168.13006457884
# Control data: Sum then square: -0.13904997606143701
# Control data: Square then sum: -0.3647724570829058
# Control start and end: 2005-09-25 03:00:00 2005-09-25 09:59:59
# 25670.371494771593
# Control data: Sum then square: 2.0852702525222835
# Control data: Square then sum: 0.9027786664567677
# EVENT COUNT 185
# 205 Bali Bombing 2 2005-10-01 11:30:00 2005-10-01 17:29:59 21600.0
# 22011.865037442374
# Event data: Sum then square: 1.972332438613571
# Event data: Square then sum: 0.7224302242970534
# For controls...
# Control start and end: 2005-09-30 23:30:00 2005-10-01 05:29:59
# 21940.203498817278
# Control data: Sum then square: 1.6314929498689184
# Control data: Square then sum: 1.1789019910924825
# Control start and end: 2005-10-01 23:30:00 2005-10-02 05:29:59
# 21763.46408978914
# Control data: Sum then square: 0.7876972348052944
# Control data: Square then sum: 2.3218928021451957
# EVENT COUNT 186
# 206 Earthquake Pakistan 2005-10-08 03:20:00 2005-10-08 11:19:59 28800.0
# 29103.656475009735
# Event data: Sum then square: 1.2635910894311069
# Event data: Square then sum: 0.3010654269328061
# For controls...
# Control start and end: 2005-10-07 11:20:00 2005-10-07 19:19:59
# 28976.155951887282
# Control data: Sum then square: 0.7352683432406871
# Control data: Square then sum: -0.6704575663725508
# Control start and end: 2005-10-08 19:20:00 2005-10-09 03:19:59
# 28522.639315425557
# Control data: Sum then square: -1.1566204052903717
# Control data: Square then sum: 0.003140081732415498
# EVENT COUNT 187
# 207 India Train Crash 2005-10-28 21:30:00 2005-10-29 02:29:59 18000.0
# 18075.455615730447
# Event data: Sum then square: 0.40064409651135297
# Event data: Square then sum: -0.11033383045661971
# For controls...
# Control start and end: 2005-10-28 11:30:00 2005-10-28 16:29:59
# 17837.27608779981
# Control data: Sum then square: -0.8567121179348742
# Control data: Square then sum: -1.7256967147414901
# Control start and end: 2005-10-29 07:30:00 2005-10-29 12:29:59
# 18254.245356877538
# Control data: Sum then square: 1.3372426906575643
# Control data: Square then sum: 1.3284556005348238
# EVENT COUNT 188
# 208 India Bombs 2005-10-29 11:08:00 2005-10-29 16:07:59 18000.0
# 18070.883214058085
# Event data: Sum then square: 0.37661057332335235
# Event data: Square then sum: 1.19883425674172
# For controls...
# Control start and end: 2005-10-29 01:08:00 2005-10-29 06:07:59
# 17757.179849585533
# Control data: Sum then square: -1.2820573812278242
# Control data: Square then sum: -0.38644837660680337
# Control start and end: 2005-10-29 21:08:00 2005-10-30 02:07:59
# 17953.184689980753
# Control data: Sum then square: -0.24343816997205203
# Control data: Square then sum: 0.11651617573429103
# EVENT COUNT 189
# 209 Jordan Bombs 2005-11-09 18:00:00 2005-11-09 22:59:59 18000.0
# 18320.014445645273
# Event data: Sum then square: 1.6802398285487945
# Event data: Square then sum: 0.2392510941452787
# For controls...
# Control start and end: 2005-11-09 08:00:00 2005-11-09 12:59:59
# 18262.917081989577
# Control data: Sum then square: 1.382514274373662
# Control data: Square then sum: 0.965098102006161
# Control start and end: 2005-11-10 04:00:00 2005-11-10 08:59:59
# 17965.268403208018
# Control data: Sum then square: -0.17965523857760277
# Control data: Square then sum: -2.1819962191382434
# EVENT COUNT 190
# 211 New Year Covar Min 2005-12-31 23:55:00 2006-01-01 00:04:59 600.0
# 542.8700188097837
# Event data: Sum then square: -1.685255221176204
# Event data: Square then sum: 0.833506537904735
# For controls...
# Control start and end: 2005-12-31 23:35:00 2005-12-31 23:44:59
# 595.3548531440383
# Control data: Sum then square: -0.1151824657779282
# Control data: Square then sum: -1.3772495776606744
# Control start and end: 2006-01-01 00:15:00 2006-01-01 00:24:59
# 588.0548382694457
# Control data: Sum then square: -0.32786374093971066
# Control data: Square then sum: -0.3075365185399508
# EVENT COUNT 191
# 212 Hadj Stoning 2006 2006-01-12 08:00:00 2006-01-12 11:59:59 14400.0
# 14587.883087935224
# Event data: Sum then square: 1.1062571708494557
# Event data: Square then sum: 0.4837385850953552
# For controls...
# Control start and end: 2006-01-12 00:00:00 2006-01-12 03:59:59
# 14509.716671395323
# Control data: Sum then square: 0.6488028713106251
# Control data: Square then sum: -1.0776099230724228
# Control start and end: 2006-01-12 16:00:00 2006-01-12 19:59:59
# 14512.67228153276
# Control data: Sum then square: 0.6661298494912885
# Control data: Square then sum: 0.9967142760722347
# EVENT COUNT 192
# 213 Mudslide, Philippines 2006-02-17 00:00:00 2006-02-17 23:59:59 86400.0
# 86925.80871200934
# Event data: Sum then square: 1.2639452303011014
# Event data: Square then sum: -0.5235984084065487
# For controls...
# Control start and end: 2006-02-15 00:00:00 2006-02-15 23:59:59
# 86722.80646726117
# Control data: Sum then square: 0.7771899112611003
# Control data: Square then sum: 0.045322997019221434
# Control start and end: 2006-02-19 00:00:00 2006-02-19 23:59:59
# 86208.89962634556
# Control data: Sum then square: -0.4584513760807567
# Control data: Square then sum: -0.44319332527115823
# EVENT COUNT 193
# 214 Golden Dome Bomb 2006-02-22 03:00:00 2006-02-22 06:59:59 14400.0
# 14289.985970446854
# Event data: Sum then square: -0.6459912740056926
# Event data: Square then sum: 1.5675777158182058
# For controls...
# Control start and end: 2006-02-21 19:00:00 2006-02-21 22:59:59
# 14420.006135499032
# Control data: Sum then square: 0.12176066351760147
# Control data: Square then sum: 0.8299467642626188
# Control start and end: 2006-02-22 11:00:00 2006-02-22 14:59:59
# 14287.020857940362
# Control data: Sum then square: -0.6635541035858337
# Control data: Square then sum: 0.23127568065884035
# EVENT COUNT 194
# 215 Planetary Play 2006-04-01 17:45:00 2006-04-01 18:14:59 1800.0
# 1799.0269411237948
# Event data: Sum then square: -0.005108662481941386
# Event data: Square then sum: 0.5086221357721872
# For controls...
# Control start and end: 2006-04-01 16:45:00 2006-04-01 17:14:59
# 1849.579299391911
# Control data: Sum then square: 0.8299406426303088
# Control data: Square then sum: 1.2625944259875466
# Control start and end: 2006-04-01 18:45:00 2006-04-01 19:14:59
# 1815.867230721819
# Control data: Sum then square: 0.27478402127860974
# Control data: Square then sum: 1.1823886478408465
# EVENT COUNT 195
# 216 Earth Day, 2006 2006-04-22 00:00:00 2006-04-22 23:59:59 86400.0
# 86822.53348487121
# Event data: Sum then square: 1.0164084255711474
# Event data: Square then sum: 0.06960225494188817
# For controls...
# Control start and end: 2006-04-20 00:00:00 2006-04-20 23:59:59
# 86469.04097377748
# Control data: Sum then square: 0.1676461962971591
# Control data: Square then sum: 0.35401864787586423
# Control start and end: 2006-04-24 00:00:00 2006-04-24 23:59:59
# 86540.25074987307
# Control data: Sum then square: 0.3388120158384435
# Control data: Square then sum: 0.8318688953203488
# EVENT COUNT 196
# 217 Indonesian Earthquake 2006-05-26 21:54:00 2006-05-27 05:53:59 28800.0
# Before masking, fraction of nans in raw data is 0.07701361726785455 for 2006-05-27 00:00:00 to 2006-05-27 05:53:59
# Found 'rotten egg' entries for device id: 161 in time range 2006-05-27 00:00:00 to 2006-05-27 05:53:59 (range: 2006-05-01 00:00:00 to 2006-05-31 23:59:59 )
# After masking, fraction of nans in raw data is 0.07701361726785455
# 29443.76847605958
# Event data: Sum then square: 2.665411526690543
# Event data: Square then sum: 0.5818333373567108
# For controls...
# Control start and end: 2006-05-26 05:54:00 2006-05-26 13:53:59
# 29092.868375562117
# Control data: Sum then square: 1.2189483230280103
# Control data: Square then sum: 0.7941943557195348
# Control start and end: 2006-05-27 13:54:00 2006-05-27 21:53:59
# Before masking, fraction of nans in raw data is 0.07135149572649573 for 2006-05-27 13:54:00 to 2006-05-27 21:53:59
# Found 'rotten egg' entries for device id: 161 in time range 2006-05-27 13:54:00 to 2006-05-27 21:53:59 (range: 2006-05-01 00:00:00 to 2006-05-31 23:59:59 )
# After masking, fraction of nans in raw data is 0.08673611111111111
# 28813.24238099576
# Control data: Sum then square: 0.05794580892947893
# Control data: Square then sum: -1.2033562170437684
# EVENT COUNT 197
# 218 Zarkawi News Release 2006-06-08 07:00:00 2006-06-08 14:59:59 28800.0
# 28521.71711458021
# Event data: Sum then square: -1.1604878231913016
# Event data: Square then sum: -1.1841822735140441
# For controls...
# Control start and end: 2006-06-07 15:00:00 2006-06-07 22:59:59
# 29147.73495564209
# Control data: Sum then square: 1.4458799916738272
# Control data: Square then sum: 0.133028423764093
# Control start and end: 2006-06-08 23:00:00 2006-06-09 06:59:59
# 28711.967869512628
# Control data: Sum then square: -0.364396450398048
# Control data: Square then sum: 0.30619813520426264
# EVENT COUNT 198
# 219 Bombay Train Bombings 2006-07-11 11:24:00 2006-07-11 16:23:59 18000.0
# 18158.55193181043
# Event data: Sum then square: 0.8367120949643239
# Event data: Square then sum: -0.6619047636002255
# For controls...
# Control start and end: 2006-07-11 01:24:00 2006-07-11 06:23:59
# 17979.58710342614
# Control data: Sum then square: -0.10411212394518388
# Control data: Square then sum: 0.0755125218278286
# Control start and end: 2006-07-11 21:24:00 2006-07-12 02:23:59
# 17797.273893199937
# Control data: Sum then square: -1.0689811985772733
# Control data: Square then sum: -0.13464151282756298
# EVENT COUNT 199
# 220 Avebury Meditations 2006-07-22 22:00:00 2006-07-22 22:59:59 3600.0
# 3687.683904397138
# Event data: Sum then square: 1.0329331998881028
# Event data: Square then sum: -0.8958441272524821
# For controls...
# Control start and end: 2006-07-22 20:00:00 2006-07-22 20:59:59
# 3479.7162860187664
# Control data: Sum then square: -1.4257811320048748
# Control data: Square then sum: 0.6019019336115476
# Control start and end: 2006-07-23 00:00:00 2006-07-23 00:59:59
# 3543.4387715141347
# Control data: Sum then square: -0.6622366174855108
# Control data: Square then sum: 1.7276926269124915
# EVENT COUNT 200
# 221 Qana Lebanon 2006-07-30 01:00:00 2006-07-30 05:59:59 18000.0
# 18274.50840534247
# Event data: Sum then square: 1.4430055567559372
# Event data: Square then sum: 0.00936764861743022
# For controls...
# Control start and end: 2006-07-29 15:00:00 2006-07-29 19:59:59
# 17915.237988559988
# Control data: Sum then square: -0.4439231509931585
# Control data: Square then sum: 0.5063639001161148
# Control start and end: 2006-07-30 11:00:00 2006-07-30 15:59:59
# 18094.27408823885
# Control data: Sum then square: 0.49951539228261443
# Control data: Square then sum: 0.05776729582711445
# EVENT COUNT 201
# 222 British Terror Plot 2006-08-10 00:00:00 2006-08-10 23:59:59 86400.0
# 86979.34491156325
# Event data: Sum then square: 1.3921871700632646
# Event data: Square then sum: -0.6089177883854078
# For controls...
# Control start and end: 2006-08-08 00:00:00 2006-08-08 23:59:59
# 86230.17879733125
# Control data: Sum then square: -0.4071902699466214
# Control data: Square then sum: -0.6149827197171507
# Control start and end: 2006-08-12 00:00:00 2006-08-12 23:59:59
# 86167.9478540193
# Control data: Sum then square: -0.5571271407574727
# Control data: Square then sum: 0.7239273584258712
# EVENT COUNT 202
# 224 Oraworld Reconciliation 2006-10-02 12:00:00 2006-10-02 23:59:59 43200.0
# 43160.005065450336
# Event data: Sum then square: -0.13383931976670377
# Event data: Square then sum: 0.6623119878693638
# For controls...
# Control start and end: 2006-10-01 12:00:00 2006-10-01 23:59:59
# 43261.69923640845
# Control data: Sum then square: 0.21207299641055594
# Control data: Square then sum: 0.9740763304720613
# Control start and end: 2006-10-03 12:00:00 2006-10-03 23:59:59
# 43258.29335235027
# Control data: Sum then square: 0.20049667349626357
# Control data: Square then sum: 0.28338000784584383
# EVENT COUNT 203
# 225 Native American Earth Ceremony 2006-10-07 03:00:00 2006-10-07 03:14:59 900.0
# 924.6374358325518
# Event data: Sum then square: 0.5911727948710884
# Event data: Square then sum: 0.6538155222859285
# For controls...
# Control start and end: 2006-10-07 02:30:00 2006-10-07 02:44:59
# 886.869222537475
# Control data: Sum then square: -0.2952799769158362
# Control data: Square then sum: 2.3141681034474804
# Control start and end: 2006-10-07 03:30:00 2006-10-07 03:44:59
# 877.4203460545393
# Control data: Sum then square: -0.5209771789329689
# Control data: Square then sum: -1.026146199027077
# EVENT COUNT 204
# 226 Election 2006 Results 2006-11-08 13:00:00 2006-11-08 20:59:59 28800.0
# 29099.233447094084
# Event data: Sum then square: 1.2452892728626876
# Event data: Square then sum: -1.1053230756391654
# For controls...
# Control start and end: 2006-11-07 21:00:00 2006-11-08 04:59:59
# 28612.87081192679
# Control data: Sum then square: -0.7786208121834028
# Control data: Square then sum: -0.2836025565553824
# Control start and end: 2006-11-09 05:00:00 2006-11-09 12:59:59
# 28806.94461247384
# Control data: Sum then square: 0.03171128645029162
# Control data: Square then sum: 1.229077644709133
# EVENT COUNT 205
# 227 Gemayel Assassination 2006-11-21 10:00:00 2006-11-21 13:59:59 14400.0
# 14229.225430608709
# Event data: Sum then square: -1.0063722833769797
# Event data: Square then sum: -0.16800317985473837
# For controls...
# Control start and end: 2006-11-21 02:00:00 2006-11-21 05:59:59
# 14620.950186258018
# Control data: Sum then square: 1.2992848204868932
# Control data: Square then sum: 0.43477523262087064
# Control start and end: 2006-11-21 18:00:00 2006-11-21 21:59:59
# 14211.35241625893
# Control data: Sum then square: -1.1125755487662374
# Control data: Square then sum: 0.5209369817402211
# EVENT COUNT 206
# 228 Global Deeksha 2006-11-23 16:30:00 2006-11-23 17:29:59 3600.0
# 3584.3430451895556
# Event data: Sum then square: -0.17692746492635203
# Event data: Square then sum: -0.6730014645661909
# For controls...
# Control start and end: 2006-11-23 14:30:00 2006-11-23 15:29:59
# 3595.0849928162916
# Control data: Sum then square: -0.050092555672097194
# Control data: Square then sum: -0.15543422950595173
# Control start and end: 2006-11-23 18:30:00 2006-11-23 19:29:59
# 3564.1816985260625
# Control data: Sum then square: -0.4156675058223539
# Control data: Square then sum: -0.8066378295373012
# EVENT COUNT 207
# 229 Global Orgasm 2006-12-22 00:00:00 2006-12-22 23:59:59 86400.0
# 86602.69497454911
# Event data: Sum then square: 0.48883097401815845
# Event data: Square then sum: -0.8388250565906828
# For controls...
# Control start and end: 2006-12-20 00:00:00 2006-12-20 23:59:59
# 86644.64143337187
# Control data: Sum then square: 0.5895646512917081
# Control data: Square then sum: 1.0604953727555233
# Control start and end: 2006-12-24 00:00:00 2006-12-24 23:59:59
# 86086.52785385877
# Control data: Sum then square: -0.7534064731648866
# Control data: Square then sum: -0.877110456788355
# EVENT COUNT 208
# 230 Saddam's Execution 2006-12-30 03:00:00 2006-12-30 16:59:59 50400.0
# 50411.7911338999
# Event data: Sum then square: 0.0392354488130849
# Event data: Square then sum: -0.9407564991388716
# For controls...
# Control start and end: 2006-12-28 23:00:00 2006-12-29 12:59:59
# 50556.98055391677
# Control data: Sum then square: 0.4960291148975388
# Control data: Square then sum: 1.0159514363242612
# Control start and end: 2006-12-31 07:00:00 2006-12-31 20:59:59
# 50098.50063187668
# Control data: Sum then square: -0.9494331413072932
# Control data: Square then sum: -0.9658510755445499
# EVENT COUNT 209
# 231 New Year Mean 2006-2007 2006-12-31 09:30:00 2007-01-01 12:29:59 97200.0
# 97125.43386322878
# Event data: Sum then square: -0.16765056996657024
# Event data: Square then sum: -0.7395609298706577
# For controls...
# Control start and end: 2006-12-29 03:30:00 2006-12-30 06:29:59
# 97098.88629913279
# Control data: Sum then square: -0.2278979378559917
# Control data: Square then sum: 1.4839548572477692
# Control start and end: 2007-01-02 15:30:00 2007-01-03 18:29:59
# 96418.86358493827
# Control data: Sum then square: -1.774908588673349
# Control data: Square then sum: 0.5067486718237935
# EVENT COUNT 210
# 233 European Storms 2007-01-18 00:00:00 2007-01-18 23:59:59 86400.0
# 86919.54414950561
# Event data: Sum then square: 1.2489355028827678
# Event data: Square then sum: -1.3311799158620157
# For controls...
# Control start and end: 2007-01-16 00:00:00 2007-01-16 23:59:59
# 86365.05646371622
# Control data: Sum then square: -0.08246861316980995
# Control data: Square then sum: -0.23664879170861736
# Control start and end: 2007-01-20 00:00:00 2007-01-20 23:59:59
# 86713.83127506802
# Control data: Sum then square: 0.755651828873521
# Control data: Square then sum: 0.20267823698105286
# EVENT COUNT 211
# 234 Iraq Worst Bombing 2007-02-03 16:00:00 2007-02-03 20:59:59 18000.0
# 18137.62916783131
# Event data: Sum then square: 0.7270402841543899
# Event data: Square then sum: -0.865660607758601
# For controls...
# Control start and end: 2007-02-03 06:00:00 2007-02-03 10:59:59
# 18128.429929156835
# Control data: Sum then square: 0.6787935361713201
# Control data: Square then sum: -0.8161917978245864
# Control start and end: 2007-02-04 02:00:00 2007-02-04 06:59:59
# 18077.75778855865
# Control data: Sum then square: 0.412743276796011
# Control data: Square then sum: 0.22737151954200888
# EVENT COUNT 212
# 235 World Sound Healing 2007-02-14 00:00:00 2007-02-14 23:59:59 86400.0
# 86359.74972803266
# Event data: Sum then square: -0.0952383317703916
# Event data: Square then sum: -0.8913187775678606
# For controls...
# Control start and end: 2007-02-12 00:00:00 2007-02-12 23:59:59
# 86358.43273306222
# Control data: Sum then square: -0.09840752770460541
# Control data: Square then sum: 1.6509267620210908
# Control start and end: 2007-02-16 00:00:00 2007-02-16 23:59:59
# 86590.52015606881
# Control data: Sum then square: 0.459587274128496
# Control data: Square then sum: -0.49136001422535736
# EVENT COUNT 213
# 236 India Train Fire 2007-02-18 17:30:00 2007-02-18 22:29:59 18000.0
# 17782.040069057064
# Event data: Sum then square: -1.149902212896182
# Event data: Square then sum: 0.7973246532128824
# For controls...
# Control start and end: 2007-02-18 07:30:00 2007-02-18 12:29:59
# 18328.532175989647
# Control data: Sum then square: 1.7246012690717782
# Control data: Square then sum: 1.0521742556615699
# Control start and end: 2007-02-19 03:30:00 2007-02-19 08:29:59
# 18224.17508091459
# Control data: Sum then square: 1.1801468696487407
# Control data: Square then sum: -0.9708356076233733
# EVENT COUNT 214
# 237 Earth Hour 2007-03-31 09:30:00 2007-03-31 10:29:59 3600.0
# 3525.8046560747457
# Event data: Sum then square: -0.8726104354635895
# Event data: Square then sum: -1.0701366171161772
# For controls...
# Control start and end: 2007-03-31 07:30:00 2007-03-31 08:29:59
# 3727.2612354448174
# Control data: Sum then square: 1.4903050290489088
# Control data: Square then sum: 0.3055584350457512
# Control start and end: 2007-03-31 11:30:00 2007-03-31 12:29:59
# 3653.1798506580226
# Control data: Sum then square: 0.6315180342399348
# Control data: Square then sum: -0.059570952036658825
# EVENT COUNT 215
# 238 Solomon Islands Quake 2007-04-01 19:00:00 2007-04-01 23:59:59 18000.0
# 18130.44843683602
# Event data: Sum then square: 0.6893812905529744
# Event data: Square then sum: 0.03717589727063199
# For controls...
# Control start and end: 2007-04-01 09:00:00 2007-04-01 13:59:59
# 18279.886724559023
# Control data: Sum then square: 1.4710645489151026
# Control data: Square then sum: 1.6733549527278855
# Control start and end: 2007-04-02 05:00:00 2007-04-02 09:59:59
# 18052.909668009426
# Control data: Sum then square: 0.28209846624776835
# Control data: Square then sum: -0.37461280647616696
# EVENT COUNT 216
# 239 Massacre at Virginia Tech 2007-04-16 10:00:00 2007-04-16 16:59:59 25200.0
# 25481.011706055768
# Event data: Sum then square: 1.2500697121856894
# Event data: Square then sum: 0.747624644727705
# For controls...
# Control start and end: 2007-04-15 20:00:00 2007-04-16 02:59:59
# 24958.960316776596
# Control data: Sum then square: -1.0741466253236713
# Control data: Square then sum: -0.023641571836001848
# Control start and end: 2007-04-17 00:00:00 2007-04-17 06:59:59
# 25071.279872353556
# Control data: Sum then square: -0.5713733360443818
# Control data: Square then sum: -0.04205683660287532
# EVENT COUNT 217
# 240 Tai Chi Chigong Day 2007-04-28 00:00:00 2007-04-28 23:59:59 86400.0
# 86598.137882818
# Event data: Sum then square: 0.4778852407219299
# Event data: Square then sum: 0.45813994446931255
# For controls...
# Control start and end: 2007-04-26 00:00:00 2007-04-26 23:59:59
# 86394.44134635969
# Control data: Sum then square: -0.011768568938173298
# Control data: Square then sum: 0.0042950682374151405
# Control start and end: 2007-04-30 00:00:00 2007-04-30 23:59:59
# 86422.82886055301
# Control data: Sum then square: 0.056516583512035805
# Control data: Square then sum: 0.24518330164613653
# EVENT COUNT 218
# 241 World Meditation Aggregation 2007-05-20 04:00:00 2007-05-20 06:59:59 10800.0
# 10604.838327767982
# Event data: Sum then square: -1.331448050390133
# Event data: Square then sum: 0.7960024705024081
# For controls...
# Control start and end: 2007-05-19 22:00:00 2007-05-20 00:59:59
# 10635.286607560614
# Control data: Sum then square: -1.1219395296150014
# Control data: Square then sum: -1.4844047011723367
# Control start and end: 2007-05-20 10:00:00 2007-05-20 12:59:59
# 10575.601479358467
# Control data: Sum then square: -1.532999273571818
# Control data: Square then sum: 0.06977325642069561
# EVENT COUNT 219
# 242 Lightning Strikes Giuliani 2007-06-06 23:00:00 2007-06-06 23:59:59 3600.0
# 3649.590630700087
# Event data: Sum then square: 0.5896168665313851
# Event data: Square then sum: 1.4848620473678706
# For controls...
# Control start and end: 2007-06-06 21:00:00 2007-06-06 21:59:59
# 3691.1182590191747
# Control data: Sum then square: 1.0727509949627416
# Control data: Square then sum: 0.06267576052530235
# Control start and end: 2007-06-07 01:00:00 2007-06-07 01:59:59
# 3528.9253785360756
# Control data: Sum then square: -0.835329342828141
# Control data: Square then sum: -0.23695981796958215
# EVENT COUNT 220
# 243 Palestinian Government Falls 2007-06-14 00:00:00 2007-06-14 23:59:59 86400.0
# 86699.8018952531
# Event data: Sum then square: 0.7219820593141508
# Event data: Square then sum: 1.0011133836156816
# For controls...
# Control start and end: 2007-06-12 00:00:00 2007-06-12 23:59:59
# 86386.7929182477
# Control data: Sum then square: -0.03016914777762477
# Control data: Square then sum: 0.7492269734453697
# Control start and end: 2007-06-16 00:00:00 2007-06-16 23:59:59
# 86127.0874608015
# Control data: Sum then square: -0.6556138934226212
# Control data: Square then sum: -0.8359893510701681
# EVENT COUNT 221
# 244 Live Earth 2007-07-07 00:00:00 2007-07-07 23:59:59 86400.0
# 86555.75553180999
# Event data: Sum then square: 0.37606816901195084
# Event data: Square then sum: -1.0412271682453085
# For controls...
# Control start and end: 2007-07-05 00:00:00 2007-07-05 23:59:59
# 86484.2077364938
# Control data: Sum then square: 0.2041101785763586
# Control data: Square then sum: -0.8539729679597897
# Control start and end: 2007-07-09 00:00:00 2007-07-09 23:59:59
# 85858.92950595681
# Control data: Sum then square: -1.3027357629937677
# Control data: Square then sum: 0.7621239010560598
# EVENT COUNT 222
# ...
# Found 'rotten egg' entries for device id: 1251 in time range 2014-09-19 00:00:00 to 2014-09-19 23:59:59 (range: 2014-03-14 00:00:00 to 2024-02-13 20:05:18 )
# After masking, fraction of nans in raw data is 0.06983311800172265
# 85926.76800248078
# Control data: Sum then square: -1.1388998944889956
# Control data: Square then sum: 0.11560408538993412
# Control start and end: 2014-09-23 00:00:00 2014-09-23 23:59:59
# Before masking, fraction of nans in raw data is 0.029715057319223987 for 2014-09-23 00:00:00 to 2014-09-23 23:59:59
# Found 'rotten egg' entries for device id: 1251 in time range 2014-09-23 00:00:00 to 2014-09-23 23:59:59 (range: 2014-03-14 00:00:00 to 2024-02-13 20:05:18 )
# After masking, fraction of nans in raw data is 0.0535245811287478
# 86682.99120626062
# Control data: Sum then square: 0.6816325121702131
# Control data: Square then sum: -0.03137116837615276
# EVENT COUNT 457
# 488 Ottowa Terror Shooting 2014-09-22 14:00:00 2014-09-22 19:59:59 21600.0
# Before masking, fraction of nans in raw data is 0.044891975308641974 for 2014-09-22 14:00:00 to 2014-09-22 19:59:59
# Found 'rotten egg' entries for device id: 1251 in time range 2014-09-22 14:00:00 to 2014-09-22 19:59:59 (range: 2014-03-14 00:00:00 to 2024-02-13 20:05:18 )
# After masking, fraction of nans in raw data is 0.06870149911816578
# 21537.4642641306
# Event data: Sum then square: -0.2979577695746314
# Event data: Square then sum: -1.1078318831977876
# For controls...
# Control start and end: 2014-09-22 02:00:00 2014-09-22 07:59:59
# Before masking, fraction of nans in raw data is 0.02382936507936508 for 2014-09-22 02:00:00 to 2014-09-22 07:59:59
# Found 'rotten egg' entries for device id: 1251 in time range 2014-09-22 02:00:00 to 2014-09-22 07:59:59 (range: 2014-03-14 00:00:00 to 2024-02-13 20:05:18 )
# After masking, fraction of nans in raw data is 0.04763888888888889
# 21829.50945762718
# Control data: Sum then square: 1.103545665711846
# Control data: Square then sum: -0.17954280841146758
# Control start and end: 2014-09-23 02:00:00 2014-09-23 07:59:59
# Before masking, fraction of nans in raw data is 0.02984567901234568 for 2014-09-23 02:00:00 to 2014-09-23 07:59:59
# Found 'rotten egg' entries for device id: 1251 in time range 2014-09-23 02:00:00 to 2014-09-23 07:59:59 (range: 2014-03-14 00:00:00 to 2024-02-13 20:05:18 )
# After masking, fraction of nans in raw data is 0.05365520282186949
# 21640.330037774274
# Control data: Sum then square: 0.19712436114092668
# Control data: Square then sum: -1.3978660299745278
# EVENT COUNT 458
# 489 Nigeria School Bombing 2014-11-10 07:00:00 2014-11-10 12:59:59 21600.0
# 21316.89412181059
# Event data: Sum then square: -1.36487955793773
# Event data: Square then sum: 0.6069794957501388
# For controls...
# Control start and end: 2014-11-09 19:00:00 2014-11-10 00:59:59
# 21283.040292033715
# Control data: Sum then square: -1.529285348014972
# Control data: Square then sum: 0.9053192183098452
# Control start and end: 2014-11-10 19:00:00 2014-11-11 00:59:59
# 21312.801708968946
# Control data: Sum then square: -1.3847444521343246
# Control data: Square then sum: -0.03767046297890212
# EVENT COUNT 459
# 490 Sydney Hostage Crisis 2014-12-14 22:00:00 2014-12-15 15:59:59 64800.0
# 64519.31912750211
# Event data: Sum then square: -0.7789451315448818
# Event data: Square then sum: -1.2374749332456239
# For controls...
# Control start and end: 2014-12-13 10:00:00 2014-12-14 03:59:59
# 64470.01684933294
# Control data: Sum then square: -0.9163277720018099
# Control data: Square then sum: 0.1778934538937983
# Control start and end: 2014-12-16 10:00:00 2014-12-17 03:59:59
# 65161.23635407126
# Control data: Sum then square: 1.003426757930015
# Control data: Square then sum: -0.016332613370330273
# EVENT COUNT 460
# 491 Pakistani School Slaughter 2014-12-16 05:00:00 2014-12-16 14:59:59 36000.0
# 36059.28589954225
# Event data: Sum then square: 0.22330851476230676
# Event data: Square then sum: -0.6414802928890364
# For controls...
# Control start and end: 2014-12-15 09:00:00 2014-12-15 18:59:59
# 36055.42569224039
# Control data: Sum then square: 0.2089376526002324
# Control data: Square then sum: -0.4894352594166361
# Control start and end: 2014-12-17 01:00:00 2014-12-17 10:59:59
# 36138.688912541904
# Control data: Sum then square: 0.5186845414087559
# Control data: Square then sum: -0.09252408416562503
# EVENT COUNT 461
# 492 Winter Solstice 2014-12-21 00:00:00 2014-12-21 23:59:59 86400.0
# 86020.51852530029
# Event data: Sum then square: -0.9126261599367942
# Event data: Square then sum: -0.13099370174752167
# For controls...
# Control start and end: 2014-12-19 00:00:00 2014-12-19 23:59:59
# 86894.1729621475
# Control data: Sum then square: 1.1881394311012539
# Control data: Square then sum: 0.1298538570469239
# Control start and end: 2014-12-23 00:00:00 2014-12-23 23:59:59
# 86551.88738532168
# Control data: Sum then square: 0.36677388799794197
# Control data: Square then sum: 1.1354466645921835
# EVENT COUNT 462
# 493 Air Asia Loss 2014-12-28 00:00:00 2014-12-28 05:59:59 21600.0
# 21753.293927297575
# Event data: Sum then square: 0.7390038058228025
# Event data: Square then sum: 1.0633855648039219
# For controls...
# Control start and end: 2014-12-27 12:00:00 2014-12-27 17:59:59
# 21658.037750335476
# Control data: Sum then square: 0.28219134424431747
# Control data: Square then sum: -0.5149439431661479
# Control start and end: 2014-12-28 12:00:00 2014-12-28 17:59:59
# 21665.11874768097
# Control data: Sum then square: 0.3161951331348221
# Control data: Square then sum: -1.1706788520962894
# EVENT COUNT 463
# 494 New Year Mean 2015 2014-12-31 09:30:00 2015-01-01 12:29:59 97200.0
# 97565.9923216917
# Event data: Sum then square: 0.8305594250636056
# Event data: Square then sum: 0.3301694546384667
# For controls...
# Control start and end: 2014-12-29 03:30:00 2014-12-30 06:29:59
# 96948.46396535623
# Control data: Sum then square: -0.5694758112011444
# Control data: Square then sum: -0.8003999966770826
# Control start and end: 2015-01-02 15:30:00 2015-01-03 18:29:59
# 96590.06656032332
# Control data: Sum then square: -1.3847484862776316
# Control data: Square then sum: -0.7625517216071396
# EVENT COUNT 464
# 496 Charlie Hebdo & Yemen 2015-01-07 05:00:00 2015-01-07 16:59:59 43200.0
# 43501.05821043107
# Event data: Sum then square: 1.0241179464374324
# Event data: Square then sum: 0.9665040606975716
# For controls...
# Control start and end: 2015-01-06 05:00:00 2015-01-06 16:59:59
# 43001.374106003444
# Control data: Sum then square: -0.6745085241005687
# Control data: Square then sum: -0.5380849520558612
# Control start and end: 2015-01-08 05:00:00 2015-01-08 16:59:59
# 43446.12464922876
# Control data: Sum then square: 0.8380151109249617
# Control data: Square then sum: 0.7379827727680387
# EVENT COUNT 465
# 497 Millions Rally for Unity 2015-01-11 12:00:00 2015-01-11 23:59:59 43200.0
# 43256.697762610376
# Event data: Sum then square: 0.19507318475113317
# Event data: Square then sum: 0.11228568853390647
# For controls...
# Control start and end: 2015-01-10 12:00:00 2015-01-10 23:59:59
# 42908.75827798527
# Control data: Sum then square: -0.9907905475911079
# Control data: Square then sum: 0.48357050654806794
# Control start and end: 2015-01-12 12:00:00 2015-01-12 23:59:59
# 43651.7975936338
# Control data: Sum then square: 1.5339868718164196
# Control data: Square then sum: -0.874521133472874
# EVENT COUNT 466
# 498 Terror attacks in Denmark 2015-02-14 14:30:00 2015-02-15 00:29:59 36000.0
# 35790.708338215394
# Event data: Sum then square: -0.7790149089620523
# Event data: Square then sum: 1.0304120269395176
# For controls...
# Control start and end: 2015-02-13 18:30:00 2015-02-14 04:29:59
# 35772.03541096995
# Control data: Sum then square: -0.8488879452661838
# Control data: Square then sum: 0.43203208511163244
# Control start and end: 2015-02-15 10:30:00 2015-02-15 20:29:59
# 36039.0268634672
# Control data: Sum then square: 0.14787630708957888
# Control data: Square then sum: 0.3101491112967317
# EVENT COUNT 467
# 499 ISIS beheads Copts in Libya 2015-02-15 18:00:00 2015-02-15 23:59:59 21600.0
# 21802.784097460757
# Event data: Sum then square: 0.9758138930229204
# Event data: Square then sum: 0.8066047116214555
# For controls...
# Control start and end: 2015-02-15 06:00:00 2015-02-15 11:59:59
# 21623.1481019988
# Control data: Sum then square: 0.11453882031625506
# Control data: Square then sum: 0.010509625831990483
# Control start and end: 2015-02-16 06:00:00 2015-02-16 11:59:59
# 21448.473322585356
# Control data: Sum then square: -0.7275354415683128
# Control data: Square then sum: 1.26842837784613
# EVENT COUNT 468
# 500 Yemen Mosque Bombings 2015-03-20 08:00:00 2015-03-20 13:59:59 21600.0
# 21486.270330426214
# Event data: Sum then square: -0.5449365225374797
# Event data: Square then sum: -0.0514759309416654
# For controls...
# Control start and end: 2015-03-19 20:00:00 2015-03-20 01:59:59
# 21322.992278978592
# Control data: Sum then square: -1.3352833443854109
# Control data: Square then sum: 0.27035586235977044
# Control start and end: 2015-03-20 20:00:00 2015-03-21 01:59:59
# 21219.533400931497
# Control data: Sum then square: -1.8381680547240458
# Control data: Square then sum: -0.16084468915273148
# EVENT COUNT 469
# 501 Germanwings Crash 2015-03-24 09:30:00 2015-03-24 15:29:59 21600.0
# 21395.417318811942
# Event data: Sum then square: -0.9842136887537772
# Event data: Square then sum: 0.9181775987607615
# For controls...
# Control start and end: 2015-03-23 21:30:00 2015-03-24 03:29:59
# 21916.71921999391
# Control data: Sum then square: 1.5196348591764668
# Control data: Square then sum: -0.2474923298359098
# Control start and end: 2015-03-24 21:30:00 2015-03-25 03:29:59
# 21636.314677531947
# Control data: Sum then square: 0.17782831454577105
# Control data: Square then sum: -0.5308106325921043
# EVENT COUNT 470
# 502 Global Meditation Day 2015-04-22 03:00:00 2015-04-22 17:59:59 54000.0
# 53760.08646921065
# Event data: Sum then square: -0.7290882222056878
# Event data: Square then sum: -1.7169463480303733
# For controls...
# Control start and end: 2015-04-20 21:00:00 2015-04-21 11:59:59
# 54191.80226856081
# Control data: Sum then square: 0.5849741453048283
# Control data: Square then sum: -0.029199780686765563
# Control start and end: 2015-04-23 09:00:00 2015-04-23 23:59:59
# 54452.64961344368
# Control data: Sum then square: 1.3755662581523522
# Control data: Square then sum: -1.1960181266447723
# EVENT COUNT 471
# 503 Nepal Earthquake 2015-04-25 05:15:00 2015-04-26 05:14:59 86400.0
# 86348.8836262075
# Event data: Sum then square: -0.12138731176818242
# Event data: Square then sum: -1.4992629974007925
# For controls...
# Control start and end: 2015-04-23 05:15:00 2015-04-24 05:14:59
# 86507.63034875333
# Control data: Sum then square: 0.26041452831244716
# Control data: Square then sum: -1.4927788471172083
# Control start and end: 2015-04-27 05:15:00 2015-04-28 05:14:59
# 86162.10952458974
# Control data: Sum then square: -0.5711974942412775
# Control data: Square then sum: 0.3467475988504256
# EVENT COUNT 472
# 504 Fuji Peace Declaration 2015-05-17 01:00:00 2015-05-17 04:59:59 14400.0
# 14378.164083193238
# Event data: Sum then square: -0.12480558789703228
# Event data: Square then sum: 0.9325469221270696
# For controls...
# Control start and end: 2015-05-16 17:00:00 2015-05-16 20:59:59
# 14398.169790786736
# Control data: Sum then square: -0.00685664239927293
# Control data: Square then sum: 1.0494491887668365
# Control start and end: 2015-05-17 09:00:00 2015-05-17 12:59:59
# 14383.879255123684
# Control data: Sum then square: -0.0910991204623562
# Control data: Square then sum: -0.20677617674833113
# EVENT COUNT 473
# 505 Charleston Hate Crime 2015-05-18 00:00:00 2015-05-18 07:59:59 28800.0
# 28621.887993354096
# Event data: Sum then square: -0.7408895815833281
# Event data: Square then sum: 0.10918963841708879
# For controls...
# Control start and end: 2015-05-17 08:00:00 2015-05-17 15:59:59
# 29012.310089083312
# Control data: Sum then square: 0.8852369677936173
# Control data: Square then sum: -0.7212208253511307
# Control start and end: 2015-05-18 16:00:00 2015-05-18 23:59:59
# 29082.534666982618
# Control data: Sum then square: 1.176175552728408
# Control data: Square then sum: 0.41993437644540177
# EVENT COUNT 474
# 506 Iran Nuclear Deal 2015-07-14 10:25:00 2015-07-14 16:24:59 21600.0
# 21871.10115851227
# Event data: Sum then square: 1.30212293240574
# Event data: Square then sum: 0.12818987142891472
# For controls...
# Control start and end: 2015-07-13 22:25:00 2015-07-14 04:24:59
# 21757.687262230036
# Control data: Sum then square: 0.7600403884698499
# Control data: Square then sum: 0.7208700701901742
# Control start and end: 2015-07-14 22:25:00 2015-07-15 04:24:59
# 21705.305643444062
# Control data: Sum then square: 0.509037200744032
# Control data: Square then sum: 0.2688302093368214
# EVENT COUNT 475
# 507 Mecca Crane Falls 2015-09-11 13:00:00 2015-09-11 18:59:59 21600.0
# 21676.242064565864
# Event data: Sum then square: 0.36959566583152326
# Event data: Square then sum: 1.2398179951560397
# For controls...
# Control start and end: 2015-09-11 01:00:00 2015-09-11 06:59:59
# 21587.831432020364
# Control data: Sum then square: -0.05534938851260727
# Control data: Square then sum: 0.010243696165924344
# Control start and end: 2015-09-12 01:00:00 2015-09-12 06:59:59
# 21593.72803223216
# Control data: Sum then square: -0.02697135394859896
# Control data: Square then sum: 0.7054283599005894
# EVENT COUNT 476
# 509 Hadj Stampede 2015 2015-09-24 05:00:00 2015-09-24 08:59:59 14400.0
# 14545.297025980391
# Event data: Sum then square: 0.8572332501320243
# Event data: Square then sum: 1.449016162343683
# For controls...
# Control start and end: 2015-09-23 21:00:00 2015-09-24 00:59:59
# 14548.107973346076
# Control data: Sum then square: 0.8736853494852872
# Control data: Square then sum: -0.5220707391309093
# Control start and end: 2015-09-24 13:00:00 2015-09-24 16:59:59
# 14360.542458705584
# Control data: Sum then square: -0.22878921358718424
# Control data: Square then sum: -0.13845979758803115
# EVENT COUNT 477
# 510 Turkey Peace Bombing 2015-10-10 09:00:00 2015-10-10 14:59:59 21600.0
# 21680.40603004604
# Event data: Sum then square: 0.3895812257611979
# Event data: Square then sum: 0.018391188901351094
# For controls...
# Control start and end: 2015-10-09 21:00:00 2015-10-10 02:59:59
# 21791.34074899025
# Control data: Sum then square: 0.9210894115636274
# Control data: Square then sum: -1.5174940905230176
# Control start and end: 2015-10-10 21:00:00 2015-10-11 02:59:59
# 21761.268371448994
# Control data: Sum then square: 0.7771857014437227
# Control data: Square then sum: -0.6176014643027693
# EVENT COUNT 478
# 511 Paris Terror 2015-11-13 20:00:00 2015-11-14 01:59:59 21600.0
# 21413.98971668363
# Event data: Sum then square: -0.8943145171460541
# Event data: Square then sum: 0.07297812975089733
# For controls...
# Control start and end: 2015-11-13 08:00:00 2015-11-13 13:59:59
# 21865.248416776176
# Control data: Sum then square: 1.2741945563501282
# Control data: Square then sum: 0.9507337103942592
# Control start and end: 2015-11-14 08:00:00 2015-11-14 13:59:59
# 21687.101559944742
# Control data: Sum then square: 0.42171203533225204
# Control data: Square then sum: -0.43593458573296856
# EVENT COUNT 479
# 512 Arbaeen, Hussein 2015-12-03 00:00:00 2015-12-03 23:59:59 86400.0
# 86176.29292857696
# Event data: Sum then square: -0.5370166439642423
# Event data: Square then sum: 0.563085646653622
# For controls...
# Control start and end: 2015-12-01 00:00:00 2015-12-01 23:59:59
# 86527.90015084711
# Control data: Sum then square: 0.3091318065097903
# Control data: Square then sum: 1.6028383145254181
# Control start and end: 2015-12-05 00:00:00 2015-12-05 23:59:59
# 85939.0830477336
# Control data: Sum then square: -1.109167242415067
# Control data: Square then sum: -0.2695080930706722
# EVENT COUNT 480
# 513 Climate Agreement, Day 1 World Peace 2015-12-12 00:00:00 2015-12-12 23:59:59 86400.0
# 86805.72336763197
# Event data: Sum then square: 0.9760982744878453
# Event data: Square then sum: 0.03868687076798962
# For controls...
# Control start and end: 2015-12-10 00:00:00 2015-12-10 23:59:59
# 87084.3845452979
# Control data: Sum then square: 1.6436489723740628
# Control data: Square then sum: 1.3540933593089008
# Control start and end: 2015-12-14 00:00:00 2015-12-14 23:59:59
# 86461.68412109063
# Control data: Sum then square: 0.14995729050319564
# Control data: Square then sum: -0.5144109162078782

# %%
from matplotlib import pyplot as plt

print("num events after dropping events with missing data:", len(surviving_events))

for (touse_pvaltozs_sumthensquare, touse_pvaltozs_squarethensum, testtype) in (
    [ (allevents_pvaltozs_sumthensquare, allevents_pvaltozs_squarethensum, "actual")]
    +[ (controls_pvaltozs_sumthensquare[control_timeshift],
        controls_pvaltozs_squarethensum[control_timeshift],
        "controltimeshift_"+str(control_timeshift))
        for control_timeshift in control_timeshifts ]):

  print("************TIME PERIODS:", testtype)

  pvaltoz_sumthensquare = np.array(touse_pvaltozs_sumthensquare)
  pvaltoz_squarethensum = np.array(touse_pvaltozs_squarethensum)

  metaz_sumthensquare = np.sum(pvaltoz_sumthensquare)/np.sqrt(len(pvaltoz_sumthensquare))
  metaz_squarethensum = np.sum(pvaltoz_squarethensum)/np.sqrt(len(pvaltoz_squarethensum))
  print("Meta-analysis Z-score if squaring *after* summing:", metaz_sumthensquare, "pval:", 1-scipy.stats.norm.cdf(metaz_sumthensquare))
  print("Meta-analysis Z-score if squaring *before* summing", metaz_squarethensum, "pval: ", 1-scipy.stats.norm.cdf(metaz_squarethensum))
  print("Argmax event for square after summing:", surviving_events[np.argmax(pvaltoz_sumthensquare)], np.max(pvaltoz_sumthensquare))
  print("Argmax event for square before summing:", surviving_events[np.argmax(pvaltoz_squarethensum)], np.max(pvaltoz_squarethensum))
  print("Correlation between the two scores:", scipy.stats.pearsonr(pvaltoz_squarethensum, pvaltoz_sumthensquare))

  fig, ax = plt.subplots(ncols=3, figsize=(20,4))
  plt.sca(ax[0])
  scipy.stats.probplot(pvaltoz_sumthensquare, dist=scipy.stats.norm, plot=plt, fit=False)
  plt.plot(plt.xlim(), plt.xlim(), color="black")
  plt.title("Q-Q plot; square after sum across eggs")
  plt.xlabel("Theoretical Z-scores for the quantile")
  plt.ylabel("Actual Z-scores (invcdf(1-p)) for the quantile")
  plt.sca(ax[1])
  scipy.stats.probplot(pvaltoz_squarethensum, dist=scipy.stats.norm, plot=plt, fit=False)
  plt.plot(plt.xlim(), plt.xlim(), color="black")
  plt.title("Q-Q plot; square before sum across eggs")
  plt.xlabel("Theoretical Z-scores for the quantile")
  plt.ylabel("Actual Z-scores (invcdf(1-p)) for the quantile")
  plt.sca(ax[2])
  plt.scatter(pvaltoz_squarethensum, pvaltoz_sumthensquare, s=1)
  plt.plot(plt.xlim(), plt.xlim(), color="black", linestyle="--")
  plt.plot(plt.xlim(), [0,0], color="black")
  plt.plot([0,0], plt.ylim(), color="black")
  plt.xlabel("pvalues to zscores\n(square before sum across eggs)")
  plt.ylabel("pvalues to zscores\n(square after sum across eggs)")
  plt.show()
# Out:
# num events after dropping events with missing data: 475
# ************TIME PERIODS: actual
# Meta-analysis Z-score if squaring *after* summing: 5.712803749536643 pval: 5.556490600966413e-09
# Meta-analysis Z-score if squaring *before* summing 1.3891521727195915 pval:  0.08239324083732802
# Argmax event for square after summing: ('487', 'September 21', datetime.datetime(2014, 9, 21, 0, 0), datetime.datetime(2014, 9, 21, 23, 59, 59), 86400.0) 3.1593632636428017
# Argmax event for square before summing: ('271', 'Obama Acceptance 080828', datetime.datetime(2008, 8, 29, 2, 0), datetime.datetime(2008, 8, 29, 3, 59, 59), 7200.0) 3.592093533886973
# Correlation between the two scores: PearsonRResult(statistic=0.09500128990910663, pvalue=0.03847735996001081)
# ************TIME PERIODS: controltimeshift_-2
# Meta-analysis Z-score if squaring *after* summing: 0.19869357573900787 pval: 0.42125122482484567
# Meta-analysis Z-score if squaring *before* summing 2.960498531875866 pval:  0.0015357079280670094
# Argmax event for square after summing: ('434', '12.12.12 Meditation', datetime.datetime(2012, 12, 12, 12, 30), datetime.datetime(2012, 12, 12, 15, 29, 59), 10800.0) 3.6632892034335143
# Argmax event for square before summing: ('106', 'Tiger Woods Triumph', datetime.datetime(2002, 4, 14, 18, 22), datetime.datetime(2002, 4, 14, 22, 59, 59), 16680.0) 3.8126637078267755
# Correlation between the two scores: PearsonRResult(statistic=0.12082961322172789, pvalue=0.008385346910044448)
# ************TIME PERIODS: controltimeshift_2
# Meta-analysis Z-score if squaring *after* summing: -0.6335653626348068 pval: 0.7368177441779721
# Meta-analysis Z-score if squaring *before* summing -0.15561134071674423 pval:  0.5618303073768627
# Argmax event for square after summing: ('376', 'William &amp Catherine', datetime.datetime(2011, 4, 29, 10, 0), datetime.datetime(2011, 4, 29, 15, 59, 59), 21600.0) 3.709429572854
# Argmax event for square before summing: ('100', 'Astrid Lindgren Dies', datetime.datetime(2002, 1, 28, 11, 0), datetime.datetime(2002, 1, 28, 14, 59, 59), 14400.0) 3.476080261507864
# Correlation between the two scores: PearsonRResult(statistic=0.17346516215733085, pvalue=0.0001450080480884051)
