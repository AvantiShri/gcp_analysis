# %% [markdown]
# <a href="https://colab.research.google.com/github/AvantiShri/gcp_analysis/blob/main/gcp1reanalysis/GCP1_Data_Reanalysis_TheoreticalNormalize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Preparation

# %%
#mount Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/GCP_data/all_data
#data at https://drive.google.com/drive/u/0/folders/1MUS-xbwoBiodWLz4gese19ti_ftlKsVu
# Out:
# /content/drive/MyDrive/GCP_data/all_data

# %%
#install utilities code for reading/parsing data at https://github.com/AvantiShri/gcpdatautils
# !pip uninstall -y gcpdatautils #uninstall the pre-existing version if want to fetch latest
# !pip install git+https://github.com/AvantiShri/gcpdatautils.git@main #install latest from github

#Note: the code that was used to consolidate the downloaded csv.gz files into hdf5 files
# is at https://github.com/AvantiShri/gcp_analysis/blob/main/alldata/Consolidate_GCP_as_HDF5.ipynb
# Out:
# WARNING: Skipping gcpdatautils as it is not installed.
# Collecting git+https://github.com/AvantiShri/gcpdatautils.git@main
#   Cloning https://github.com/AvantiShri/gcpdatautils.git (to revision main) to /tmp/pip-req-build-8o8apyav
#   Running command git clone --filter=blob:none --quiet https://github.com/AvantiShri/gcpdatautils.git /tmp/pip-req-build-8o8apyav
#   Resolved https://github.com/AvantiShri/gcpdatautils.git to commit 55a9bc16c7c36ea920eafb44079d401f76da48f1
#   Preparing metadata (setup.py) ... done
# Collecting bs4 (from gcpdatautils==0.1.1.3)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from gcpdatautils==0.1.1.3) (3.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gcpdatautils==0.1.1.3) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gcpdatautils==0.1.1.3) (1.11.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->gcpdatautils==0.1.1.3) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->gcpdatautils==0.1.1.3) (2.5)
# Building wheels for collected packages: gcpdatautils
#   Building wheel for gcpdatautils (setup.py) ... done
#   Created wheel for gcpdatautils: filename=gcpdatautils-0.1.1.3-py3-none-any.whl size=6405 sha256=8b11d0193f41da3439fa886b7dfb0fc61601ce180bac282b746711aa0feca638
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gduxso8a/wheels/8c/35/d9/946037b24577e21d0dce0d66645d002768f5bac3497186d55f
# Successfully built gcpdatautils
# Installing collected packages: bs4, gcpdatautils
# Successfully installed bs4-0.0.2 gcpdatautils-0.1.1.3

# %% [markdown]
# Load in the GCP event timeperiod definitions

# %%
from gcpdatautils import parse_events_html

#download the formal event registry if not already present
# !wget https://global-mind.org/pred_formal.html -O pred_formal.html

# we will parse the events file, dropping events longer than 30 days for memory efficiency
# we will also drop 'New Year Var...' events as they tend to be redundant in duration
# with the 'mean' events, and we are going to do a standard analysis on all the events
included_events = parse_events_html("/content/drive/MyDrive/GCP_data/pred_formal.html",
                                    exclude_events_longer_than_days=30)
# Out:
# --2024-02-13 20:07:26--  https://global-mind.org/pred_formal.html
# Resolving global-mind.org (global-mind.org)... 162.245.217.130
# Connecting to global-mind.org (global-mind.org)|162.245.217.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘pred_formal.html’
#
# pred_formal.html        [ <=>                ] 184.64K  --.-KB/s    in 0.1s
#
# 2024-02-13 20:07:26 (1.78 MB/s) - ‘pred_formal.html’ saved [189067]
#
# Skipping because redundant with a corresponding 'mean' event:  43 New Year Var 99-00 1999-12-31 09:30:00 2000-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  65 New Year Var 00-01 2000-12-31 09:30:00 2001-01-01 11:29:59
# Skipping because end < start: 82 Silent Prayer, Sept 14 2001-09-14 10:00:00 2001-09-14 10:00:00
# Skipping because redundant with a corresponding 'mean' event:  98 New Year Var 01-02 2001-12-31 09:30:00 2002-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  126 New Year Variance 2002-12-31 09:30:00 2003-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  163 New Year Variance 2003-12-31 09:30:00 2004-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  191 New Year Variance 2004-12-31 09:30:00 2005-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  210 New Year Dev-Net Var 2005-12-31 23:53:00 2006-01-01 00:00:59
# Skipping because event is more than 30 days long! 223 TM Flyer Aggregation 2006-07-29 12:30:00 2006-09-09 23:29:59
# Skipping because redundant with a corresponding 'mean' event:  232 New Year Variance 2006-12-31 09:30:00 2007-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  257 New Year Var, 2008 2007-12-31 09:30:00 2008-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  284 New Year Variance 2009 2008-12-31 09:30:00 2009-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  318 New Year Variance 2010 2009-12-31 09:30:00 2010-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  357 New Year Variance 2011 2010-12-31 09:30:00 2011-01-01 11:29:59
# Skipping because end < start: 392 Troy Davis Execution 2011-09-22 00:00:00 2011-09-21 05:59:59
# Skipping because redundant with a corresponding 'mean' event:  405 New Year Variance 2012 2011-12-31 09:30:00 2012-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  439 New Year Variance 2013 2012-12-31 09:30:00 2013-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  474 New Year Variance 2014 2013-12-31 09:30:00 2014-01-01 11:29:59
# Skipping because redundant with a corresponding 'mean' event:  495 New Year Variance 2015 2014-12-31 09:30:00 2015-01-01 11:29:59

# %%
len(included_events)
# Out:
# 480

# %% [markdown]
# Load the code for reading from the hdf5 files

# %%
import numpy as np
from collections import defaultdict
import h5py
from datetime import datetime, timedelta
from gcpdatautils import GCPHdf5DataReader, GCPMissingDataError

#Refer to the github repo https://github.com/AvantiShri/gcpdatautils for the
# code for reading from the hdf5 files
#Instantiate the hdf5 data reader
#it will auto-load a rotteneggs.txt file specifying bad data time periods (downloaded from https://global-mind.org/rotteneggs and saved in the package)
# this rotten egg file can be overridden by altering the arguments to the GCPHdf5DataReader
gcp_data_reader = GCPHdf5DataReader()
# Out:
# Parsing the bad data file: /usr/local/lib/python3.10/dist-packages/gcpdatautils/resources/rotteneggs.txt
# manually correcting 47,2000-01-01 00:00:00,2001-06-31 23:59:59,2222
# manually correcting 47,2008-04-25 00:00:00,2008-04-55 23:59:59,1092

# %% [markdown]
# Pull data for a specific event to compare to the GCP plots, as a sanity check

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import scipy
#data for a top-ranked GCP event - Valentine's day 2009
# Compare to: https://global-mind.org/valentines.09.html
idx=263
print(included_events[idx])

start_datetime, end_datetime = included_events[idx][2], included_events[idx][3]
event_data = gcp_data_reader.fetch_data(start_datetime, end_datetime, normalize=False)[0] #returns both the event data and the device ids; we just want the data

#make the chi-squared-minus-1 plot
csm1 = np.square(np.nansum((event_data - 100)/np.sqrt(50), axis=1)/np.sqrt(
        np.sum(np.isnan(event_data)==False, axis=1))) - 1
plt.figure(figsize=(20,5))
plt.plot(np.arange(len(csm1)), np.cumsum(csm1))
#also plot the p=0.05 envelop
plt.plot(np.arange(len(csm1)), np.array([scipy.stats.chi2.ppf(0.95, x+1)
                                         for x in np.arange(len(csm1))])
                                        - (np.arange(len(csm1))+1) )
plt.show()
# Out:
# ('289', 'Meditations Valentines Day', datetime.datetime(2009, 2, 14, 0, 0), datetime.datetime(2009, 2, 14, 23, 59, 59), 86400.0)

# %% [markdown]
# Load the empirical variances, computed from https://github.com/AvantiShri/gcp_analysis/blob/main/alldata/ComputeLifetimeDeviceStats.ipynb

# %%
import json
from matplotlib import pyplot as plt

device_to_empirical_variances = json.loads(open("empirical_device_variances.json").read())
plt.hist(device_to_empirical_variances.values(), bins=50)
plt.show()

# %% [markdown]
# Do aggregate analysis

# %%
from datetime import datetime,timedelta
import numpy as np
import h5py
import traceback
import scipy


def normalize_by_lifetime_device_variance(data, devices, device_to_empirical_variances):
  data = np.array(data) #make a copy, just in case
  for i,device in enumerate(devices):
    scalefactor = (np.sqrt(device_to_empirical_variances[str(int(device))])/np.sqrt(50))
    data[:,i] = ((data[:,i]-100)/scalefactor)+100
  return data


def compute_pvaltoz(egg_values):

  num_nonnan_eggs = np.sum(np.isnan(egg_values)==False, axis=1) #get the number of non NaN eggs per row
  egg_zscores = (egg_values - 100)/np.sqrt(50)
  composite_z_scores = np.nansum(egg_zscores, axis=1)/np.sqrt(num_nonnan_eggs)

  print(np.nansum(np.square(composite_z_scores)))
  pvaltoz_sumthensquare = scipy.stats.norm.ppf(
      scipy.stats.chi2.cdf(x=np.nansum(np.square(composite_z_scores)),
                           df=np.sum(np.isnan(composite_z_scores)==False)))
  pvaltoz_squarethensum = scipy.stats.norm.ppf(
      scipy.stats.chi2.cdf(np.nansum(np.square(egg_zscores)),
                           df=np.sum(np.isnan(egg_zscores)==False)))

  return pvaltoz_sumthensquare, pvaltoz_squarethensum


def get_normalized_data(start_datetime, end_datetime, device_to_empirical_variances):
  data, devices = gcp_data_reader.fetch_data(start_datetime, end_datetime, normalize=DAY_NORMALIZE)
  if LIFETIME_NORMALIZE:
    data = normalize_by_lifetime_device_variance(data, devices, device_to_empirical_variances)
  return data


DAY_NORMALIZE = False
LIFETIME_NORMALIZE = False
assert (DAY_NORMALIZE and LIFETIME_NORMALIZE)==False #at most one should be true

control_timeshifts = [-2, 2] #how much to shift the events by (as a multiple of their duration) to define 'control' time periods

surviving_events = [] #in case we encounter missing data errors, maintain a list of surviving events

eventcount = 0

allevents_pvaltozs_sumthensquare = []
allevents_pvaltozs_squarethensum = []
controls_pvaltozs_sumthensquare = defaultdict(list)
controls_pvaltozs_squarethensum = defaultdict(list)

missing_data_errors = []

for (event_num, event_name, start_datetime, end_datetime, duration) in included_events[:]:
  eventcount += 1
  print("EVENT COUNT", eventcount)
  print(event_num, event_name, start_datetime, end_datetime, duration)
  try:
    event_data = get_normalized_data(start_datetime, end_datetime, device_to_empirical_variances)
    event_pvaltoz_sumthensquare, event_pvaltoz_squarethensum = compute_pvaltoz(event_data)
    print("Event data: Sum then square:", event_pvaltoz_sumthensquare)
    print("Event data: Square then sum:", event_pvaltoz_squarethensum)

    print("For controls...")
    thisevent_control_pvaltozs_sumthensquare = {}
    thisevent_control_pvaltozs_squarethensum = {}
    for control_timeshift in control_timeshifts:
      timeshift = timedelta(seconds=control_timeshift*duration)
      control_starttime = start_datetime + timeshift
      control_endtime = end_datetime + timeshift
      print("Control start and end:", control_starttime, control_endtime)
      control_data = get_normalized_data(control_starttime, control_endtime, device_to_empirical_variances)
      pvaltozs_sumthensquare, pvaltozs_squarethensum = compute_pvaltoz(control_data)
      print("Control data: Sum then square:", pvaltozs_sumthensquare)
      print("Control data: Square then sum:", pvaltozs_squarethensum)
      thisevent_control_pvaltozs_sumthensquare[control_timeshift] = pvaltozs_sumthensquare
      thisevent_control_pvaltozs_squarethensum[control_timeshift] = pvaltozs_squarethensum

    allevents_pvaltozs_sumthensquare.append(event_pvaltoz_sumthensquare)
    allevents_pvaltozs_squarethensum.append(event_pvaltoz_squarethensum)
    for control_timeshift in control_timeshifts:
      controls_pvaltozs_sumthensquare[control_timeshift].append(
          thisevent_control_pvaltozs_sumthensquare[control_timeshift])
      controls_pvaltozs_squarethensum[control_timeshift].append(
          thisevent_control_pvaltozs_squarethensum[control_timeshift])
    surviving_events.append((event_num, event_name, start_datetime, end_datetime, duration))
  except GCPMissingDataError as e:
    print("MISSING DATA ERROR!",e)
    missing_data_errors.append(e)
# Out:
# Streaming output truncated to the last 5000 lines.
# 28728.38827993197
# Control data: Sum then square: -0.295851478724476
# Control data: Square then sum: -1.0043140116610023
# Control start and end: 2003-12-26 17:30:00 2003-12-27 01:29:59
# 28934.598936214483
# Control data: Sum then square: 0.5627342854165587
# Control data: Square then sum: -0.8844155119475765
# EVENT COUNT 143
# 161 60 Seconds for Peace 2003-12-27 21:00:00 2003-12-27 21:00:59 60.0
# 76.7576923076923
# Event data: Sum then square: 1.4664260246960543
# Event data: Square then sum: 0.36032719617708486
# For controls...
# Control start and end: 2003-12-27 20:58:00 2003-12-27 20:58:59
# 56.27807692307693
# Control data: Sum then square: -0.28582893996098213
# Control data: Square then sum: 0.20433039335427486
# Control start and end: 2003-12-27 21:02:00 2003-12-27 21:02:59
# 59.0103846153846
# Control data: Sum then square: -0.02985073023452156
# Control data: Square then sum: -0.004473979467534306
# EVENT COUNT 144
# 162 New Year Mean 2003-2004 2003-12-31 09:30:00 2004-01-01 12:29:59 97200.0
# 97412.01850484297
# Event data: Sum then square: 0.4820303025847347
# Event data: Square then sum: 1.5545797630490061
# For controls...
# Control start and end: 2003-12-29 03:30:00 2003-12-30 06:29:59
# 97577.19066201251
# Control data: Sum then square: 0.8558932467703966
# Control data: Square then sum: 1.7448591599082408
# Control start and end: 2004-01-02 15:30:00 2004-01-03 18:29:59
# 96874.7733804531
# Control data: Sum then square: -0.7369407990202569
# Control data: Square then sum: 0.32289470668372716
# EVENT COUNT 145
# 164 Hadj Ritual Tragedy 2004-02-01 05:30:00 2004-02-01 07:29:59 7200.0
# 7301.49588989442
# Event data: Sum then square: 0.8474062300174262
# Event data: Square then sum: 1.8034042566889186
# For controls...
# Control start and end: 2004-02-01 01:30:00 2004-02-01 03:29:59
# 7237.303371040724
# Control data: Sum then square: 0.3158793799179905
# Control data: Square then sum: -0.1566521544057553
# Control start and end: 2004-02-01 09:30:00 2004-02-01 11:29:59
# 7057.129146907993
# Control data: Sum then square: -1.1929930690089527
# Control data: Square then sum: -0.7611601429249117
# EVENT COUNT 146
# 165 Iran Train Explosion 2004-02-18 00:30:00 2004-02-18 10:29:59 36000.0
# 36253.73783107089
# Event data: Sum then square: 0.9458955470741711
# Event data: Square then sum: -1.4184633580949493
# For controls...
# Control start and end: 2004-02-17 04:30:00 2004-02-17 14:29:59
# 35276.36555758302
# Control data: Sum then square: -2.7126221084144286
# Control data: Square then sum: -0.278939997245163
# Control start and end: 2004-02-18 20:30:00 2004-02-19 06:29:59
# 36078.49539647243
# Control data: Sum then square: 0.29480679571887786
# Control data: Square then sum: 0.2702346497969767
# EVENT COUNT 147
# 166 Oscar Ceremony 2004 2004-03-01 01:00:00 2004-03-01 05:08:59 14940.0
# 14986.615097035736
# Event data: Sum then square: 0.273248043174905
# Event data: Square then sum: -1.1490452293237394
# For controls...
# Control start and end: 2004-02-29 16:42:00 2004-02-29 20:50:59
# 15203.587285034013
# Control data: Sum then square: 1.5198491610923153
# Control data: Square then sum: 0.1604114793526949
# Control start and end: 2004-03-01 09:18:00 2004-03-01 13:26:59
# 14892.955634437836
# Control data: Sum then square: -0.2685840677346267
# Control data: Square then sum: -1.7159929187919425
# EVENT COUNT 148
# 167 Attacks on Shiites, Iraq 2004-03-02 06:30:00 2004-03-02 10:29:59 14400.0
# 14509.551127819546
# Event data: Sum then square: 0.6478323185913742
# Event data: Square then sum: -1.9494633842243534
# For controls...
# Control start and end: 2004-03-01 22:30:00 2004-03-02 02:29:59
# 14562.189473588438
# Control data: Sum then square: 0.9560706331730885
# Control data: Square then sum: 0.32186940706800526
# Control start and end: 2004-03-02 14:30:00 2004-03-02 18:29:59
# 14221.539525974025
# Control data: Sum then square: -1.052031792208227
# Control data: Square then sum: 0.24849778267218786
# EVENT COUNT 149
# 168 Terror Attacks in Madrid 2004-03-11 06:00:00 2004-03-11 10:59:59 18000.0
# 17711.725211612982
# Event data: Sum then square: -1.5240106890360747
# Event data: Square then sum: -0.13391808457660725
# For controls...
# Control start and end: 2004-03-10 20:00:00 2004-03-11 00:59:59
# 17836.77636348976
# Control data: Sum then square: -0.8593619128020826
# Control data: Square then sum: 1.2255927169261882
# Control start and end: 2004-03-11 16:00:00 2004-03-11 20:59:59
# 17934.46194714957
# Control data: Sum then square: -0.34232126154052134
# Control data: Square then sum: 1.8014101998757277
# EVENT COUNT 150
# 169 Demonstrations in Spain 2004-03-12 11:00:00 2004-03-12 22:59:59 43200.0
# 43527.99496431631
# Event data: Sum then square: 1.1153165371056564
# Event data: Square then sum: 1.8169709049703768
# For controls...
# Control start and end: 2004-03-11 11:00:00 2004-03-11 22:59:59
# 42850.86709766294
# Control data: Sum then square: -1.1887196214603883
# Control data: Square then sum: 0.9597984325768627
# Control start and end: 2004-03-13 11:00:00 2004-03-13 22:59:59
# 43229.2074947589
# Control data: Sum then square: 0.10161145094386759
# Control data: Square then sum: -0.05235593896444598
# EVENT COUNT 151
# 170 Global Day of Peace 2004-03-20 00:00:00 2004-03-20 23:59:59 86400.0
# 85890.91313473388
# Event data: Sum then square: -1.225481764640231
# Event data: Square then sum: 1.3935198438927632
# For controls...
# Control start and end: 2004-03-18 00:00:00 2004-03-18 23:59:59
# 86968.24142050729
# Control data: Sum then square: 1.365593916065261
# Control data: Square then sum: 1.5125823001669212
# Control start and end: 2004-03-22 00:00:00 2004-03-22 23:59:59
# 86563.68402325522
# Control data: Sum then square: 0.39511767519502117
# Control data: Square then sum: 0.4724308641886899
# EVENT COUNT 152
# 171 Cricket, India vs Pakistan 2004-03-24 09:00:00 2004-03-24 16:59:59 28800.0
# 29083.383823627108
# Event data: Sum then square: 1.1796907212249241
# Event data: Square then sum: -0.615776815638688
# For controls...
# Control start and end: 2004-03-23 17:00:00 2004-03-24 00:59:59
# 28809.481655603653
# Control data: Sum then square: 0.042280269859915974
# Control data: Square then sum: 0.40980715416263797
# Control start and end: 2004-03-25 01:00:00 2004-03-25 08:59:59
# 29011.888965758208
# Control data: Sum then square: 0.8834908504779205
# Control data: Square then sum: -0.5657675726865367
# EVENT COUNT 153
# 172 Rantisi Assassination 2004-04-17 17:00:00 2004-04-17 20:59:59 14400.0
# 14279.383514937423
# Event data: Sum then square: -0.7088024926580334
# Event data: Square then sum: -0.16371437704685715
# For controls...
# Control start and end: 2004-04-17 09:00:00 2004-04-17 12:59:59
# 14652.990455330319
# Control data: Sum then square: 1.486041329754398
# Control data: Square then sum: 0.50619495285883
# Control start and end: 2004-04-18 01:00:00 2004-04-18 04:59:59
# 14563.70249407856
# Control data: Sum then square: 0.9649195596261357
# Control data: Square then sum: 0.3268094540188183
# EVENT COUNT 154
# 173 Korean Train Explosion 2004-04-22 03:00:00 2004-04-22 06:59:59 14400.0
# 14551.623422558921
# Event data: Sum then square: 0.8942578243534332
# Event data: Square then sum: -0.6073516695387702
# For controls...
# Control start and end: 2004-04-21 19:00:00 2004-04-21 22:59:59
# 14347.517576720013
# Control data: Sum then square: -0.3057025728352764
# Control data: Square then sum: -1.1526011542622097
# Control start and end: 2004-04-22 11:00:00 2004-04-22 14:59:59
# 14677.957954545454
# Control data: Sum then square: 1.631383663932024
# Control data: Square then sum: 1.862047927373861
# EVENT COUNT 155
# 174 Floods in Haiti 2004-05-24 00:00:00 2004-05-24 23:59:59 86400.0
# 86724.31267333303
# Event data: Sum then square: 0.7808042610393069
# Event data: Square then sum: 1.8223212294653621
# For controls...
# Control start and end: 2004-05-22 00:00:00 2004-05-22 23:59:59
# 86258.61996850808
# Control data: Sum then square: -0.338689214503758
# Control data: Square then sum: 1.2718280031850735
# Control start and end: 2004-05-26 00:00:00 2004-05-26 23:59:59
# 85835.99372463638
# Control data: Sum then square: -1.3581471998590042
# Control data: Square then sum: -1.0630777010125023
# EVENT COUNT 156
# 175 Iraq Insurgency Bombs 2004-06-24 04:30:00 2004-06-24 08:29:59 14400.0
# 14560.22755267772
# Event data: Sum then square: 0.9445953929675664
# Event data: Square then sum: 0.02427509128976385
# For controls...
# Control start and end: 2004-06-23 20:30:00 2004-06-24 00:29:59
# 14536.321592244716
# Control data: Sum then square: 0.8046870538631226
# Control data: Square then sum: 0.6842783482159048
# Control start and end: 2004-06-24 12:30:00 2004-06-24 16:29:59
# 13732.250840603872
# Control data: Sum then square: -3.993326073031496
# Control data: Square then sum: 1.3704975710242406
# EVENT COUNT 157
# 176 Turkish Train Wreck 2004-07-22 04:15:00 2004-07-22 08:14:59 14400.0
# 14288.059330411064
# Event data: Sum then square: -0.6574027905128593
# Event data: Square then sum: 0.5011213481043303
# For controls...
# Control start and end: 2004-07-21 20:15:00 2004-07-22 00:14:59
# 14297.315307032923
# Control data: Sum then square: -0.6025888849664891
# Control data: Square then sum: 0.5711034604485034
# Control start and end: 2004-07-22 12:15:00 2004-07-22 16:14:59
# 14088.56758757062
# Control data: Sum then square: -1.844596660171522
# Control data: Square then sum: -0.36718913525640723
# EVENT COUNT 158
# 177 Democratic Convention, Kerry 2004-07-30 02:00:00 2004-07-30 02:44:59 2700.0
# 2840.9420627533937
# Event data: Sum then square: 1.8946194899407576
# Event data: Square then sum: -0.4113564137788055
# For controls...
# Control start and end: 2004-07-30 00:30:00 2004-07-30 01:14:59
# 2639.85550520007
# Control data: Sum then square: -0.8155311049361541
# Control data: Square then sum: -0.8769865571686944
# Control start and end: 2004-07-30 03:30:00 2004-07-30 04:14:59
# 2585.6090902102437
# Control data: Sum then square: -1.5701018695235276
# Control data: Square then sum: 0.45483658016974665
# EVENT COUNT 159
# 178 Fire in Paraguay 2004-08-01 14:00:00 2004-08-01 17:59:59 14400.0
# 14466.100481310803
# Event data: Sum then square: 0.3928333191552869
# Event data: Square then sum: 0.21781448142913654
# For controls...
# Control start and end: 2004-08-01 06:00:00 2004-08-01 09:59:59
# 14209.681665113778
# Control data: Sum then square: -1.122507876503451
# Control data: Square then sum: 0.4279055348385719
# Control start and end: 2004-08-01 22:00:00 2004-08-02 01:59:59
# 14476.887110866111
# Control data: Sum then square: 0.4561844305220416
# Control data: Square then sum: 1.4673875042844535
# EVENT COUNT 160
# 179 Bob Morris Dies 2004-08-12 04:00:00 2004-08-12 19:59:59 57600.0
# 57830.461633840234
# Event data: Sum then square: 0.6800641601802018
# Event data: Square then sum: 0.3151343179329175
# For controls...
# Control start and end: 2004-08-10 20:00:00 2004-08-11 11:59:59
# 58276.29561184619
# Control data: Sum then square: 1.9867719487965783
# Control data: Square then sum: 0.9832456429933152
# Control start and end: 2004-08-13 12:00:00 2004-08-14 03:59:59
# 57815.473524315355
# Control data: Sum then square: 0.6360186357307265
# Control data: Square then sum: 0.24162977061150143
# EVENT COUNT 161
# 180 Olympic Opening Athens 2004-08-13 18:00:00 2004-08-13 20:59:59 10800.0
# 10623.239512265513
# Event data: Sum then square: -1.204785246970963
# Event data: Square then sum: -0.13322913797799935
# For controls...
# Control start and end: 2004-08-13 12:00:00 2004-08-13 14:59:59
# 10977.382174755068
# Control data: Sum then square: 1.2049176893504892
# Control data: Square then sum: -0.41870917539433083
# Control start and end: 2004-08-14 00:00:00 2004-08-14 02:59:59
# 10862.153092706034
# Control data: Sum then square: 0.4266236362096126
# Control data: Square then sum: 0.793339034141375
# EVENT COUNT 162
# 181 Day of Murderous Violence 2004-08-31 00:00:00 2004-08-31 23:59:59 86400.0
# 87128.29880112685
# Event data: Sum then square: 1.7487185120298154
# Event data: Square then sum: 1.415288982248669
# For controls...
# Control start and end: 2004-08-29 00:00:00 2004-08-29 23:59:59
# 86300.98188311403
# Control data: Sum then square: -0.23668772054976603
# Control data: Square then sum: 1.5107385751895355
# Control start and end: 2004-09-02 00:00:00 2004-09-02 23:59:59
# 86730.20183785059
# Control data: Sum then square: 0.7949357242162355
# Control data: Square then sum: -1.6716357828805872
# EVENT COUNT 163
# 182 Republican Convention, Bush 2004-09-03 02:09:59 2004-09-03 03:11:59 3721.0
# 3705.6635526315786
# Event data: Sum then square: -0.1702929181669781
# Event data: Square then sum: -1.1936358439916668
# For controls...
# Control start and end: 2004-09-03 00:05:57 2004-09-03 01:07:57
# 3786.117011278195
# Control data: Sum then square: 0.7581889203278254
# Control data: Square then sum: -0.30535898294643044
# Control start and end: 2004-09-03 04:14:01 2004-09-03 05:16:01
# 3749.1473120300748
# Control data: Sum then square: 0.3331853149173849
# Control data: Square then sum: -0.15229629718604323
# EVENT COUNT 164
# 183 Russian School Hostage Crisis 2004-09-03 05:00:00 2004-09-03 08:59:59 14400.0
# 14733.077235702893
# Event data: Sum then square: 1.951665777830571
# Event data: Square then sum: 2.2814004416844917
# For controls...
# Control start and end: 2004-09-02 21:00:00 2004-09-03 00:59:59
# 14564.042905971823
# Control data: Sum then square: 0.9669103800815559
# Control data: Square then sum: 0.698101275413461
# Control start and end: 2004-09-03 13:00:00 2004-09-03 16:59:59
# 14362.595432330825
# Control data: Sum then square: -0.21667042319862923
# Control data: Square then sum: 0.6335022038887251
# EVENT COUNT 165
# 184 Earthdance 2004 2004-09-18 22:50:00 2004-09-18 23:14:59 1500.0
# 1414.2450187969923
# Event data: Sum then square: -1.5843062546408184
# Event data: Square then sum: -0.732818471613679
# For controls...
# Control start and end: 2004-09-18 22:00:00 2004-09-18 22:24:59
# 1518.8739849624058
# Control data: Sum then square: 0.35531476497580833
# Control data: Square then sum: -1.759730726268764
# Control start and end: 2004-09-18 23:40:00 2004-09-19 00:04:59
# 1454.6843766744446
# Control data: Sum then square: -0.823624842699215
# Control data: Square then sum: -1.0971510717239688
# EVENT COUNT 166
# 185 Intnl Day Peace + Hurricane Haiti 2004-09-21 00:00:00 2004-09-21 23:59:59 86400.0
# 85788.64976897759
# Event data: Sum then square: -1.4725585264686598
# Event data: Square then sum: 0.17403085108445024
# For controls...
# Control start and end: 2004-09-19 00:00:00 2004-09-19 23:59:59
# 85884.1078501792
# Control data: Sum then square: -1.24191779949548
# Control data: Square then sum: -0.7688506150716052
# Control start and end: 2004-09-23 00:00:00 2004-09-23 23:59:59
# 87071.06096286277
# Control data: Sum then square: 1.6117639013927336
# Control data: Square then sum: 1.6956708372303093
# EVENT COUNT 167
# 186 Bombing in Taba, Egypt 2004-10-07 19:00:00 2004-10-07 22:59:59 14400.0
# 14618.505920514319
# Event data: Sum then square: 1.2850264881811198
# Event data: Square then sum: 0.325051368385956
# For controls...
# Control start and end: 2004-10-07 11:00:00 2004-10-07 14:59:59
# 14233.176472382005
# Control data: Sum then square: -0.9829068087512501
# Control data: Square then sum: -2.10720909801195
# Control start and end: 2004-10-08 03:00:00 2004-10-08 06:59:59
# 14479.426428988896
# Control data: Sum then square: 0.4710935624571822
# Control data: Square then sum: -0.18048653309519871
# EVENT COUNT 168
# 187 US Election 2004 2004-11-02 11:00:00 2004-11-03 05:59:59 68400.0
# 67967.86080442237
# Event data: Sum then square: -1.1690367896366114
# Event data: Square then sum: 0.10094514051290454
# For controls...
# Control start and end: 2004-10-31 21:00:00 2004-11-01 15:59:59
# 69303.5688479227
# Control data: Sum then square: 2.4340957318751197
# Control data: Square then sum: 0.31463994605530604
# Control start and end: 2004-11-04 01:00:00 2004-11-04 19:59:59
# 68321.20180081086
# Control data: Sum then square: -0.21132516242475027
# Control data: Square then sum: -0.1929123998058256
# EVENT COUNT 169
# 188 Arafat Dies 2004-11-11 02:30:00 2004-11-11 14:29:59 43200.0
# 43682.505126388154
# Event data: Sum then square: 1.637709812945659
# Event data: Square then sum: 2.2249520092789243
# For controls...
# Control start and end: 2004-11-10 02:30:00 2004-11-10 14:29:59
# 43332.71995884077
# Control data: Sum then square: 0.45332837229761275
# Control data: Square then sum: -0.37734108040304504
# Control start and end: 2004-11-12 02:30:00 2004-11-12 14:29:59
# 42919.53604186348
# Control data: Sum then square: -0.9539612070888778
# Control data: Square then sum: 0.532587395560554
# EVENT COUNT 170
# 189 Tsunami Indian Ocean 2004-12-26 00:29:00 2004-12-26 08:28:59 28800.0
# 28877.293505080645
# Event data: Sum then square: 0.32454577129431184
# Event data: Square then sum: 1.4002056198855917
# For controls...
# Control start and end: 2004-12-25 08:29:00 2004-12-25 16:28:59
# 28692.406233935213
# Control data: Sum then square: -0.4460882065510234
# Control data: Square then sum: -0.5845420418368147
# Control start and end: 2004-12-26 16:29:00 2004-12-27 00:28:59
# 29127.7657192786
# Control data: Sum then square: 1.3633189164508472
# Control data: Square then sum: -0.30669317843590904
# EVENT COUNT 171
# 190 New Year Mean 2004-2005 2004-12-31 09:30:00 2005-01-01 12:29:59 97200.0
# 97954.87462501475
# Event data: Sum then square: 1.7091892985516761
# Event data: Square then sum: 0.8144108732269125
# For controls...
# Control start and end: 2004-12-29 03:30:00 2004-12-30 06:29:59
# 96967.59374327231
# Control data: Sum then square: -0.5260164554892769
# Control data: Square then sum: 0.3101000188095048
# Control start and end: 2005-01-02 15:30:00 2005-01-03 18:29:59
# 96121.00365985355
# Control data: Sum then square: -2.4548143850225825
# Control data: Square then sum: 0.21840602446470256
# EVENT COUNT 172
# 192 Elections in Iraq 2005-01-30 04:00:00 2005-01-30 15:59:59 43200.0
# 43687.51762419638
# Event data: Sum then square: 1.654636259662978
# Event data: Square then sum: -0.8061522439945925
# For controls...
# Control start and end: 2005-01-29 04:00:00 2005-01-29 15:59:59
# 43297.89809739378
# Control data: Sum then square: 0.33507245737833363
# Control data: Square then sum: 1.9236268804325343
# Control start and end: 2005-01-31 04:00:00 2005-01-31 15:59:59
# 43682.13333102627
# Control data: Sum then square: 1.636454264725377
# Control data: Square then sum: -1.2126410031455985
# EVENT COUNT 173
# 193 Hariri Assassination Beirut 2005-02-14 09:00:00 2005-02-14 12:59:59 14400.0
# 14432.76179745096
# Event data: Sum then square: 0.19683217187904492
# Event data: Square then sum: 0.8678711782460863
# For controls...
# Control start and end: 2005-02-14 01:00:00 2005-02-14 04:59:59
# 14431.53464927661
# Control data: Sum then square: 0.18961190106398665
# Control data: Square then sum: 3.1861060496800726
# Control start and end: 2005-02-14 17:00:00 2005-02-14 20:59:59
# 14458.286045454544
# Control data: Sum then square: 0.34691857570743684
# Control data: Square then sum: 0.636958074151536
# EVENT COUNT 174
# 194 Siyum Daf Yomi 2005-03-01 22:45:00 2005-03-02 01:59:59 11700.0
# 11689.532183637059
# Event data: Sum then square: -0.06409219549958031
# Event data: Square then sum: 0.5729189402531603
# For controls...
# Control start and end: 2005-03-01 16:15:00 2005-03-01 19:29:59
# 11886.704489628513
# Control data: Sum then square: 1.2184453508156783
# Control data: Square then sum: 1.871807731622174
# Control start and end: 2005-03-02 05:15:00 2005-03-02 08:29:59
# 11488.254234355612
# Control data: Sum then square: -1.3883004285119076
# Control data: Square then sum: 1.219717658331945
# EVENT COUNT 175
# 195 Quake, Indian Ocean 2005-03-28 16:00:00 2005-03-28 23:59:59 28800.0
# 28906.910755255165
# Event data: Sum then square: 0.4476883839713694
# Event data: Square then sum: 0.6134318877447462
# For controls...
# Control start and end: 2005-03-28 00:00:00 2005-03-28 07:59:59
# 28823.710310694172
# Control data: Sum then square: 0.10154345488948122
# Control data: Square then sum: 0.5246662731410522
# Control start and end: 2005-03-29 08:00:00 2005-03-29 15:59:59
# 28845.15562823408
# Control data: Sum then square: 0.19082762758645988
# Control data: Square then sum: 0.5077288538400588
# EVENT COUNT 176
# 196 Pope John Paul Dies 2005-04-02 04:00:00 2005-04-02 23:59:59 72000.0
# 72118.75375906337
# Event data: Sum then square: 0.31452832688455284
# Event data: Square then sum: 0.5454078165202089
# For controls...
# Control start and end: 2005-03-31 12:00:00 2005-04-01 07:59:59
# 71899.93985281952
# Control data: Sum then square: -0.2620468618183707
# Control data: Square then sum: 1.3315752060356663
# Control start and end: 2005-04-03 20:00:00 2005-04-04 15:59:59
# 71769.89569163267
# Control data: Sum then square: -0.6052679845918996
# Control data: Square then sum: 0.764784525310765
# EVENT COUNT 177
# 197 Pope Paul's Funeral 2005-04-08 08:00:00 2005-04-08 12:29:59 16200.0
# 16555.73909235391
# Event data: Sum then square: 1.965741598397408
# Event data: Square then sum: 1.0399416818745242
# For controls...
# Control start and end: 2005-04-07 23:00:00 2005-04-08 03:29:59
# 16324.630809541386
# Control data: Sum then square: 0.6943270708650071
# Control data: Square then sum: 1.0050536140429969
# Control start and end: 2005-04-08 17:00:00 2005-04-08 21:29:59
# 15894.314925384764
# Control data: Sum then square: -1.70534166482139
# Control data: Square then sum: 0.9446247525992596
# EVENT COUNT 178
# 198 Prince Charles' Wedding 2005-04-09 11:00:00 2005-04-09 14:59:59 14400.0
# 14728.0867085525
# Event data: Sum then square: 1.9227001392683656
# Event data: Square then sum: -1.1741732978457824
# For controls...
# Control start and end: 2005-04-09 03:00:00 2005-04-09 06:59:59
# 14197.831856716599
# Control data: Sum then square: -1.1929753239847751
# Control data: Square then sum: 1.183858997286034
# Control start and end: 2005-04-09 19:00:00 2005-04-09 22:59:59
# 14472.591360607832
# Control data: Sum then square: 0.4309587673444859
# Control data: Square then sum: 1.194174068703227
# EVENT COUNT 179
# 199 Oraworld Resonance 2005-04-23 00:50:00 2005-04-23 14:44:59 50100.0
# 50778.19028197319
# Event data: Sum then square: 2.1349964935608488
# Event data: Square then sum: 0.6733232280772512
# For controls...
# Control start and end: 2005-04-21 21:00:00 2005-04-22 10:54:59
# 50355.98611223558
# Control data: Sum then square: 0.8094228183428438
# Control data: Square then sum: 1.6461911339444195
# Control start and end: 2005-04-24 04:40:00 2005-04-24 18:34:59
# 50740.91394167769
# Control data: Sum then square: 2.0182579432550924
# Control data: Square then sum: 0.7149185842010916
# EVENT COUNT 180
# 200 Live 8 Concert 2005-07-02 00:00:00 2005-07-02 23:59:59 86400.0
# Before masking, fraction of nans in raw data is 0.09175617283950617 for 2005-07-02 00:00:00 to 2005-07-02 23:59:59
# Found 'rotten egg' entries for device id: 1026 in time range 2005-07-02 00:00:00 to 2005-07-02 23:59:59 (range: 2005-07-02 00:00:00 to 2005-07-04 23:59:59 )
# After masking, fraction of nans in raw data is 0.0963804012345679
# 85677.96148476713
# Event data: Sum then square: -1.740212101537482
# Event data: Square then sum: -1.271152234303781
# For controls...
# Control start and end: 2005-06-30 00:00:00 2005-06-30 23:59:59
# 86162.56538833932
# Control data: Sum then square: -0.5700988413192876
# Control data: Square then sum: 0.22606443349142605
# Control start and end: 2005-07-04 00:00:00 2005-07-04 23:59:59
# Before masking, fraction of nans in raw data is 0.07662615740740741 for 2005-07-04 00:00:00 to 2005-07-04 23:59:59
# Found 'rotten egg' entries for device id: 1026 in time range 2005-07-04 00:00:00 to 2005-07-04 23:59:59 (range: 2005-07-02 00:00:00 to 2005-07-04 23:59:59 )
# After masking, fraction of nans in raw data is 0.07821813512731482
# 85579.97313620697
# Control data: Sum then square: -1.9773487321063472
# Control data: Square then sum: -0.08961285640031576
# EVENT COUNT 181
# 201 London Subway Bombs 2005-07-07 00:00:00 2005-07-07 23:59:59 86400.0
# 86405.96061725345
# Event data: Sum then square: 0.015942429257801535
# Event data: Square then sum: 0.0892508907043611
# For controls...
# Control start and end: 2005-07-05 00:00:00 2005-07-05 23:59:59
# 86541.07063939454
# Control data: Sum then square: 0.34078222458865026
# Control data: Square then sum: 1.4810316148533942
# Control start and end: 2005-07-09 00:00:00 2005-07-09 23:59:59
# 87096.23810905234
# Control data: Sum then square: 1.672013365021571
# Control data: Square then sum: -0.2872465736932698
# EVENT COUNT 182
# 202 Hurricane Katrina 2005-08-29 10:00:00 2005-08-29 23:59:59 50400.0
# 50070.26287502848
# Event data: Sum then square: -1.0387469778719738
# Event data: Square then sum: -0.36552417529459474
# For controls...
# Control start and end: 2005-08-28 06:00:00 2005-08-28 19:59:59
# 49963.5006530532
# Control data: Sum then square: -1.376731599778271
# Control data: Square then sum: 0.281912032170013
# Control start and end: 2005-08-30 14:00:00 2005-08-31 03:59:59
# 50218.322396962
# Control data: Sum then square: -0.5708192517698806
# Control data: Square then sum: 0.816535352045674
# EVENT COUNT 183
# 203 Baghdad Bridge Stampede 2005-08-31 08:00:00 2005-08-31 12:59:59 18000.0
# 18457.593710215977
# Event data: Sum then square: 2.3950977874926074
# Event data: Square then sum: -3.3819177068327324
# For controls...
# Control start and end: 2005-08-30 22:00:00 2005-08-31 02:59:59
# 17977.697186147187
# Control data: Sum then square: -0.11408071928577398
# Control data: Square then sum: 1.02164931128617
# Control start and end: 2005-08-31 18:00:00 2005-08-31 22:59:59
# 18004.793498577943
# Control data: Sum then square: 0.028775286758531138
# Control data: Square then sum: 2.56032401264255
# EVENT COUNT 184
# 204 End the War Rally 2005-09-24 13:00:00 2005-09-24 19:59:59 25200.0
# 25608.497568058076
# Event data: Sum then square: 1.8128183085831169
# Event data: Square then sum: 1.1736276741282419
# For controls...
# Control start and end: 2005-09-23 23:00:00 2005-09-24 05:59:59
# 25175.665681177667
# Control data: Sum then square: -0.10545876679319383
# Control data: Square then sum: -0.10892837000631561
# Control start and end: 2005-09-25 03:00:00 2005-09-25 09:59:59
# 25678.12051380643
# Control data: Sum then square: 2.1193610052050875
# Control data: Square then sum: 1.1649467514760985
# EVENT COUNT 185
# 205 Bali Bombing 2 2005-10-01 11:30:00 2005-10-01 17:29:59 21600.0
# 22018.59480951063
# Event data: Sum then square: 2.0043028890430614
# Event data: Square then sum: 0.965600457658974
# For controls...
# Control start and end: 2005-09-30 23:30:00 2005-10-01 05:29:59
# 21946.473396186382
# Control data: Sum then square: 1.661343646776173
# Control data: Square then sum: 1.4049089861944553
# Control start and end: 2005-10-01 23:30:00 2005-10-02 05:29:59
# 21769.871820931636
# Control data: Sum then square: 0.8183688422695773
# Control data: Square then sum: 2.557969437073371
# EVENT COUNT 186
# 206 Earthquake Pakistan 2005-10-08 03:20:00 2005-10-08 11:19:59 28800.0
# 29111.41485064935
# Event data: Sum then square: 1.2956895929338166
# Event data: Square then sum: 0.5410072385491629
# For controls...
# Control start and end: 2005-10-07 11:20:00 2005-10-07 19:19:59
# 28984.48618067897
# Control data: Sum then square: 0.7698334724730367
# Control data: Square then sum: -0.40985021989629855
# Control start and end: 2005-10-08 19:20:00 2005-10-09 03:19:59
# 28530.197888646646
# Control data: Sum then square: -1.124925289883667
# Control data: Square then sum: 0.2433281744029841
# EVENT COUNT 187
# 207 India Train Crash 2005-10-28 21:30:00 2005-10-29 02:29:59 18000.0
# 18080.91232482287
# Event data: Sum then square: 0.4293204268394764
# Event data: Square then sum: 0.10991138309912193
# For controls...
# Control start and end: 2005-10-28 11:30:00 2005-10-28 16:29:59
# 17842.664825771328
# Control data: Sum then square: -0.8281414085765457
# Control data: Square then sum: -1.5050245143715337
# Control start and end: 2005-10-29 07:30:00 2005-10-29 12:29:59
# 18259.82716520553
# Control data: Sum then square: 1.3663847053060516
# Control data: Square then sum: 1.5548608951124816
# EVENT COUNT 188
# 208 India Bombs 2005-10-29 11:08:00 2005-10-29 16:07:59 18000.0
# 18076.599938827196
# Event data: Sum then square: 0.4066582700725373
# Event data: Square then sum: 1.4329346399932477
# For controls...
# Control start and end: 2005-10-29 01:08:00 2005-10-29 06:07:59
# 17762.515752253224
# Control data: Sum then square: -1.253681697712213
# Control data: Square then sum: -0.16815723795699367
# Control start and end: 2005-10-29 21:08:00 2005-10-30 02:07:59
# 17958.690515688762
# Control data: Sum then square: -0.21437255241778416
# Control data: Square then sum: 0.33585076902717215
# EVENT COUNT 189
# 209 Jordan Bombs 2005-11-09 18:00:00 2005-11-09 22:59:59 18000.0
# 18325.65153842635
# Event data: Sum then square: 1.709600072403502
# Event data: Square then sum: 0.45886525894755065
# For controls...
# Control start and end: 2005-11-09 08:00:00 2005-11-09 12:59:59
# 18268.50656153707
# Control data: Sum then square: 1.411687109694491
# Control data: Square then sum: 1.184258474795255
# Control start and end: 2005-11-10 04:00:00 2005-11-10 08:59:59
# 17970.544013949013
# Control data: Sum then square: -0.15181731218658992
# Control data: Square then sum: -1.9753240152851153
# EVENT COUNT 190
# 211 New Year Covar Min 2005-12-31 23:55:00 2006-01-01 00:04:59 600.0
# 543.0538455505279
# Event data: Sum then square: -1.6795821273829934
# Event data: Square then sum: 0.8723412885223144
# For controls...
# Control start and end: 2005-12-31 23:35:00 2005-12-31 23:44:59
# 595.512
# Control data: Sum then square: -0.11062327653104809
# Control data: Square then sum: -1.3390434516549083
# Control start and end: 2006-01-01 00:15:00 2006-01-01 00:24:59
# 588.246923076923
# Control data: Sum then square: -0.322244960849478
# Control data: Square then sum: -0.26894478349830236
# EVENT COUNT 191
# 212 Hadj Stoning 2006 2006-01-12 08:00:00 2006-01-12 11:59:59 14400.0
# 14592.387668971798
# Event data: Sum then square: 1.1325695836965435
# Event data: Square then sum: 0.6747164862143735
# For controls...
# Control start and end: 2006-01-12 00:00:00 2006-01-12 03:59:59
# 14514.268038361935
# Control data: Sum then square: 0.6754838420537289
# Control data: Square then sum: -0.8874122817365736
# Control start and end: 2006-01-12 16:00:00 2006-01-12 19:59:59
# 14517.214598190045
# Control data: Sum then square: 0.6927541586408914
# Control data: Square then sum: 1.1856628776454645
# EVENT COUNT 192
# 213 Mudslide, Philippines 2006-02-17 00:00:00 2006-02-17 23:59:59 86400.0
# 86954.14973925514
# Event data: Sum then square: 1.3318405831870193
# Event data: Square then sum: -0.028604508382221658
# For controls...
# Control start and end: 2006-02-15 00:00:00 2006-02-15 23:59:59
# 86750.15224842378
# Control data: Sum then square: 0.8428033810541034
# Control data: Square then sum: 0.5254189277780345
# Control start and end: 2006-02-19 00:00:00 2006-02-19 23:59:59
# 86235.80599861214
# Control data: Sum then square: -0.39363586247796095
# Control data: Square then sum: 0.03395123918845267
# EVENT COUNT 193
# 214 Golden Dome Bomb 2006-02-22 03:00:00 2006-02-22 06:59:59 14400.0
# 14294.241812780048
# Event data: Sum then square: -0.6207874960518626
# Event data: Square then sum: 1.763011604631744
# For controls...
# Control start and end: 2006-02-21 19:00:00 2006-02-21 22:59:59
# 14424.235472023132
# Control data: Sum then square: 0.14665668379516303
# Control data: Square then sum: 1.0201748300515543
# Control start and end: 2006-02-22 11:00:00 2006-02-22 14:59:59
# 14291.363941370082
# Control data: Sum then square: -0.637830162037337
# Control data: Square then sum: 0.43177487538546755
# EVENT COUNT 194
# 215 Planetary Play 2006-04-01 17:45:00 2006-04-01 18:14:59 1800.0
# 1799.5884589908433
# Event data: Sum then square: 0.004252080229460094
# Event data: Square then sum: 0.5790301558838915
# For controls...
# Control start and end: 2006-04-01 16:45:00 2006-04-01 17:14:59
# 1850.1445856019354
# Control data: Sum then square: 0.8391919160758355
# Control data: Square then sum: 1.3326840506433364
# Control start and end: 2006-04-01 18:45:00 2006-04-01 19:14:59
# 1816.375435417884
# Control data: Sum then square: 0.2832036590206186
# Control data: Square then sum: 1.2507251724873656
# EVENT COUNT 195
# 216 Earth Day, 2006 2006-04-22 00:00:00 2006-04-22 23:59:59 86400.0
# 86849.11308607871
# Event data: Sum then square: 1.0801348909054194
# Event data: Square then sum: 0.5594215294620686
# For controls...
# Control start and end: 2006-04-20 00:00:00 2006-04-20 23:59:59
# 86495.35388932689
# Control data: Sum then square: 0.23090507953062134
# Control data: Square then sum: 0.8421002481402156
# Control start and end: 2006-04-24 00:00:00 2006-04-24 23:59:59
# 86566.82116998294
# Control data: Sum then square: 0.4026548656340677
# Control data: Square then sum: 1.3222963623419748
# EVENT COUNT 196
# 217 Indonesian Earthquake 2006-05-26 21:54:00 2006-05-27 05:53:59 28800.0
# Before masking, fraction of nans in raw data is 0.07701361726785455 for 2006-05-27 00:00:00 to 2006-05-27 05:53:59
# Found 'rotten egg' entries for device id: 161 in time range 2006-05-27 00:00:00 to 2006-05-27 05:53:59 (range: 2006-05-01 00:00:00 to 2006-05-31 23:59:59 )
# After masking, fraction of nans in raw data is 0.07701361726785455
# 29452.643856808878
# Event data: Sum then square: 2.7018480264414793
# Event data: Square then sum: 0.8581469974624771
# For controls...
# Control start and end: 2006-05-26 05:54:00 2006-05-26 13:53:59
# 29101.767890111747
# Control data: Sum then square: 1.255776639125793
# Control data: Square then sum: 1.075545001426195
# Control start and end: 2006-05-27 13:54:00 2006-05-27 21:53:59
# Before masking, fraction of nans in raw data is 0.07135149572649573 for 2006-05-27 13:54:00 to 2006-05-27 21:53:59
# Found 'rotten egg' entries for device id: 161 in time range 2006-05-27 13:54:00 to 2006-05-27 21:53:59 (range: 2006-05-01 00:00:00 to 2006-05-31 23:59:59 )
# After masking, fraction of nans in raw data is 0.08673611111111111
# 28822.177428281397
# Control data: Sum then square: 0.09515984697962276
# Control data: Square then sum: -0.9197530991529328
# EVENT COUNT 197
# 218 Zarkawi News Release 2006-06-08 07:00:00 2006-06-08 14:59:59 28800.0
# 28530.398789258496
# Event data: Sum then square: -1.124082936422027
# Event data: Square then sum: -0.906922667055149
# For controls...
# Control start and end: 2006-06-07 15:00:00 2006-06-07 22:59:59
# 29156.704907256448
# Control data: Sum then square: 1.4829532173796791
# Control data: Square then sum: 0.41558200954120594
# Control start and end: 2006-06-08 23:00:00 2006-06-09 06:59:59
# 28720.445143578643
# Control data: Sum then square: -0.3290058555695054
# Control data: Square then sum: 0.5722901296889682
# EVENT COUNT 198
# 219 Bombay Train Bombings 2006-07-11 11:24:00 2006-07-11 16:23:59 18000.0
# 18163.497115193288
# Event data: Sum then square: 0.8626211878702206
# Event data: Square then sum: -0.4566837110637301
# For controls...
# Control start and end: 2006-07-11 01:24:00 2006-07-11 06:23:59
# 17984.516620031747
# Control data: Sum then square: -0.0781140846239262
# Control data: Square then sum: 0.27210456559031293
# Control start and end: 2006-07-11 21:24:00 2006-07-12 02:23:59
# 17802.49185117967
# Control data: Sum then square: -1.0412743963711002
# Control data: Square then sum: 0.07136975597543242
# EVENT COUNT 199
# 220 Avebury Meditations 2006-07-22 22:00:00 2006-07-22 22:59:59 3600.0
# 3688.691998491704
# Event data: Sum then square: 1.044623566963949
# Event data: Square then sum: -0.8163900539358336
# For controls...
# Control start and end: 2006-07-22 20:00:00 2006-07-22 20:59:59
# 3480.6514663593157
# Control data: Sum then square: -1.4145082108397613
# Control data: Square then sum: 0.6841533140125312
# Control start and end: 2006-07-23 00:00:00 2006-07-23 00:59:59
# 3544.3172775263956
# Control data: Sum then square: -0.6517743955070583
# Control data: Square then sum: 1.8068932663123312
# EVENT COUNT 200
# 221 Qana Lebanon 2006-07-30 01:00:00 2006-07-30 05:59:59 18000.0
# 18278.840013722125
# Event data: Sum then square: 1.4656042307559134
# Event data: Square then sum: 0.17479563775018503
# For controls...
# Control start and end: 2006-07-29 15:00:00 2006-07-29 19:59:59
# 17919.49512433862
# Control data: Sum then square: -0.4214171991268355
# Control data: Square then sum: 0.6739262828630348
# Control start and end: 2006-07-30 11:00:00 2006-07-30 15:59:59
# 18098.559518278016
# Control data: Sum then square: 0.5220212433312221
# Control data: Square then sum: 0.22551715938815503
# EVENT COUNT 201
# 222 British Terror Plot 2006-08-10 00:00:00 2006-08-10 23:59:59 86400.0
# 87003.9977659504
# Event data: Sum then square: 1.4512235434296827
# Event data: Square then sum: -0.16087904732758682
# For controls...
# Control start and end: 2006-08-08 00:00:00 2006-08-08 23:59:59
# 86253.92953667692
# Control data: Sum then square: -0.34998516403742236
# Control data: Square then sum: -0.18370435234409666
# Control start and end: 2006-08-12 00:00:00 2006-08-12 23:59:59
# 86191.08531124714
# Control data: Sum then square: -0.5013722006676335
# Control data: Square then sum: 1.1502061487443496
# EVENT COUNT 202
# 224 Oraworld Reconciliation 2006-10-02 12:00:00 2006-10-02 23:59:59 43200.0
# 43172.5422157051
# Event data: Sum then square: -0.09116490881669047
# Event data: Square then sum: 0.9949487998980137
# For controls...
# Control start and end: 2006-10-01 12:00:00 2006-10-01 23:59:59
# 43274.70667445938
# Control data: Sum then square: 0.25627863080026303
# Control data: Square then sum: 1.3132629341722133
# Control start and end: 2006-10-03 12:00:00 2006-10-03 23:59:59
# 43270.90907070249
# Control data: Sum then square: 0.2433734319782172
# Control data: Square then sum: 0.6229894492491962
# EVENT COUNT 203
# 225 Native American Earth Ceremony 2006-10-07 03:00:00 2006-10-07 03:14:59 900.0
# 924.8981498015871
# Event data: Sum then square: 0.5972074155789022
# Event data: Square then sum: 0.7045770036982252
# For controls...
# Control start and end: 2006-10-07 02:30:00 2006-10-07 02:44:59
# 887.1597767857143
# Control data: Sum then square: -0.2883652568320525
# Control data: Square then sum: 2.3650534180087996
# Control start and end: 2006-10-07 03:30:00 2006-10-07 03:44:59
# 877.6877204941114
# Control data: Sum then square: -0.5145683748668324
# Control data: Square then sum: -0.9752445548220133
# EVENT COUNT 204
# 226 Election 2006 Results 2006-11-08 13:00:00 2006-11-08 20:59:59 28800.0
# 29106.958876208635
# Event data: Sum then square: 1.2772547151462268
# Event data: Square then sum: -0.8606226418581987
# For controls...
# Control start and end: 2006-11-07 21:00:00 2006-11-08 04:59:59
# 28620.70812920524
# Control data: Sum then square: -0.7458261197685728
# Control data: Square then sum: -0.03435707311650795
# Control start and end: 2006-11-09 05:00:00 2006-11-09 12:59:59
# 28814.769266053056
# Control data: Sum then square: 0.06430575598738184
# Control data: Square then sum: 1.474330220582846
# EVENT COUNT 205
# 227 Gemayel Assassination 2006-11-21 10:00:00 2006-11-21 13:59:59 14400.0
# 14233.198568542568
# Event data: Sum then square: -0.98277559054879
# Event data: Square then sum: 0.009138343747874925
# For controls...
# Control start and end: 2006-11-21 02:00:00 2006-11-21 05:59:59
# 14625.05295021645
# Control data: Sum then square: 1.323214236753706
# Control data: Square then sum: 0.6122132214936062
# Control start and end: 2006-11-21 18:00:00 2006-11-21 21:59:59
# 14215.328318181817
# Control data: Sum then square: -1.0889426302560548
# Control data: Square then sum: 0.6967582444309164
# EVENT COUNT 206
# 228 Global Deeksha 2006-11-23 16:30:00 2006-11-23 17:29:59 3600.0
# 3585.4562881355923
# Event data: Sum then square: -0.16377115137122567
# Event data: Square then sum: -0.5731744591021938
# For controls...
# Control start and end: 2006-11-23 14:30:00 2006-11-23 15:29:59
# 3596.156306838106
# Control data: Sum then square: -0.03745694364402682
# Control data: Square then sum: -0.06146455672383392
# Control start and end: 2006-11-23 18:30:00 2006-11-23 19:29:59
# 3565.290411688432
# Control data: Sum then square: -0.4025153329354179
# Control data: Square then sum: -0.7067602976888602
# EVENT COUNT 207
# 229 Global Orgasm 2006-12-22 00:00:00 2006-12-22 23:59:59 86400.0
# 86628.18872201655
# Event data: Sum then square: 0.5500576317579567
# Event data: Square then sum: -0.3568411578976713
# For controls...
# Control start and end: 2006-12-20 00:00:00 2006-12-20 23:59:59
# 86670.57466962606
# Control data: Sum then square: 0.6518265996730456
# Control data: Square then sum: 1.55446349926087
# Control start and end: 2006-12-24 00:00:00 2006-12-24 23:59:59
# 86112.44596820026
# Control data: Sum then square: -0.690912204856937
# Control data: Square then sum: -0.37613478825250624
# EVENT COUNT 208
# 230 Saddam's Execution 2006-12-30 03:00:00 2006-12-30 16:59:59 50400.0
# 50426.90118859778
# Event data: Sum then square: 0.08681542058399006
# Event data: Square then sum: -0.5712027074270183
# For controls...
# Control start and end: 2006-12-28 23:00:00 2006-12-29 12:59:59
# 50571.58798713202
# Control data: Sum then square: 0.5419384576689131
# Control data: Square then sum: 1.3781949446371236
# Control start and end: 2006-12-31 07:00:00 2006-12-31 20:59:59
# 50113.69049179132
# Control data: Sum then square: -0.901402680341428
# Control data: Square then sum: -0.5896051203928683
# EVENT COUNT 209
# 231 New Year Mean 2006-2007 2006-12-31 09:30:00 2007-01-01 12:29:59 97200.0
# 97154.94065907496
# Event data: Sum then square: -0.10070036685147156
# Event data: Square then sum: -0.21361212471607094
# For controls...
# Control start and end: 2006-12-29 03:30:00 2006-12-30 06:29:59
# 97127.75771793707
# Control data: Sum then square: -0.16237730818312493
# Control data: Square then sum: 2.000915943599925
# Control start and end: 2007-01-02 15:30:00 2007-01-03 18:29:59
# 96447.84689833815
# Control data: Sum then square: -1.7088250834064418
# Control data: Square then sum: 1.0284665856867887
# EVENT COUNT 210
# 233 European Storms 2007-01-18 00:00:00 2007-01-18 23:59:59 86400.0
# 86945.97858368157
# Event data: Sum then square: 1.312266818005118
# Event data: Square then sum: -0.8479882746974461
# For controls...
# Control start and end: 2007-01-16 00:00:00 2007-01-16 23:59:59
# 86392.91954399562
# Control data: Sum then square: -0.01542963262671142
# Control data: Square then sum: 0.27996153220838005
# Control start and end: 2007-01-20 00:00:00 2007-01-20 23:59:59
# 86741.1286262482
# Control data: Sum then square: 0.8211536251833986
# Control data: Square then sum: 0.697161292193281
# EVENT COUNT 211
# 234 Iraq Worst Bombing 2007-02-03 16:00:00 2007-02-03 20:59:59 18000.0
# 18143.661649448622
# Event data: Sum then square: 0.7586696629770052
# Event data: Square then sum: -0.6168808364778955
# For controls...
# Control start and end: 2007-02-03 06:00:00 2007-02-03 10:59:59
# 18134.301170372608
# Control data: Sum then square: 0.7095879990182494
# Control data: Square then sum: -0.570573767721432
# Control start and end: 2007-02-04 02:00:00 2007-02-04 06:59:59
# 18083.73853516658
# Control data: Sum then square: 0.44417058086698574
# Control data: Square then sum: 0.4753771305250897
# EVENT COUNT 212
# 235 World Sound Healing 2007-02-14 00:00:00 2007-02-14 23:59:59 86400.0
# 86391.39370713018
# Event data: Sum then square: -0.019100445448727202
# Event data: Square then sum: -0.3291903229881182
# For controls...
# Control start and end: 2007-02-12 00:00:00 2007-02-12 23:59:59
# 86387.70402101513
# Control data: Sum then square: -0.027977160890715093
# Control data: Square then sum: 2.1798055043083355
# Control start and end: 2007-02-16 00:00:00 2007-02-16 23:59:59
# 86620.49811778514
# Control data: Sum then square: 0.5315888781846847
# Control data: Square then sum: 0.050326280457845894
# EVENT COUNT 213
# 236 India Train Fire 2007-02-18 17:30:00 2007-02-18 22:29:59 18000.0
# 17787.98152941237
# Event data: Sum then square: -1.1183360878417186
# Event data: Square then sum: 1.043067012187991
# For controls...
# Control start and end: 2007-02-18 07:30:00 2007-02-18 12:29:59
# 18334.817256996674
# Control data: Sum then square: 1.7573259850194314
# Control data: Square then sum: 1.3022630707561733
# Control start and end: 2007-02-19 03:30:00 2007-02-19 08:29:59
# 18229.952512842596
# Control data: Sum then square: 1.2103432349496588
# Control data: Square then sum: -0.737611792021419
# EVENT COUNT 214
# 237 Earth Hour 2007-03-31 09:30:00 2007-03-31 10:29:59 3600.0
# 3526.9442521996853
# Event data: Sum then square: -0.8589939228738076
# Event data: Square then sum: -0.9647821716753716
# For controls...
# Control start and end: 2007-03-31 07:30:00 2007-03-31 08:29:59
# 3728.439649717514
# Control data: Sum then square: 1.5038736506294752
# Control data: Square then sum: 0.41224505562108915
# Control start and end: 2007-03-31 11:30:00 2007-03-31 12:29:59
# 3654.315513661202
# Control data: Sum then square: 0.6447702492321654
# Control data: Square then sum: 0.0466652075597714
# EVENT COUNT 215
# 238 Solomon Islands Quake 2007-04-01 19:00:00 2007-04-01 23:59:59 18000.0
# 18136.287954722866
# Event data: Sum then square: 0.7200071118991952
# Event data: Square then sum: 0.2781519410237952
# For controls...
# Control start and end: 2007-04-01 09:00:00 2007-04-01 13:59:59
# 18285.538034528632
# Control data: Sum then square: 1.5005418275420956
# Control data: Square then sum: 1.9094956311922147
# Control start and end: 2007-04-02 05:00:00 2007-04-02 09:59:59
# 18058.67924425642
# Control data: Sum then square: 0.31244404180764507
# Control data: Square then sum: -0.1323651028588487
# EVENT COUNT 216
# 239 Massacre at Virginia Tech 2007-04-16 10:00:00 2007-04-16 16:59:59 25200.0
# 25489.488123772313
# Event data: Sum then square: 1.2875444627468593
# Event data: Square then sum: 1.0281728327144315
# For controls...
# Control start and end: 2007-04-15 20:00:00 2007-04-16 02:59:59
# 24966.775092847412
# Control data: Sum then square: -1.0391167355677895
# Control data: Square then sum: 0.24732101419849892
# Control start and end: 2007-04-17 00:00:00 2007-04-17 06:59:59
# 25079.577383401516
# Control data: Sum then square: -0.5342910332252284
# Control data: Square then sum: 0.24220186641703675
# EVENT COUNT 217
# 240 Tai Chi Chigong Day 2007-04-28 00:00:00 2007-04-28 23:59:59 86400.0
# 86626.62543320021
# Event data: Sum then square: 0.5463035294202931
# Event data: Square then sum: 0.9578256598949632
# For controls...
# Control start and end: 2007-04-26 00:00:00 2007-04-26 23:59:59
# 86422.71302110593
# Control data: Sum then square: 0.0562379662422428
# Control data: Square then sum: 0.5131610750954884
# Control start and end: 2007-04-30 00:00:00 2007-04-30 23:59:59
# 86452.12140378043
# Control data: Sum then square: 0.12696307728512657
# Control data: Square then sum: 0.7561760948955679
# EVENT COUNT 218
# 241 World Meditation Aggregation 2007-05-20 04:00:00 2007-05-20 06:59:59 10800.0
# 10608.058323232322
# Event data: Sum then square: -1.309272931801586
# Event data: Square then sum: 0.958066483495121
# For controls...
# Control start and end: 2007-05-19 22:00:00 2007-05-20 00:59:59
# 10638.592602884186
# Control data: Sum then square: -1.0992157467871673
# Control data: Square then sum: -1.3169512637013239
# Control start and end: 2007-05-20 10:00:00 2007-05-20 12:59:59
# 10578.886344155842
# Control data: Sum then square: -1.5103357311330479
# Control data: Square then sum: 0.24331063738258804
# EVENT COUNT 219
# 242 Lightning Strikes Giuliani 2007-06-06 23:00:00 2007-06-06 23:59:59 3600.0
# 3650.9299419448475
# Event data: Sum then square: 0.6052554229249092
# Event data: Square then sum: 1.5973571999575111
# For controls...
# Control start and end: 2007-06-06 21:00:00 2007-06-06 21:59:59
# 3692.44358490566
# Control data: Sum then square: 1.0881101887903735
# Control data: Square then sum: 0.17350691065634383
# Control start and end: 2007-06-07 01:00:00 2007-06-07 01:59:59
# 3530.1705550180077
# Control data: Sum then square: -0.8204602334011168
# Control data: Square then sum: -0.12542700539026824
# EVENT COUNT 220
# 243 Palestinian Government Falls 2007-06-14 00:00:00 2007-06-14 23:59:59 86400.0
# 86728.8987541323
# Event data: Sum then square: 0.7918089385660012
# Event data: Square then sum: 1.5097126650453447
# For controls...
# Control start and end: 2007-06-12 00:00:00 2007-06-12 23:59:59
# 86416.59340791371
# Control data: Sum then square: 0.04151870635423421
# Control data: Square then sum: 1.2838286269124977
# Control start and end: 2007-06-16 00:00:00 2007-06-16 23:59:59
# 86156.99953161024
# Control data: Sum then square: -0.5835130811706154
# Control data: Square then sum: -0.30688476138192955
# EVENT COUNT 221
# 244 Live Earth 2007-07-07 00:00:00 2007-07-07 23:59:59 86400.0
# 86583.05147024349
# Event data: Sum then square: 0.4416462657774457
# Event data: Square then sum: -0.57566019897692
# For controls...
# Control start and end: 2007-07-05 00:00:00 2007-07-05 23:59:59
# 86512.11334850862
# Control data: Sum then square: 0.27118981008059295
# Control data: Square then sum: -0.37633313341096886
# Control start and end: 2007-07-09 00:00:00 2007-07-09 23:59:59
# 85886.21414142735
# Control data: Sum then square: -1.2368306194137926
# Control data: Square then sum: 1.235386097024877
# EVENT COUNT 222
# 245 Fire The Grid 2007-07-17 11:11:00 2007-07-17 12:10:59 3600.0
# 3727.1902392087295
# Event data: Sum then square: 1.4894874656479304
# ...
# Found 'rotten egg' entries for device id: 1251 in time range 2014-09-19 00:00:00 to 2014-09-19 23:59:59 (range: 2014-03-14 00:00:00 to 2024-02-13 20:07:27 )
# After masking, fraction of nans in raw data is 0.06983311800172265
# 85951.88431174087
# Control data: Sum then square: -1.0782637071714642
# Control data: Square then sum: 0.501548655027535
# Control start and end: 2014-09-23 00:00:00 2014-09-23 23:59:59
# Before masking, fraction of nans in raw data is 0.029715057319223987 for 2014-09-23 00:00:00 to 2014-09-23 23:59:59
# Found 'rotten egg' entries for device id: 1251 in time range 2014-09-23 00:00:00 to 2014-09-23 23:59:59 (range: 2014-03-14 00:00:00 to 2024-02-13 20:07:27 )
# After masking, fraction of nans in raw data is 0.0535245811287478
# 86709.02034412953
# Control data: Sum then square: 0.7441062581181592
# Control data: Square then sum: 0.36292775598873017
# EVENT COUNT 457
# 488 Ottowa Terror Shooting 2014-09-22 14:00:00 2014-09-22 19:59:59 21600.0
# Before masking, fraction of nans in raw data is 0.044891975308641974 for 2014-09-22 14:00:00 to 2014-09-22 19:59:59
# Found 'rotten egg' entries for device id: 1251 in time range 2014-09-22 14:00:00 to 2014-09-22 19:59:59 (range: 2014-03-14 00:00:00 to 2024-02-13 20:07:27 )
# After masking, fraction of nans in raw data is 0.06870149911816578
# 21543.972475033737
# Event data: Sum then square: -0.2665877757488569
# Event data: Square then sum: -0.9108424523368855
# For controls...
# Control start and end: 2014-09-22 02:00:00 2014-09-22 07:59:59
# Before masking, fraction of nans in raw data is 0.02382936507936508 for 2014-09-22 02:00:00 to 2014-09-22 07:59:59
# Found 'rotten egg' entries for device id: 1251 in time range 2014-09-22 02:00:00 to 2014-09-22 07:59:59 (range: 2014-03-14 00:00:00 to 2024-02-13 20:07:27 )
# After masking, fraction of nans in raw data is 0.04763888888888889
# 21835.93488461538
# Control data: Sum then square: 1.1342399584690601
# Control data: Square then sum: 0.016817150365919332
# Control start and end: 2014-09-23 02:00:00 2014-09-23 07:59:59
# Before masking, fraction of nans in raw data is 0.02984567901234568 for 2014-09-23 02:00:00 to 2014-09-23 07:59:59
# Found 'rotten egg' entries for device id: 1251 in time range 2014-09-23 02:00:00 to 2014-09-23 07:59:59 (range: 2014-03-14 00:00:00 to 2024-02-13 20:07:27 )
# After masking, fraction of nans in raw data is 0.05365520282186949
# 21646.610582321184
# Control data: Sum then square: 0.22730109713043853
# Control data: Square then sum: -1.2030867096353537
# EVENT COUNT 458
# 489 Nigeria School Bombing 2014-11-10 07:00:00 2014-11-10 12:59:59 21600.0
# 21322.342686897427
# Event data: Sum then square: -1.3384357437064551
# Event data: Square then sum: 0.7695885877476366
# For controls...
# Control start and end: 2014-11-09 19:00:00 2014-11-10 00:59:59
# 21288.542074442863
# Control data: Sum then square: -1.5025549362227104
# Control data: Square then sum: 1.0695598828053727
# Control start and end: 2014-11-10 19:00:00 2014-11-11 00:59:59
# 21318.611635846377
# Control data: Sum then square: -1.3565433678064618
# Control data: Square then sum: 0.13638465660626167
# EVENT COUNT 459
# 490 Sydney Hostage Crisis 2014-12-14 22:00:00 2014-12-15 15:59:59 64800.0
# 64538.13931405089
# Event data: Sum then square: -0.7265204428119659
# Event data: Square then sum: -0.9134281631929029
# For controls...
# Control start and end: 2014-12-13 10:00:00 2014-12-14 03:59:59
# 64488.54196301567
# Control data: Sum then square: -0.8646986355356354
# Control data: Square then sum: 0.49659875378652274
# Control start and end: 2014-12-16 10:00:00 2014-12-17 03:59:59
# 65180.554474474484
# Control data: Sum then square: 1.0568844168068299
# Control data: Square then sum: 0.3091846322448055
# EVENT COUNT 460
# 491 Pakistani School Slaughter 2014-12-16 05:00:00 2014-12-16 14:59:59 36000.0
# 36069.848807491704
# Event data: Sum then square: 0.26262709251908445
# Event data: Square then sum: -0.4002702714900372
# For controls...
# Control start and end: 2014-12-15 09:00:00 2014-12-15 18:59:59
# 36066.12801801802
# Control data: Sum then square: 0.24877798005380158
# Control data: Square then sum: -0.2460631539862369
# Control start and end: 2014-12-17 01:00:00 2014-12-17 10:59:59
# 36149.21429429429
# Control data: Sum then square: 0.5578060605802087
# Control data: Square then sum: 0.15055649236158078
# EVENT COUNT 461
# 492 Winter Solstice 2014-12-21 00:00:00 2014-12-21 23:59:59 86400.0
# 86045.75285511077
# Event data: Sum then square: -0.8517493564431378
# Event data: Square then sum: 0.24172141207506515
# For controls...
# Control start and end: 2014-12-19 00:00:00 2014-12-19 23:59:59
# 86919.2412059428
# Control data: Sum then square: 1.2482096397816864
# Control data: Square then sum: 0.4995358496580186
# Control start and end: 2014-12-23 00:00:00 2014-12-23 23:59:59
# 86575.58691848992
# Control data: Sum then square: 0.42371415742146057
# Control data: Square then sum: 1.4811762586585517
# EVENT COUNT 462
# 493 Air Asia Loss 2014-12-28 00:00:00 2014-12-28 05:59:59 21600.0
# 21758.767652916078
# Event data: Sum then square: 0.7652131839655971
# Event data: Square then sum: 1.2247025557062676
# For controls...
# Control start and end: 2014-12-27 12:00:00 2014-12-27 17:59:59
# 21664.26265686739
# Control data: Sum then square: 0.31208447721289745
# Control data: Square then sum: -0.3303377588302515
# Control start and end: 2014-12-28 12:00:00 2014-12-28 17:59:59
# 21671.236585695005
# Control data: Sum then square: 0.34556775268600953
# Control data: Square then sum: -0.9901565009087671
# EVENT COUNT 463
# 494 New Year Mean 2015 2014-12-31 09:30:00 2015-01-01 12:29:59 97200.0
# 97594.15939860913
# Event data: Sum then square: 0.8942776490637433
# Event data: Square then sum: 0.7179534941071835
# For controls...
# Control start and end: 2014-12-29 03:30:00 2014-12-30 06:29:59
# 96975.55072509755
# Control data: Sum then square: -0.5079413319987733
# Control data: Square then sum: -0.41732312816833567
# Control start and end: 2015-01-02 15:30:00 2015-01-03 18:29:59
# 96616.70067580332
# Control data: Sum then square: -1.324092596659343
# Control data: Square then sum: -0.38371633416706646
# EVENT COUNT 464
# 496 Charlie Hebdo & Yemen 2015-01-07 05:00:00 2015-01-07 16:59:59 43200.0
# 43514.38619433197
# Event data: Sum then square: 1.0692466203872772
# Event data: Square then sum: 1.2482491780045972
# For controls...
# Control start and end: 2015-01-06 05:00:00 2015-01-06 16:59:59
# 43014.223710909275
# Control data: Sum then square: -0.6306631674825204
# Control data: Square then sum: -0.2572888891979718
# Control start and end: 2015-01-08 05:00:00 2015-01-08 16:59:59
# 43459.344580552206
# Control data: Sum then square: 0.882815653182972
# Control data: Square then sum: 1.0170000982049332
# EVENT COUNT 465
# 497 Millions Rally for Unity 2015-01-11 12:00:00 2015-01-11 23:59:59 43200.0
# 43269.54334615384
# Event data: Sum then square: 0.23873217688620169
# Event data: Square then sum: 0.38909018545882
# For controls...
# Control start and end: 2015-01-10 12:00:00 2015-01-10 23:59:59
# 42921.54783333332
# Control data: Sum then square: -0.9470872775789344
# Control data: Square then sum: 0.7609649005757531
# Control start and end: 2015-01-12 12:00:00 2015-01-12 23:59:59
# 43665.16179341284
# Control data: Sum then square: 1.5791340177821829
# Control data: Square then sum: -0.5924397564259882
# EVENT COUNT 466
# 498 Terror attacks in Denmark 2015-02-14 14:30:00 2015-02-15 00:29:59 36000.0
# 35797.81751045295
# Event data: Sum then square: -0.7524191799170539
# Event data: Square then sum: 1.2111979400071782
# For controls...
# Control start and end: 2015-02-13 18:30:00 2015-02-14 04:29:59
# 35779.76548030018
# Control data: Sum then square: -0.8199595132945273
# Control data: Square then sum: 0.617614078843698
# Control start and end: 2015-02-15 10:30:00 2015-02-15 20:29:59
# 36046.95895393501
# Control data: Sum then square: 0.17741390640012578
# Control data: Square then sum: 0.5020060864640533
# EVENT COUNT 467
# 499 ISIS beheads Copts in Libya 2015-02-15 18:00:00 2015-02-15 23:59:59 21600.0
# 21807.211044134725
# Event data: Sum then square: 0.9969793434758896
# Event data: Square then sum: 0.9464268022503715
# For controls...
# Control start and end: 2015-02-15 06:00:00 2015-02-15 11:59:59
# 21627.56295121951
# Control data: Sum then square: 0.1357631133372114
# Control data: Square then sum: 0.1502059868866395
# Control start and end: 2015-02-16 06:00:00 2015-02-16 11:59:59
# 21452.67350754936
# Control data: Sum then square: -0.7072335780093624
# Control data: Square then sum: 1.4043325466730012
# EVENT COUNT 468
# 500 Yemen Mosque Bombings 2015-03-20 08:00:00 2015-03-20 13:59:59 21600.0
# 21490.1933076923
# Event data: Sum then square: -0.525996731911852
# Event data: Square then sum: 0.06950328354024779
# For controls...
# Control start and end: 2015-03-19 20:00:00 2015-03-20 01:59:59
# 21326.88883333333
# Control data: Sum then square: -1.316375137462737
# Control data: Square then sum: 0.391279668700555
# Control start and end: 2015-03-20 20:00:00 2015-03-21 01:59:59
# 21223.227871120103
# Control data: Sum then square: -1.8201821193278171
# Control data: Square then sum: -0.044205586725931834
# EVENT COUNT 469
# 501 Germanwings Crash 2015-03-24 09:30:00 2015-03-24 15:29:59 21600.0
# 21399.387129455907
# Event data: Sum then square: -0.9649935578468452
# Event data: Square then sum: 1.040231026139029
# For controls...
# Control start and end: 2015-03-23 21:30:00 2015-03-24 03:29:59
# 21920.763768292683
# Control data: Sum then square: 1.5389051549740742
# Control data: Square then sum: -0.1263734010280468
# Control start and end: 2015-03-24 21:30:00 2015-03-25 03:29:59
# 21640.16293902439
# Control data: Sum then square: 0.19632140599802847
# Control data: Square then sum: -0.4086757306742281
# EVENT COUNT 470
# 502 Global Meditation Day 2015-04-22 03:00:00 2015-04-22 17:59:59 54000.0
# 53769.14285917497
# Event data: Sum then square: -0.7014501443407787
# Event data: Square then sum: -1.5461825888271072
# For controls...
# Control start and end: 2015-04-20 21:00:00 2015-04-21 11:59:59
# 54200.607012802284
# Control data: Sum then square: 0.6117014093205148
# Control data: Square then sum: 0.13959542262498062
# Control start and end: 2015-04-23 09:00:00 2015-04-23 23:59:59
# 54461.739829302984
# Control data: Sum then square: 1.4030718963207853
# Control data: Square then sum: -1.0267977205748522
# EVENT COUNT 471
# 503 Nepal Earthquake 2015-04-25 05:15:00 2015-04-26 05:14:59 86400.0
# 86364.04680950263
# Event data: Sum then square: -0.08489812673868445
# Event data: Square then sum: -1.2634872700619015
# For controls...
# Control start and end: 2015-04-23 05:15:00 2015-04-24 05:14:59
# 86522.0552916074
# Control data: Sum then square: 0.2950848114030631
# Control data: Square then sum: -1.278627137355203
# Control start and end: 2015-04-27 05:15:00 2015-04-28 05:14:59
# 86178.20226493597
# Control data: Sum then square: -0.5324155850894748
# Control data: Square then sum: 0.5957360303195711
# EVENT COUNT 472
# 504 Fuji Peace Declaration 2015-05-17 01:00:00 2015-05-17 04:59:59 14400.0
# 14381.085481997676
# Event data: Sum then square: -0.10757488826501695
# Event data: Square then sum: 1.042886630696618
# For controls...
# Control start and end: 2015-05-16 17:00:00 2015-05-16 20:59:59
# 14401.068617886176
# Control data: Sum then square: 0.010225095373388515
# Control data: Square then sum: 1.1606306016050534
# Control start and end: 2015-05-17 09:00:00 2015-05-17 12:59:59
# 14386.750046457608
# Control data: Sum then square: -0.07417137428966092
# Control data: Square then sum: -0.09443945853576731
# EVENT COUNT 473
# 505 Charleston Hate Crime 2015-05-18 00:00:00 2015-05-18 07:59:59 28800.0
# 28627.990444048293
# Event data: Sum then square: -0.7153591635615416
# Event data: Square then sum: 0.2730782560649269
# For controls...
# Control start and end: 2015-05-17 08:00:00 2015-05-17 15:59:59
# 29018.219082462252
# Control data: Sum then square: 0.9097358382760251
# Control data: Square then sum: -0.5625395807779235
# Control start and end: 2015-05-18 16:00:00 2015-05-18 23:59:59
# 29088.815274680597
# Control data: Sum then square: 1.202173136769108
# Control data: Square then sum: 0.5852895803165113
# EVENT COUNT 474
# 506 Iran Nuclear Deal 2015-07-14 10:25:00 2015-07-14 16:24:59 21600.0
# 21876.463178464175
# Event data: Sum then square: 1.3277052917357177
# Event data: Square then sum: 0.28214254975235586
# For controls...
# Control start and end: 2015-07-13 22:25:00 2015-07-14 04:24:59
# 21762.98078078078
# Control data: Sum then square: 0.785383556631494
# Control data: Square then sum: 0.8741983302391357
# Control start and end: 2015-07-14 22:25:00 2015-07-15 04:24:59
# 21710.75988795518
# Control data: Sum then square: 0.5351917618117329
# Control data: Square then sum: 0.42434024510843027
# EVENT COUNT 475
# 507 Mecca Crane Falls 2015-09-11 13:00:00 2015-09-11 18:59:59 21600.0
# 21680.366219512194
# Event data: Sum then square: 0.38939016140751814
# Event data: Square then sum: 1.364534645641363
# For controls...
# Control start and end: 2015-09-11 01:00:00 2015-09-11 06:59:59
# 21591.966451219512
# Control data: Sum then square: -0.035448614356022104
# Control data: Square then sum: 0.13541339284341303
# Control start and end: 2015-09-12 01:00:00 2015-09-12 06:59:59
# 21597.78440243902
# Control data: Sum then square: -0.007452627167054984
# Control data: Square then sum: 0.8310532435604732
# EVENT COUNT 476
# 509 Hadj Stampede 2015 2015-09-24 05:00:00 2015-09-24 08:59:59 14400.0
# 14547.981634146341
# Event data: Sum then square: 0.8729459484775477
# Event data: Square then sum: 1.5507542831462093
# For controls...
# Control start and end: 2015-09-23 21:00:00 2015-09-24 00:59:59
# 14550.577368042526
# Control data: Sum then square: 0.888136639668112
# Control data: Square then sum: -0.4263731719454153
# Control start and end: 2015-09-24 13:00:00 2015-09-24 16:59:59
# 14363.32412195122
# Control data: Sum then square: -0.2123692152188797
# Control data: Square then sum: -0.036345415330580465
# EVENT COUNT 477
# 510 Turkey Peace Bombing 2015-10-10 09:00:00 2015-10-10 14:59:59 21600.0
# 21684.329460317458
# Event data: Sum then square: 0.40840996121117573
# Event data: Square then sum: 0.1322909863909105
# For controls...
# Control start and end: 2015-10-09 21:00:00 2015-10-10 02:59:59
# 21795.368597572364
# Control data: Sum then square: 0.9403536071931649
# Control data: Square then sum: -1.4034310854433936
# Control start and end: 2015-10-10 21:00:00 2015-10-11 02:59:59
# 21764.877541549955
# Control data: Sum then square: 0.7944634599112128
# Control data: Square then sum: -0.5142495741061159
# EVENT COUNT 478
# 511 Paris Terror 2015-11-13 20:00:00 2015-11-14 01:59:59 21600.0
# 21418.580628205127
# Event data: Sum then square: -0.8721003575569224
# Event data: Square then sum: 0.21408318728533793
# For controls...
# Control start and end: 2015-11-13 08:00:00 2015-11-13 13:59:59
# 21869.97904183535
# Control data: Sum then square: 1.296768751308523
# Control data: Square then sum: 1.0921443033090579
# Control start and end: 2015-11-14 08:00:00 2015-11-14 13:59:59
# 21691.77215384615
# Control data: Sum then square: 0.4441215770012618
# Control data: Square then sum: -0.29570633723784245
# EVENT COUNT 479
# 512 Arbaeen, Hussein 2015-12-03 00:00:00 2015-12-03 23:59:59 86400.0
# 86195.57609986505
# Event data: Sum then square: -0.49055178560192547
# Event data: Square then sum: 0.851574751663616
# For controls...
# Control start and end: 2015-12-01 00:00:00 2015-12-01 23:59:59
# 86547.22990553305
# Control data: Sum then square: 0.35558265021641416
# Control data: Square then sum: 1.8913221045450777
# Control start and end: 2015-12-05 00:00:00 2015-12-05 23:59:59
# 85957.09457422399
# Control data: Sum then square: -1.065686489940408
# Control data: Square then sum: 0.0039055632923820794
# EVENT COUNT 480
# 513 Climate Agreement, Day 1 World Peace 2015-12-12 00:00:00 2015-12-12 23:59:59 86400.0
# 86821.18977477477
# Event data: Sum then square: 1.0131864407951185
# Event data: Square then sum: 0.2642333177440966
# For controls...
# Control start and end: 2015-12-10 00:00:00 2015-12-10 23:59:59
# 87099.31334706134
# Control data: Sum then square: 1.6793716818696325
# Control data: Square then sum: 1.5681595316009354
# Control start and end: 2015-12-14 00:00:00 2015-12-14 23:59:59
# 86477.24825740025
# Control data: Sum then square: 0.187378704663729
# Control data: Square then sum: -0.2875133510185635

# %%
from matplotlib import pyplot as plt

print("num events after dropping events with missing data:", len(surviving_events))

for (touse_pvaltozs_sumthensquare, touse_pvaltozs_squarethensum, testtype) in (
    [ (allevents_pvaltozs_sumthensquare, allevents_pvaltozs_squarethensum, "actual")]
    +[ (controls_pvaltozs_sumthensquare[control_timeshift],
        controls_pvaltozs_squarethensum[control_timeshift],
        "controltimeshift_"+str(control_timeshift))
        for control_timeshift in control_timeshifts ]):

  print("************TIME PERIODS:", testtype)

  pvaltoz_sumthensquare = np.array(touse_pvaltozs_sumthensquare)
  pvaltoz_squarethensum = np.array(touse_pvaltozs_squarethensum)

  metaz_sumthensquare = np.sum(pvaltoz_sumthensquare)/np.sqrt(len(pvaltoz_sumthensquare))
  metaz_squarethensum = np.sum(pvaltoz_squarethensum)/np.sqrt(len(pvaltoz_squarethensum))
  print("Meta-analysis Z-score if squaring *after* summing:", metaz_sumthensquare, "pval:", 1-scipy.stats.norm.cdf(metaz_sumthensquare))
  print("Meta-analysis Z-score if squaring *before* summing", metaz_squarethensum, "pval: ", 1-scipy.stats.norm.cdf(metaz_squarethensum))
  print("Argmax event for square after summing:", surviving_events[np.argmax(pvaltoz_sumthensquare)], np.max(pvaltoz_sumthensquare))
  print("Argmax event for square before summing:", surviving_events[np.argmax(pvaltoz_squarethensum)], np.max(pvaltoz_squarethensum))
  print("Correlation between the two scores:", scipy.stats.pearsonr(pvaltoz_squarethensum, pvaltoz_sumthensquare))

  fig, ax = plt.subplots(ncols=3, figsize=(20,4))
  plt.sca(ax[0])
  scipy.stats.probplot(pvaltoz_sumthensquare, dist=scipy.stats.norm, plot=plt, fit=False)
  plt.plot(plt.xlim(), plt.xlim(), color="black")
  plt.title("Q-Q plot; square after sum across eggs")
  plt.xlabel("Theoretical Z-scores for the quantile")
  plt.ylabel("Actual Z-scores (invcdf(1-p)) for the quantile")
  plt.sca(ax[1])
  scipy.stats.probplot(pvaltoz_squarethensum, dist=scipy.stats.norm, plot=plt, fit=False)
  plt.plot(plt.xlim(), plt.xlim(), color="black")
  plt.title("Q-Q plot; square before sum across eggs")
  plt.xlabel("Theoretical Z-scores for the quantile")
  plt.ylabel("Actual Z-scores (invcdf(1-p)) for the quantile")
  plt.sca(ax[2])
  plt.scatter(pvaltoz_squarethensum, pvaltoz_sumthensquare, s=1)
  plt.plot(plt.xlim(), plt.xlim(), color="black", linestyle="--")
  plt.plot(plt.xlim(), [0,0], color="black")
  plt.plot([0,0], plt.ylim(), color="black")
  plt.xlabel("pvalues to zscores\n(square before sum across eggs)")
  plt.ylabel("pvalues to zscores\n(square after sum across eggs)")
  plt.show()
# Out:
# num events after dropping events with missing data: 475
# ************TIME PERIODS: actual
# Meta-analysis Z-score if squaring *after* summing: 6.431194494097156 pval: 6.330247437347225e-11
# Meta-analysis Z-score if squaring *before* summing 6.420298874215483 pval:  6.800349172664255e-11
# Argmax event for square after summing: ('487', 'September 21', datetime.datetime(2014, 9, 21, 0, 0), datetime.datetime(2014, 9, 21, 23, 59, 59), 86400.0) 3.220190532336857
# Argmax event for square before summing: ('271', 'Obama Acceptance 080828', datetime.datetime(2008, 8, 29, 2, 0), datetime.datetime(2008, 8, 29, 3, 59, 59), 7200.0) 3.693110187603022
# Correlation between the two scores: PearsonRResult(statistic=0.09664672460180908, pvalue=0.03522622187798498)
# ************TIME PERIODS: controltimeshift_-2
# Meta-analysis Z-score if squaring *after* summing: 0.911459091513648 pval: 0.181026765357722
# Meta-analysis Z-score if squaring *before* summing 7.969330070267504 pval:  7.771561172376096e-16
# Argmax event for square after summing: ('434', '12.12.12 Meditation', datetime.datetime(2012, 12, 12, 12, 30), datetime.datetime(2012, 12, 12, 15, 29, 59), 10800.0) 3.6758652241570964
# Argmax event for square before summing: ('106', 'Tiger Woods Triumph', datetime.datetime(2002, 4, 14, 18, 22), datetime.datetime(2002, 4, 14, 22, 59, 59), 16680.0) 4.077320983912348
# Correlation between the two scores: PearsonRResult(statistic=0.12231111548572646, pvalue=0.007614268950115791)
# ************TIME PERIODS: controltimeshift_2
# Meta-analysis Z-score if squaring *after* summing: 0.0951760929863812 pval: 0.4620874794017872
# Meta-analysis Z-score if squaring *before* summing 4.926582405255687 pval:  4.1840165032613896e-07
# Argmax event for square after summing: ('376', 'William &amp Catherine', datetime.datetime(2011, 4, 29, 10, 0), datetime.datetime(2011, 4, 29, 15, 59, 59), 21600.0) 3.7297312617661484
# Argmax event for square before summing: ('100', 'Astrid Lindgren Dies', datetime.datetime(2002, 1, 28, 11, 0), datetime.datetime(2002, 1, 28, 14, 59, 59), 14400.0) 3.7399698663781185
# Correlation between the two scores: PearsonRResult(statistic=0.1791828222858791, pvalue=8.610707746150385e-05)
